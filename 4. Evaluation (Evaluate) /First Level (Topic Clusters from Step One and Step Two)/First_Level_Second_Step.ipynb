# %% [markdown]
# # This notebook performs topic diversity and topic coherence calculations for a clustering result dataset.
#
# ## Steps:
# 1. **Preprocessing the text data**:
#    - Loads the dataset `Second_step_clustering_BERTopic_results.csv` and assumes a separate list of documents.
#    - Preprocesses the text by removing stopwords and non-alphabetic tokens using NLTK.
#
# 2. **Topic diversity calculation**:
#    - Groups the data by 'Topic Label' and extracts keywords from the 'Second_Step_Topic_Keywords' column.
#    - Calculates topic diversity by computing the proportion of unique words to total words across all topics.
#
# 3. **Topic coherence calculation**:
#    - Uses Gensim to compute the c_v coherence score for each topic.
#    - A Gensim dictionary is created from the tokenized documents, and the c_v coherence score is computed for each topic.
#
# 4. **Results output**:
#    - The results, including topic keywords and c_v coherence scores, are stored in a DataFrame and saved as `First_Level_Second_Step_coherence.csv`.
#    - The average coherence score across all topics is calculated and printed for analysis.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load your dataset
file_path = 'Second_step_clustering_BERTopic_results.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Example: Assuming you have a separate list of documents
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

# Extract topics after filtering
topic_representations = data.groupby('Topic Label')['Second_Step_Topic_Keywords'].apply(lambda x: x.iloc[0].split(', '))
topics = topic_representations.tolist()

# Calculate Topic Diversity
def calculate_topic_diversity(topics):
    unique_words = set()
    total_words = 0

    for topic in topics:
        unique_words.update(topic)  # Add words to the unique set
        total_words += len(topic)   # Count total words in all topics

    # Topic diversity is the proportion of unique words to total words
    topic_diversity = len(unique_words) / total_words
    return topic_diversity

# Calculate topic diversity
topic_diversity = calculate_topic_diversity(topics)

# Display the topic diversity score
print(f"\nTopic Diversity: {topic_diversity}")
# Out:
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Topic Diversity: 0.429073482428115

# %% [markdown]
# Topic Coherence

# %%
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
import pandas as pd

# Assuming 'processed_docs' is a list of tokenized documents
# Create a Gensim dictionary from the processed documents
dictionary = Dictionary(processed_docs)

# Initialize a list to store c_v coherence scores
per_topic_coherence_cv = []

for topic in topics:
    # Create a list containing just the current topic
    current_topic = [topic]
    
    print(current_topic)
    # print(processed_docs)
    # print(dictionary)
    
    # Initialize the CoherenceModel for the current topic using 'c_v'
    coherence_model_cv = CoherenceModel(topics=current_topic, texts=processed_docs, dictionary=dictionary, coherence='c_v')
    
    # Compute the c_v coherence score
    coherence_cv = coherence_model_cv.get_coherence()
    print(coherence_cv)
    # Append the c_v score to the list
    per_topic_coherence_cv.append(coherence_cv)
    
    

# Create a DataFrame to display the results
results = pd.DataFrame({
    "Topic": topic_ids,
    "Keywords": topic_representations.values,
    "Coherence c_v": per_topic_coherence_cv,
})


# Display overall and per-topic coherence scores
print(results)
# Out:
# [['hypergraph', 'subgraph', 'graphs', 'hypergraphs', 'graph', 'adjacency', 'networks', 'nodes', 'vertices', 'embeddings']]
# 0.57424560033956
# [['federated', 'privacy', 'learning', 'datasets', 'collaborative', 'distributed', 'trained', 'sharing', 'fedllm', 'collaboratively']]
# 0.5736654091434796
# [['graphs', 'subgraph', 'nodes', 'networks', 'graph', 'subgraphs', 'supervised', 'node', 'learning', 'labeled']]
# 0.6255834867442949
# [['captioning', 'multimodal', 'embeddings', 'recognition', 'captions', 'encoder', 'embedding', 'retrieval', 'visual', 'text']]
# 0.6520743704244423
# [['learns', 'reinforcement', 'robotic', 'robotics', 'robot', 'learning', 'robots', 'exploration', 'learned', 'imitation']]
# 0.6901123007785468
# [['mri', 'imaging', 'neuroimaging', 'tomography', 'fmri', 'segmentation', 'dataset', 'deep', 'images', 'brain']]
# 0.5866121210747726
# [['attention', 'rnns', 'memory', 'nlp', 'learn', 'recurrent', 'examples', 'context', 'language', 'transformers']]
# 0.4572251851231385
# [['audio', 'microphone', 'encoder', 'recording', 'acoustic', 'supervised', 'acoustics', 'wavlm', 'recognition', 'auditory']]
# 0.5093620848200476
# [['adversarial', 'malicious', 'vulnerabilities', 'attacker', 'threats', 'vulnerability', 'security', 'attacks', 'attackers', 'vulnerable']]
# 0.893062211538694
# [['utterances', 'utterance', 'transcription', 'speech', 'dialogue', 'voice', 'transcripts', 'multilingual', 'conversational', 'decoder']]
# 0.6223952725024909
# [['reinforcement', 'reward', 'rewards', 'learning', 'agents', 'agent', 'learned', 'automaton', 'autonomous', 'tasks']]
# 0.6226387660245961
# [['sparse', 'lasso', 'optimal', 'iterative', 'optimization', 'algorithms', 'matrix', 'matrices', 'spectral', 'complexity']]
# 0.5109648528342654
# [['forecast', 'forecasts', 'forecasting', 'meteorological', 'predicting', 'spatiotemporal', 'predict', 'climate', 'prediction', 'weather']]
# 0.806511666042215
# [['reinforcement', 'planning', 'learning', 'exploration', 'actions', 'rewards', 'learned', 'reward', 'critic', 'control']]
# 0.6747447339135065
# [['reinforcement', 'optimality', 'learning', 'optimal', 'critic', 'policies', 'policy', 'markovian', 'reward', 'exploration']]
# 0.6840010068280248
# [['learns', 'reinforcement', 'learning', 'planning', 'supervised', 'learned', 'trained', 'reward', 'rewards', 'learn']]
# 0.582686499438803
# [['bias', 'biases', 'stereotypes', 'attitudes', 'stereotyping', 'perceptions', 'stereotypical', 'language', 'demographics', 'culturally']]
# 0.4767092015661568
# [['privacy', 'adversarial', 'private', 'confidential', 'obfuscation', 'datasets', 'unlearning', 'deep', 'secure', 'learning']]
# 0.4215601998148699
# [['graphs', 'networks', 'graph', 'graphgpt', 'adjacency', 'neural', 'nodes', 'node', 'edges', 'network']]
# 0.6778989483417048
# [['visual', 'multimodal', 'recognition', 'vision', 'embedding', 'language', 'linguistic', 'concepts', 'semantic', 'vlm']]
# 0.5688168435607891
# [['federated', 'privacy', 'distributed', 'cloud', 'collaborative', 'shared', 'cluster', 'sharing', 'networks', 'fedmap']]
# 0.5594227651617444
# [['graphnas', 'networks', 'graphs', 'subgraph', 'graphstorm', 'nodes', 'graph', 'gnn', 'gnns', 'neural']]
# 0.5585220983367701
# [['kernels', 'kernel', 'approximations', 'rkhs', 'gaussian', 'hessian', 'approximation', 'neural', 'spectral', 'dimensional']]
# 0.5844312668341587
# [['parallelization', 'fpgas', 'cnns', 'fpga', 'throughput', 'accelerator', 'accelerators', 'hardware', 'memory', 'microarchitecture']]
# 0.6457557331872021
# [['cloud', 'edge', 'federated', 'networks', 'servers', 'bandwidth', 'iot', 'serverless', 'network', 'distributed']]
# 0.5975547329894593
# [['federated', 'distributed', 'learning', 'synchronization', 'adaptive', 'sgd', 'stochastic', 'centralized', 'asynchronous', 'gradient']]
# 0.6279535228060577
# [['prognosis', 'lung', 'cancer', 'ai', 'cnn', 'predict', 'radiology', 'oncology', 'prediction', 'melanoma']]
# 0.37034002175930564
# [['sentiment', 'corpus', 'tweets', 'linguistic', 'annotators', 'annotations', 'twitter', 'lexicon', 'annotation', 'textual']]
# 0.6018601906581919
# [['ranking', 'evaluations', 'rankings', 'evaluation', 'language', 'assessment', 'responses', 'bias', 'questioner', 'prompts']]
# 0.40233641360656414
# [['adversarial', 'teaming', 'threat', 'unsafe', 'attacker', 'attackers', 'attacking', 'vulnerability', 'vulnerabilities', 'attacks']]
# 0.6610684848343811
# [['pretraining', 'trained', 'unlearning', 'pretrained', 'training', 'benchmarks', 'tuning', 'datasets', 'dataset', 'tuned']]
# 0.47550070744908696
# [['modeling', 'simulations', 'learning', 'neural', 'dynamics', 'networks', 'nonlinear', 'pdes', 'simulation', 'computational']]
# 0.6042479975588739
# [['dynamics', 'learning', 'dynamical', 'neural', 'modeling', 'odes', 'networks', 'dynamic', 'nonlinear', 'hamiltonian']]
# 0.6228515057315229
# [['editing', 'gans', 'generative', 'gan', 'blur', 'denoising', 'attention', 'diffusion', 'images', 'pixel']]
# 0.4586409529173262
# [['factorization', 'dimensionality', 'supervised', 'autoencoders', 'regularization', 'features', 'discriminative', 'dimensional', 'matrix', 'feature']]
# 0.5224058932387785
# [['recommender', 'recommendation', 'recommendations', 'personalized', 'popularity', 'preference', 'spotify', 'preferences', 'playlists', 'rankings']]
# 0.4839662911252419
# [['transportation', 'traffic', 'routes', 'ridesharing', 'travelers', 'travel', 'trips', 'transport', 'mobility', 'passengers']]
# 0.6011799423206865
# [['optimality', 'reinforcement', 'optimal', 'bandit', 'mdps', 'learning', 'mdp', 'policies', 'exploration', 'policy']]
# 0.7609694065485028
# [['diffusion', 'models', 'denoising', 'generative', 'stochastic', 'denoisers', 'denoiser', 'priors', 'brownian', 'sampling']]
# 0.5338525238975892
# [['bert', 'encoder', 'encoders', 'encode', 'embeddings', 'tokenizer', 'tokenization', 'decoder', 'embedding', 'representations']]
# 0.6409189059228149
# [['privacy', 'adversary', 'security', 'attacks', 'secure', 'federated', 'confidentiality', 'malicious', 'attacker', 'protect']]
# 0.7439415730026335
# [['answerability', 'answering', 'questions', 'annotators', 'retrieval', 'comprehension', 'responses', 'answers', 'questionnaires', 'texts']]
# 0.5924581566800334
# [['tweets', 'twitter', 'sentiment', 'reddit', 'hashtags', 'communities', 'sentiments', 'news', 'epidemic', 'content']]
# 0.6187680166348878
# [['captioning', 'captions', 'multimodal', 'caption', 'multilingual', 'visual', 'translation', 'textual', 'text', 'benchmark']]
# 0.6395354799304405
# [['speechtokenizer', 'voice', 'vocalizations', 'voices', 'utterances', 'audio', 'speaker', 'speech', 'vocal', 'acoustic']]
# 0.7052786353764221
# [['reinforcement', 'reward', 'rewards', 'learning', 'rl', 'offline', 'learned', 'learner', 'optimal', 'exploration']]
# 0.7046511120695412
# [['variational', 'dynamical', 'neural', 'stochastic', 'dynamics', 'kalman', 'nonlinear', 'ensemble', 'spatiotemporal', 'simulations']]
# 0.6682045246231554
# [['diffusion', 'denoising', 'denoiser', 'gans', 'denoised', 'generative', 'imagenet', 'images', 'modeling', 'gan']]
# 0.5848109638969549
# [['segmentation', 'imaging', 'supervised', 'mri', 'microscopy', 'tomography', 'images', 'datasets', 'unsupervised', 'detection']]
# 0.5557133355338986
# [['attention', 'memory', 'sparse', 'recurrent', 'recall', 'tasks', 'efficient', 'language', 'chunk', 'longlora']]
# 0.3312199206995437
# [['utterances', 'phonetics', 'phonetic', 'speech', 'phonetically', 'voice', 'corpus', 'asr', 'pronunciation', 'multilingual']]
# 0.62860088925881
# [['multimodal', 'embedding', 'supervised', 'modality', 'ehr', 'ehrs', 'health', 'medical', 'structured', 'unstructured']]
# 0.5982948494737623
# [['privacy', 'federated', 'private', 'adversarial', 'distributed', 'sharing', 'learning', 'secret', 'security', 'decentralized']]
# 0.711697326677502
# [['seismic', 'waveform', 'deep', 'inversion', 'predicting', 'forecasting', 'neural', 'prediction', 'deeponet', 'wave']]
# 0.45785813822637395
# [['caching', 'cache', 'caches', 'memory', 'cachedattention', 'quantization', 'storage', 'attention', 'compression', 'efficient']]
# 0.4757688704696217
# [['speaker', 'utterances', 'diarization', 'voice', 'voices', 'speech', 'audio', 'microphone', 'corpus', 'transcription']]
# 0.7145629378456411
# [['optimal', 'allocation', 'equilibrium', 'incentive', 'bandits', 'equilibria', 'auctions', 'games', 'markets', 'bandit']]
# 0.40894143297528096
# [['corpus', 'zeroshot', 'annotation', 'annotate', 'annotated', 'nlp', 'classification', 'shot', 'nlg', 'sentences']]
# 0.4005141636817079
# [['wasserstein', 'gradient', 'variational', 'divergence', 'divergences', 'generative', 'flow', 'minimization', 'stochastic', 'langevin']]
# 0.5747738241392282
# [['biomarkers', 'ai', 'diagnoses', 'diagnosis', 'diagnostic', 'predicting', 'classification', 'predictive', 'interpretability', 'prediction']]
# 0.5005822707209258
# [['boltzmann', 'molecule', 'molecules', 'molecular', 'simulations', 'sampling', 'kinetic', 'atomnet', 'particles', 'flow']]
# 0.41160550047858246
# [['annotated', 'instruction', 'responses', 'language', 'metacognitive', 'feedback', 'tasks', 'examples', 'reinforcement', 'text']]
# 0.37780477912980504
# [['pose', 'poses', 'camera', 'cameras', 'scenes', '3d', 'articulated', 'vision', 'scene', 'slam']]
# 0.6043217508400683
# [['visual', 'supervised', 'learning', 'multimodal', 'prompts', 'captioning', 'embeddings', 'trained', 'captions', 'prompt']]
# 0.4957250493332735
# [['bandits', 'bandit', 'optimal', 'regret', 'optimization', 'reward', 'games', 'guarantees', 'exploration', 'rewards']]
# 0.7471854620519426
# [['graphs', 'graphon', 'graph', 'adjacency', 'spectral', 'nodes', 'networks', 'vertex', 'edges', 'clustering']]
# 0.6818154772016267
# [['reinforcement', 'agents', 'games', 'agent', 'rewards', 'cooperation', 'reward', 'opponents', 'strategies', 'cooperative']]
# 0.734550783273643
# [['adversarial', 'gans', 'watermarking', 'steganalysis', 'copyright', 'steganography', 'deepfacegen', 'watermark', 'spoofing', 'impersonation']]
# 0.2555940878347858
# [['posterior', 'bayesian', 'generative', 'phylogenetic', 'likelihood', 'inference', 'models', 'estimating', 'markov', 'monte']]
# 0.615663633375027
# [['dialogues', 'dialogue', 'dialog', 'conversation', 'conversational', 'chatbots', 'conversations', 'chatbot', 'chat', 'planning']]
# 0.7833439945874182
# [['traffic', 'accidentgpt', 'driving', 'accidents', 'roads', 'lanes', 'crash', 'vehicles', 'predicting', 'prediction']]
# 0.6430297116272601
# [['cnn', 'cnns', 'efficientnetv2b1', 'memory', 'optimized', 'networks', 'neural', 'deep', 'dnns', 'dnn']]
# 0.6460324009171957
# [['supervised', 'classification', 'learning', 'adversarial', 'labeling', 'deep', 'unlearning', 'trained', 'labeled', 'labels']]
# 0.42914515130516084
# [['normalization', 'regularization', 'neural', 'generalization', 'backpropagation', 'convolutional', 'neuron', 'learning', 'networks', 'deep']]
# 0.5831028056316273
# [['classifiers', 'learning', 'classification', 'classifier', 'generalization', 'regularization', 'optimal', 'memorization', 'minimax', 'distributionally']]
# 0.33083837572630836
# [['planning', 'robotics', 'planner', 'robotic', 'robot', 'planners', 'robots', 'motions', 'motion', 'trajectory']]
# 0.7629548132575179
# [['reservoir', 'deep', 'flow', 'flows', 'predicting', 'modeling', 'predict', 'simulations', 'neural', 'prediction']]
# 0.5414759597664193
# [['saliency', 'neural', 'attention', 'recognition', 'visual', 'attentions', 'vision', 'representations', 'images', 'perception']]
# 0.4413850849177832
# [['stochastic', 'brownian', 'discretization', 'diffusion', 'gaussian', 'sde', 'drift', 'probabilistic', 'sdes', 'mcmc']]
# 0.5379160385172506
# [['hippocampal', 'planning', 'hippocampus', 'exploration', 'cortex', 'cognitive', 'environments', 'reinforcement', 'behaviors', 'adaptive']]
# 0.34273998223464497
# [['reinforcement', 'objectives', 'optimal', 'critic', 'learning', 'reward', 'objective', 'rewards', 'optimization', 'control']]
# 0.6073144625657866
# [['textual', 'nlp', 'summarization', 'linguistic', 'texts', 'evaluation', 'text', 'generated', 'language', 'lingual']]
# 0.5748768502257013
# [['predicting', 'biomarkers', 'prediction', 'personalized', 'learning', 'lstm', 'biomedical', 'cancer', 'genomic', 'genome']]
# 0.3660681222840737
# [['adversarial', 'privacy', 'security', 'anonymization', 'protected', 'adversary', 'secure', 'confidentiality', 'protection', 'attacks']]
# 0.656086298885316
# [['compression', 'compressed', 'memory', 'softmax', 'decoding', 'tokenizers', 'decoder', 'tokenization', 'tokenizer', 'attention']]
# 0.39175637294752885
# [['mcmc', 'bayesian', 'probabilistic', 'posteriors', 'markov', 'posterior', 'stochastic', 'bayesmbar', 'monte', 'dmc']]
# 0.56104711338069
# [['knowledge', 'contexts', 'language', 'entailment', 'comprehension', 'memory', 'paraphrases', 'nlp', 'facts', 'retrieval']]
# 0.438722410908036
# [['opioids', 'opioid', 'nlp', 'annotated', 'tweets', 'drug', 'classification', 'text', 'addiction', 'posts']]
# 0.4618433198693972
# [['multimodal', 'modality', 'dialogues', 'visual', 'models', 'mllm', 'interactive', 'conversations', 'conversational', 'dialog']]
# 0.5158504646917875
# [['retrieval', 'embeddings', 'embedding', 'embed', 'textual', 'multilingual', 'search', 'encoder', 'lingual', 'relevance']]
# 0.4161396768780299
# [['forgetting', 'continual', 'learning', 'memory', 'learned', 'forgotten', 'adaptive', 'regularization', 'incremental', 'trained']]
# 0.46392124610761537
# [['reinforcement', 'learning', 'optimizing', 'exploration', 'reward', 'rewards', 'autonomous', 'optimization', 'optimisation', 'strategies']]
# 0.5198844583884875
# [['memorizing', 'memorization', 'context', 'examples', 'skills', 'exemplars', 'answering', 'knowledge', 'language', 'reasoning']]
# 0.42830458206119265
# [['bias', 'biases', 'debiasing', 'biased', 'unbiased', 'debiased', 'debias', 'annotators', 'biasalert', 'nlp']]
# 0.5130729713220139
# [['cnn', 'neural', 'backpropagation', 'imagenet', 'layers', 'layer', 'convolutional', 'neurons', 'networks', 'memory']]
# 0.6630450980043937
# [['workflows', 'workflow', 'automate', 'automation', 'apis', 'tools', 'interpreter', 'flowmind', 'software', 'pipelines']]
# 0.4942374080087858
# [['quantization', 'compression', 'softmax', 'compressed', 'quantize', 'compressing', 'quantized', 'memory', 'pruning', 'efficient']]
# 0.6592971686040026
# [['reinforcement', 'optimal', 'regret', 'adaptive', 'learning', 'optimization', 'guarantees', 'exploration', 'control', 'reward']]
# 0.6212826256550781
# [['recognition', 'vision', 'detection', 'supervised', 'detectors', 'objectness', 'attention', 'yolov8', 'objects', '3d']]
# 0.4495356375368771
# [['inferences', 'answering', 'reasoning', 'questions', 'retrieval', 'knowledge', 'answers', 'hop', 'language', 'contexts']]
# 0.5393760988019146
# [['judgments', 'evaluations', 'bias', 'evaluation', 'annotators', 'biases', 'evaluating', 'judge', 'annotations', 'assessing']]
# 0.6425216178183477
# [['navigate', 'navigating', 'navigation', 'planning', 'robotics', 'robot', 'terrain', 'slam', 'obstacle', 'exploration']]
# 0.6440148713353469
# [['recourses', 'recourse', 'algorithmic', 'unfairness', 'algorithms', 'decisions', 'predictive', 'bias', 'allocation', 'fairness']]
# 0.4679408474574004
# [['biases', 'bias', 'biased', 'partisan', 'debates', 'sentiment', 'propaganda', 'biasscanner', 'politically', 'political']]
# 0.41033465086656057
# [['headlines', 'corpus', 'headline', 'nlp', 'texts', 'newswire', 'newsserow', 'annotated', 'multilingual', 'corpora']]
# 0.3834640591685352
# [['planning', 'planner', 'pomdps', 'pomdp', 'reinforcement', 'rpomdps', 'markov', 'stochastic', 'optimal', 'pomcp']]
# 0.5059523096663172
# [['memorization', 'pretrained', 'tuning', 'trained', 'language', 'tuned', 'training', 'generating', 'tasks', 'examples']]
# 0.41878749914315894
# [['ai', 'generative', 'openai', 'aied', 'creativity', 'intelligence', 'artificial', 'creators', 'software', 'openness']]
# 0.4325880859453246
# [['agents', 'reinforcement', 'agent', 'cooperative', 'cooperation', 'learning', 'coordination', 'cooperate', 'collaborative', 'centralized']]
# 0.7194537516440109
# [['estimation', 'estimators', 'optimal', 'estimator', 'lasso', 'robust', 'outliers', 'outlier', 'unbiased', 'empirical']]
# 0.46708970640656694
# [['energy', 'buildings', 'forecasting', 'buildingsbench', 'predicting', 'forecast', 'prediction', 'hvac', 'predict', 'forecasts']]
# 0.5118521930216046
# [['optimizers', 'optimization', 'optimize', 'hyperparameters', 'minimization', 'hyperparameter', 'minimizing', 'optimal', 'objectives', 'constraints']]
# 0.5668527264653311
# [['multimodal', 'modality', 'attention', 'semantic', 'modal', 'linking', 'semantics', 'visual', 'retrieval', 'linkage']]
# 0.4179736041056044
# [['cnn', 'segmentation', 'objects', 'instance', 'detection', 'vision', 'images', 'masks', 'detectors', 'mask']]
# 0.6095307510481973
# [['chatbots', 'chatbot', 'ai', 'conversational', 'intelligence', 'bots', 'communication', 'social', 'human', 'intentions']]
# 0.46131807764775534
# [['nonlinear', 'fractional', 'sparse', 'solvers', 'odes', 'differential', 'pdes', 'rnns', 'solver', 'numerical']]
# 0.5406120856964431
# [['planning', 'reinforcement', 'planner', 'maze', 'robotics', 'exploration', 'robot', 'autonomous', 'robotic', 'learning']]
# 0.6449121755213932
# [['retrieval', 'conversational', 'conversation', 'chatbots', 'conversations', 'dialogue', 'chatbot', 'dialogues', 'dialog', 'assistant']]
# 0.8091479220611898
# [['dehazing', 'haze', 'blur', 'convolutional', 'encoder', 'vision', 'deblur', 'deep', 'hazy', 'res2net']]
# 0.2942918564265769
# [['programming', 'program', 'generate', 'pseudocode', 'abstractions', 'synthesis', 'algorithmic', 'programs', 'automata', 'solvers']]
# 0.416642726907465
# [['wildfires', 'wildfire', 'disasters', 'flood', 'fires', 'floodwater', 'disaster', 'rescue', 'emergency', 'emergencies']]
# 0.4656025832169708
# [['corpus', 'nlp', 'texts', 'sentences', 'linguistic', 'language', 'structured', 'languages', 'text', 'writing']]
# 0.7279534664382916
# [['urban', 'cities', 'city', 'infrastructure', 'spatial', 'data', 'features', 'geoshapley', 'areas', 'geographical']]
# 0.5013055529627366
# [['regularization', 'overfitting', 'gradients', 'minimization', 'minimizing', 'overparameterization', 'generalization', 'gradient', 'learning', 'overparameterized']]
# 0.5883165187066333
# [['learnability', 'classification', 'prediction', 'optimal', 'deterministic', 'classifier', 'adversary', 'randomized', 'bandit', 'complexity']]
# 0.3581527027950864
# [['forecasting', 'inventory', 'forecast', 'forecasts', 'predicting', 'prediction', 'supply', 'planning', 'analytics', 'suppliers']]
# 0.485905933998921
# [['scaling', 'generalization', 'neural', 'regularization', 'sparse', 'sgd', 'networks', 'learned', 'small', 'empirically']]
# 0.5157935487861535
# [['visual', '3d', 'multimodal', 'vision', 'spatial', 'interactive', 'reasoning', 'robot', 'tasks', 'robots']]
# 0.5230671711442119
# [['attention', 'memory', 'softmax', 'decoder', 'layers', 'transformers', 'throughput', 'efficient', 'pruning', 'faster']]
# 0.49453424479315633
# [['iot', 'iotds', 'sensor', 'rscnet', 'cloud', 'sensing', 'sensors', 'networks', 'network', 'classification']]
# 0.45631422680121814
# [['vision', 'camera', 'cameras', '3d', 'rgb', 'recognition', 'scenes', 'view', 'views', 'frames']]
# 0.6732745202008121
# [['chatbots', 'chatbot', 'conversational', 'conversations', 'conversation', 'ai', 'dialogue', 'messages', 'dialogues', 'chat']]
# 0.7623543921275143
# [['automation', 'ai', 'architecture', 'agent', 'agents', 'software', 'industrial', 'engineering', 'intelligence', 'artificial']]
# 0.5615784119308646
# [['artworks', 'artists', 'artistic', 'stylistic', 'styles', 'artness', 'artwork', 'generative', 'stylization', 'artist']]
# 0.5725014648674771
# [['multimodal', 'videos', 'visual', 'language', 'tasks', 'answering', 'mllm', 'benchmark', 'mind', 'modal']]
# 0.5554935844405503
# [['articulated', 'pose', 'poses', 'portrait', '3d', 'animation', 'avatars', 'vr', 'avatar', 'camera']]
# 0.6195316723655279
# [['programming', 'programmers', 'programmer', 'coding', 'code', 'program', 'developers', 'software', 'agilecoder', 'prompts']]
# 0.5940119169040952
# [['cognition', 'biases', 'bias', 'judgments', 'cognitive', 'behavioral', 'behavior', 'intelligence', 'decisions', 'language']]
# 0.5542845814557202
# [['language', 'models', 'lms', 'decoding', 'llms', 'deepseek', 'llama2', 'llm', 'throughput', 'computational']]
# 0.4275228267192981
# [['regularization', 'kernels', 'lasso', 'classification', 'learning', 'classifier', 'regularized', 'kernel', 'generalization', 'svm']]
# 0.3683227028159105
# [['supervised', 'labeling', 'classification', 'imagenet', 'labeled', 'labels', 'embeddings', 'learning', 'embedding', 'label']]
# 0.5544177230854992
# [['disinformation', 'misinformation', 'debunking', 'persuasive', 'deception', 'fallacy', 'biases', 'fallacies', 'bias', 'headlines']]
# 0.287872847810286
# [['annotating', 'annotations', 'annotators', 'annotation', 'annotate', 'annotated', 'annotator', 'labeling', 'nlp', 'crowdsourcing']]
# 0.8298440413025837
# [['hashing', 'imagenet', 'hash', 'cnn', 'cnns', 'retrieval', 'convolutional', 'images', 'features', 'embedding']]
# 0.5800581088577441
# [['llms', 'language', 'modelizer', 'llm', 'benchmarks', 'expertise', 'models', 'knowledge', 'training', 'optimizers']]
# 0.4232397518095393
# [['aesthetics', 'aesthetic', 'multimodal', 'visual', 'attributes', 'generative', 'creative', 'ratings', 'colors', 'perception']]
# 0.5194949544209713
# [['tokenizers', 'language', 'datasets', 'nlp', 'models', 'feature', 'dataset', 'generating', 'trained', 'tokens']]
# 0.45841150105626954
# [['nlg', 'text', 'generate', 'texts', 'sentences', 'generation', 'generated', 'constraints', 'language', 'lexical']]
# 0.5307499028170717
# [['cnn', 'cnns', 'drilling', 'boulders', 'geological', 'neural', 'deep', 'networks', 'learning', 'drill']]
# 0.5138796058110804
# [['ethical', 'ethics', 'ai', 'moral', 'agent', 'intelligence', 'algorithmic', 'agents', 'humanity', 'cooperation']]
# 0.5293701489628775
# [['linguistic', 'cognition', 'linguistics', 'language', 'cognitive', 'semantic', 'learners', 'knowledge', 'brain', 'minds']]
# 0.4411700705304912
# [['unlearning', 'memorization', 'forgetting', 'memorize', 'unlearned', 'dataset', 'overfitting', 'trained', 'forget', 'training']]
# 0.5388331244495357
# [['bayesian', 'probabilistic', 'neural', 'ensembles', 'optimization', 'posterior', 'deep', 'estimation', 'sbnn', 'networks']]
# 0.5210813568953891
# [['videos', 'multimodal', 'visual', 'attention', 'video', 'clips', 'vision', 'frames', 'trained', 'recognition']]
# 0.5417062093798874
# [['classifiers', 'classifier', 'classification', 'ensemble', 'ensembles', 'boosting', 'datasets', 'outliers', 'outlier', 'unifier']]
# 0.4357474848431542
# [['chemical', 'chemistry', 'chemists', 'chemist', 'molecule', 'molecular', 'catalysts', 'chemicals', 'synthesis', 'molecules']]
# 0.701269833418934
# [['turbine', 'prediction', 'lstm', 'forecasting', 'turbines', 'neural', 'forecast', 'scada', 'forecasts', 'monitoring']]
# 0.4844463229032609
# [['classification', 'misclassification', 'losses', 'surrogate', 'loss', 'learning', 'generalization', 'prediction', 'learnability', 'multiclass']]
# 0.3308215194819775
# [['federated', 'privacy', 'intrusion', 'distributed', 'decentralized', 'ddos', 'cloud', 'security', 'anomaly', 'malicious']]
# 0.5765832417545623
# [['videos', 'videoshop', 'gans', 'clips', 'scenes', 'video', 'frames', 'compression', 'editing', 'generative']]
# 0.4624253803900282
# [['attention', 'captioning', 'recognition', 'captions', 'scene', 'visual', 'vision', 'images', 'segmentation', 'coco']]
# 0.6866509751691445
# [['nl2gql', 'semantic', 'retrieval', 'knowledge', 'textual', 'answering', 'knowledgenavigator', 'gql', 'entities', 'queries']]
# 0.39195075778405464
# [['benchmarking', 'tools', 'benchmarks', 'benchmark', 'tool', 'evaluations', 'language', 'answering', 'software', 'openai']]
# 0.45283402570126763
# [['backdoors', 'backdoor', 'adversarial', 'attacks', 'backdoored', 'attacker', 'vulnerability', 'malicious', 'security', 'obfuscation']]
# 0.7276548164953073
# [['hyperbolic', 'embeddings', 'embedding', 'manifolds', 'manifold', 'dimensional', 'cnns', 'riemannian', 'classification', 'hessian']]
# 0.42726733871710626
# [['annotation', 'corpus', 'semantic', 'metadata', 'texts', 'scholarly', 'wikipedia', 'ontologies', 'ontology', 'retrieval']]
# 0.5086276674229366
# [['chatbots', 'chatbot', 'socialbot', 'conversational', 'conversation', 'conversations', 'dialogues', 'chat', 'dialogue', 'chatgpt']]
# 0.7843748824173263
# [['robotic', 'robotics', 'robot', 'robots', 'manipulators', 'grasping', 'softmac', 'manipulator', 'exoskeleton', 'mechanical']]
# 0.4546339572718653
# [['riemannian', 'manifold', 'manifolds', 'geodesics', 'geodesic', 'generative', 'gps', 'divergence', 'spatiotemporal', 'gradient']]
# 0.4817748684458868
# [['corpus', 'syntactic', 'nlp', 'context', 'linguistic', 'multilingual', 'parsing', 'lingual', 'sentences', 'language']]
# 0.5526296316493413
# [['lingual', 'multilingual', 'corpus', 'translations', 'linguistics', 'corpora', 'linguistic', 'languages', 'language', 'langue']]
# 0.4845563108416613
# [['knowledge', 'relational', 'reasoning', 'inference', 'entities', 'logic', 'language', 'entity', 'queries', 'relations']]
# 0.6241878943301734
# [['safetybench', 'safety', 'unsafe', 'safeguards', 'risks', 'vulnerabilities', 'ai', 'risk', 'language', 'testing']]
# 0.49600473656012756
# [['dynamics', 'cells', 'multicellular', 'networks', 'cell', 'neural', 'interactions', 'dynamical', 'cellular', 'motion']]
# 0.6014125782129647
# [['prompts', 'prompting', 'prompt', 'conversational', 'ai', 'answering', 'tasks', 'questions', 'responses', 'task']]
# 0.6236809916690972
# [['sram', 'memory', 'fpgas', 'fpga', 'hardware', 'cpus', 'cim', 'gpu', 'gpus', 'cpu']]
# 0.6221056571891098
# [['semantic', 'parsing', 'nlp', 'annotated', 'entailment', 'lexical', 'structured', 'amr', 'corpora', 'entities']]
# 0.5393135697534801
# [['linguistic', 'grammars', 'syntactic', 'semantics', 'languages', 'grammar', 'language', 'monadic', 'contextual', 'parsing']]
# 0.5879408246062492
# [['ai', 'thinking', 'brainteaser', 'tasks', 'subtasks', 'cognitive', 'interactive', 'reasoning', 'planning', 'cognition']]
# 0.4223157060583597
# [['recommender', 'embeddings', 'personalized', 'embedding', 'recommendation', 'recommendations', 'ranking', 'items', 'modality', 'similarity']]
# 0.6071953139064916
# [['gpu', 'gpus', 'fpga', 'memory', 'compilers', 'implementations', 'sram', 'bottleneck', 'hardware', 'dataflow']]
# 0.6309307931761541
# [['simplifications', 'simplification', 'readability', 'sentences', 'annotation', 'nlp', 'corpus', 'texts', 'lexical', 'text']]
# 0.533544184951305
# [['shapenet', '3d', 'points', 'shapes', 'maps', 'shape', 'mesh', 'surfaces', 'lidar', 'point2ssm']]
# 0.46695472148404427
# [['underwater', 'submerged', 'cnn', 'sonar', 'recognition', 'camera', 'lidar', 'detection', 'detecting', 'detector']]
# 0.40526389613795094
# [['explanations', 'explainability', 'ai', 'interpretability', 'neural', 'cnn', 'explaining', 'classifiers', 'explainer', 'interpretable']]
# 0.533250478949882
# [['epistemological', 'epistemic', 'probabilistic', 'belief', 'uncertainty', 'beliefs', 'information', 'isopignistic', 'hypothesis', 'credibility']]
# 0.34399831215757476
# [['retrieval', 'queries', 'sparql', 'search', 'annotations', 'retrievers', 'litsearch', 'semantic', 'retriever', 'query']]
# 0.5011209391409088
# [['recognition', 'imagenet', 'neural', 'vision', 'representations', 'supervised', 'objects', 'features', 'convolutional', 'visual']]
# 0.5354477787221947
# [['lidar', 'radar', 'pointnet', 'clouds', '3d', 'camera', 'terrain', 'slam', 'depth', 'mapping']]
# 0.5227461291275466
# [['classifier', 'classification', 'imagenet', 'supervised', 'learning', 'classes', 'datasets', 'imbalance', 'dataset', 'imbalanced']]
# 0.5995412158650796
# [['matting', 'mattes', 'matte', 'pixels', 'segmentation', 'pixel', 'videos', 'ximagenet', 'images', 'objectpi']]
# 0.4137332998616664
# [['pretraining', 'supervised', 'imagenet', 'trained', 'learning', 'pretrained', 'learned', 'training', 'classification', 'datasets']]
# 0.5158796749828394
# [['supervised', 'classification', 'learning', 'recognition', 'imagenet', 'classes', 'trained', 'pretraining', 'learned', 'training']]
# 0.4803876181233354
# [['fidelity', 'surrogate', 'modeling', 'prediction', 'modelling', 'surrogates', 'regression', 'neural', 'model', 'predictive']]
# 0.4971808028465299
# [['annotations', 'annotation', 'textual', 'retrieval', 'summarization', 'summaries', 'factuality', 'narratives', 'reading', 'narrative']]
# 0.6040447454830238
# [['compression', 'decoding', 'compressed', 'encoder', 'information', 'bottleneck', 'decoder', 'entropy', 'generalization', 'encoding']]
# 0.5532019426757333
# [['sgd', 'asynch', 'distributed', 'asynchronous', 'synchronization', 'stragglers', 'synchronous', 'sgbdt', 'parallelism', 'gradient']]
# 0.6906004840609603
# [['encodenet', 'autoencoders', 'representations', 'embeddings', 'encoders', 'autoencoder', 'imagenet', 'neural', 'encoder', 'supervised']]
# 0.3599382442009106
# [['imagenet', 'cnn', 'autoencoder', 'cnns', 'neural', 'backpropagation', 'networks', 'supervised', 'deep', 'learning']]
# 0.5025594229175654
# [['reinforcement', 'optimal', 'games', 'bandits', 'strategy', 'allocation', 'strategies', 'game', 'risk', 'optimize']]
# 0.5956629078307846
# [['retrieval', 'search', 'personalization', 'personalized', 'queries', 'personalize', 'profiles', 'mindsearch', 'seeking', 'cosearchagent']]
# 0.3059529293712989
# [['adversarial', 'cybersecurity', 'security', 'ai', 'attacks', 'threats', 'intrusion', 'attack', 'threat', 'defense']]
# 0.8412499900641836
# [['operators', 'operator', 'approximating', 'approximation', 'neural', 'approximate', 'learning', 'banach', 'kernel', 'networks']]
# 0.6841451107982186
# [['generative', 'autoencoder', 'adversarial', 'models', 'variational', 'energy', 'flow', 'modeling', 'rnn', 'generator']]
# 0.3973789301617226
# [['planning', 'planner', 'reinforcement', 'autonomous', 'plan', 'policies', 'schedule', 'temporal', 'projects', 'actions']]
# 0.5348370969262898
# [['corpus', 'nlp', 'stemming', 'texts', 'disambiguation', 'semantic', 'entities', 'keywords', 'entity', 'contextual']]
# 0.5494345082484166
# [['dialogues', 'dialogue', 'conversational', 'utterances', 'conversation', 'conversations', 'utterance', 'responses', 'chatgpt', 'language']]
# 0.8488238039964738
# [['softmax', 'gaussian', 'experts', 'overparameterization', 'generalization', 'minimax', 'expert', 'overparameterized', 'neural', 'regularization']]
# 0.283709692980035
# [['quizzes', 'distractors', 'distractor', 'assessments', 'students', 'comprehension', 'exam', 'quiz', 'pedagogical', 'assessment']]
# 0.34565196491945144
# [['pdes', 'pde', 'stabilization', 'lyapunov', 'control', 'stability', 'controller', 'controllers', 'nonlinear', 'stabilizing']]
# 0.7431189000544542
# [['ai', 'automation', 'generative', 'prototyping', 'tools', 'programming', 'intelligence', 'tooling', 'genai', 'technology']]
# 0.4411606892462814
# [['keyphrases', 'keyphrase', 'keywords', 'keyword', 'corpus', 'annotations', 'annotators', 'nlp', 'annotated', 'texts']]
# 0.5555261625242787
# [['uav', 'drones', 'drone', 'uavs', 'unmanned', 'lidar', 'sensing', 'flying', 'quadrotor', 'aerial']]
# 0.6388234180798905
# [['depression', 'depressive', 'health', 'wellbeing', 'sentiment', 'data', 'mental', 'anxiety', 'psychological', 'monitoring']]
# 0.5899254384927829
# [['sketches', 'sketching', 'sketch', 'sketchime', 'sketchinr', 'drawings', 'drawing', 'cadyface', 'abstraction', '3d']]
# 0.4239271337507775
# [['narratives', 'storytelling', 'narrative', 'writing', 'linguistic', 'conversations', 'stories', 'summaries', 'texts', 'discourse']]
# 0.4495844719440882
# [['mimo', '5g', 'wireless', 'cellular', 'antennas', 'mmwave', 'transmits', 'pilot', 'antenna', 'channel']]
# 0.3612953912843219
# [['optimality', 'optimal', 'optimize', 'optimization', 'risk', 'regret', 'stochastic', 'predict', 'predictive', 'portfolios']]
# 0.4162003327901786
# [['compositionality', 'compositional', 'compositionally', 'compositions', 'composition', 'generalization', 'neural', 'representations', 'generalize', 'cognition']]
# 0.5823749664818845
# [['bias', 'biases', 'learning', 'neural', 'deeppoly', 'benchmark', 'debiasing', 'classifier', 'generalization', 'networks']]
# 0.3611357626267522
# [['softmax', 'regularization', 'overfitting', 'underfitting', 'neural', 'classifiers', 'deep', 'memorization', 'networks', 'trained']]
# 0.38650473378079003
# [['programming', 'interpreter', 'solvers', 'automate', 'solver', 'programs', 'code', 'tools', 'maxmind', 'optimization']]
# 0.3719063386225506
# [['cultures', 'cultural', 'culturellm', 'culturebank', 'multilingual', 'culture', 'multicultural', 'culturally', 'language', 'culturepark']]
# 0.5725636029688136
# [['entities', 'entity', 'semantic', 'annotated', 'corpus', 'referential', 'corpora', 'hypernym', 'embeddings', 'retrieval']]
# 0.4609827100555915
# [['gans', 'gan', 'microscopy', 'dcgan', 'generative', 'cgan', 'autoencoders', 'imaging', 'adversarial', 'microscope']]
# 0.394779698353411
# [['tutoring', 'tutors', 'grading', 'students', 'learnersourcing', 'pedagogical', 'automating', 'instructional', 'assessment', 'feedback']]
# 0.3997555044056346
# [['ai', 'healthcare', 'bias', 'ethical', 'ethics', 'fairness', 'outcomes', 'biases', 'intelligence', 'medical']]
# 0.6793805716204497
# [['knowledge', 'wikidata', 'entities', 'provenance', 'rdf', 'iconology', 'iconological', 'concepts', 'organizational', 'information']]
# 0.2680193731474763
# [['ai', 'intelligence', 'chatbots', 'iq', 'language', 'turing', 'robot', 'agent', 'behavioral', 'assessment']]
# 0.38937628660165124
# [['reviews', 'review', 'ratings', 'sentiment', 'spam', 'classifier', 'language', 'texts', 'sentences', 'helpfulness']]
# 0.39478735283189204
# [['3d', 'scenecraft', 'scenes', 'uni3d', 'interactive', 'embodied', 'visual', 'robotic', 'scene', 'robot']]
# 0.5856398416879476
# [['summarizing', 'summarization', 'summaries', 'abstracts', 'systematic', 'pubmed', 'metadata', 'summary', 'text', 'automate']]
# 0.34129130513700745
# [['feature', 'supervised', 'classifiers', 'features', 'classification', 'labeling', 'selection', 'prediction', 'learning', 'discriminative']]
# 0.5491649599615093
# [['molecular', 'molecule', 'molecules', 'networks', 'neural', 'graphs', 'representations', 'ligand', 'graph', 'protein']]
# 0.625435641497502
# [['spatial', 'visual', 'planning', 'abstractions', 'reasoning', 'ai', 'language', 'tasks', 'intelligence', 'multimodal']]
# 0.4806064847406056
# [['embeddings', 'embedding', 'recommender', 'memory', 'recommendations', 'factorization', 'recommendation', 'storage', 'gpu', 'items']]
# 0.5447475740205037
# [['audiovisual', 'audio', 'audioldm', 'audiocaps', 'generative', 'recordings', 'sound', 'music', 'visual', 'videos']]
# 0.36802861102489476
# [['repositories', 'documentation', 'retrieval', 'software', 'discoverybench', 'language', 'models', 'tools', 'completions', 'benchmarks']]
# 0.3614537935947831
# [['anomaly', 'anomalies', 'detecting', 'detection', 'supervised', 'datasets', 'boosting', 'hyperspectral', 'monitoring', 'unsupervised']]
# 0.5234663754431044
# [['scheduling', 'prediction', 'knapsack', 'algorithms', 'optimal', 'predictive', 'optimally', 'predictions', 'schedules', 'optimization']]
# 0.3473743998786468
# [['gans', 'gan', 'generative', 'adversarial', 'autoencoders', 'cgan', 'castgan', 'ctgan', 'datasets', 'gansemble']]
# 0.41868866192941895
# [['forecast', 'forecasting', 'networks', 'spatiotemporal', 'graphrl', 'neural', 'prediction', 'graph', 'network', 'temporal']]
# 0.5856279844646801
# [['exploration', 'heuristic', 'algorithms', 'search', 'subtrees', 'monte', 'mcts', 'tree', 'pathfinding', 'randomized']]
# 0.4085388688129859
# [['semantic', 'wordnet', 'lexical', 'semantics', 'linguistic', 'disambiguation', 'semantically', 'parsing', 'nlp', 'parsers']]
# 0.4577670664619092
# [['choreography', 'dance', 'rhythm', 'motions', 'animations', 'animation', 'motion', 'pose', 'poses', 'videos']]
# 0.5932965848685963
# [['cad', 'metamaterial', 'metamaterials', 'generative', 'meshing', 'mesh', 'designs', 'neural', 'designing', 'shapes']]
# 0.3248819201582718
# [['ai', 'agent', 'agents', 'cooperation', 'intelligence', 'warfare', 'autonomous', 'robot', 'intelligent', 'combat']]
# 0.48348733066379374
# [['generative', 'synthetic', 'datasets', 'models', 'learning', 'classification', 'data', 'trained', 'unlearning', 'artificial']]
# 0.4119592623050637
# [['fuzzy', 'classifier', 'classification', 'intuitionistic', 'feature', 'features', 'ensemble', 'prediction', 'datasets', 'kernelshap']]
# 0.4002552831909821
# [['experimentation', 'experimenters', 'statistical', 'experiments', 'metrics', 'empirical', 'randomized', 'testing', 'estimators', 'metric']]
# 0.30673659317325697
# [['entropy', 'variational', 'generative', 'gaussian', 'divergence', 'densities', 'estimation', 'approximations', 'likelihood', 'mixtures']]
# 0.5642472811010754
# [['backpropagation', 'rnns', 'neural', 'rnn', 'networks', 'neurons', 'gradients', 'recurrent', 'gradient', 'dynamical']]
# 0.6905528726471113
# [['imputation', 'forecasting', 'datasets', 'data', 'spatiotemporal', 'recurrent', 'monitoring', 'incomplete', 'temporal', 'ito']]
# 0.4986882430464795
# [['geoparsing', 'geospatial', 'geo', 'geolocalization', 'geographic', 'geolocation', 'geographical', 'geolinguistic', 'geollm', 'geolingit']]
# 0.20562515973634773
# [['embeddings', 'nlp', 'embedding', 'attention', 'textual', 'encoder', 'descriptors', 'detection', 'representations', 'semantic']]
# 0.546902997692346
# [['optimizing', 'optimize', 'generative', 'optimization', 'offline', 'bandit', 'surrogate', 'search', 'gradients', 'algorithms']]
# 0.4649096965025211
# [['learnware', 'software', 'tools', 'mlops', 'projects', 'ai', 'development', 'engineering', 'tooling', 'learning']]
# 0.5347134510072058
# [['iot', 'ioe', 'generative', 'ai', 'cloud', 'devices', 'smart', 'intelligent', 'sensing', 'gai']]
# 0.5140266219280973
# [['counterfactuals', 'counterfactual', 'causality', 'causal', 'counterfactually', 'inference', 'reasoning', 'interventions', 'interventional', 'discrimination']]
# 0.5126357753930814
# [['embeddings', 'biodiversity', 'embedding', 'supervised', 'genomes', 'genome', 'taxonomic', 'classification', 'datasets', 'species']]
# 0.44385826896373537
# [['ai', 'explainability', 'xai', 'explanations', 'xaiport', 'intelligence', 'understandable', 'explainable', 'insights', 'understanding']]
# 0.6438472458002895
# [['markovian', 'stochastic', 'martingale', 'markov', 'approximation', 'ergodic', 'asynchronous', 'algorithms', 'asymptotic', 'optimal']]
# 0.5853487943281867
# [['feature', 'features', 'classification', 'biomarker', 'ensemble', 'selection', 'datasets', 'prediction', 'predictive', 'optimization']]
# 0.49303300672895595
# [['reading', 'gaze', 'dyslexia', 'corpus', 'attention', 'linguistic', 'texts', 'comprehension', 'eye', 'text']]
# 0.39748116188044674
# [['sentences', 'linguistic', 'semantics', 'syntactic', 'ambiguities', 'semantic', 'lexical', 'negation', 'nlg', 'ambiguity']]
# 0.5113713220322118
# [['attributions', 'attribution', 'classifiers', 'classification', 'neural', 'learning', 'deep', 'datasets', 'ensemble', 'deeprepviz']]
# 0.38172704072770003
# [['deception', 'deceiving', 'deceive', 'deceptive', 'deceptively', 'disinformation', 'linguistic', 'language', 'ai', 'detecting']]
# 0.47069736463108136
# [['autoencoders', 'autoencoder', 'encoder', 'quantization', 'decoder', 'softmax', 'coding', 'quantized', 'codebook', 'representations']]
# 0.40600723197971683
# [['imaging', 'deep', 'gans', 'telescope', 'iterative', 'regularization', 'astronomy', 'dnns', 'dnn', 'generative']]
# 0.30032796884247526
# [['intents', 'intent', 'automation', 'automate', 'automated', 'semantic', 'ai', 'orchestration', 'networks', 'network']]
# 0.4019008028492559
# [['interpretability', 'neural', 'ai', 'abstraction', 'neuron', 'intelligence', 'explanations', 'brain', 'cognition', 'neurons']]
# 0.46076911221408823
# [['networks', 'symmetries', 'neural', 'symmetry', 'neurons', 'metanetworks', 'scalegmn', 'representations', 'layers', 'permuted']]
# 0.414391893224651
# [['retrieval', 'intents', 'search', 'intent', 'queryner', 'relevance', 'queries', 'pagerank', 'ranking', 'matching']]
# 0.4529340718123721
# [['interpretability', 'explainability', 'interpretable', 'nlp', 'explanations', 'contextual', 'ai', 'explaining', 'text', 'syntaxshap']]
# 0.49539845159800294
# [['markets', 'agents', 'market', 'traders', 'agent', 'trading', 'trader', 'investors', 'liquidity', 'finance']]
# 0.5963072446684877
# [['networks', 'nodes', 'influence', 'graphs', 'influential', 'maximization', 'spreading', 'node', 'cascades', 'cascade']]
# 0.4109588480043974
# [['neural', 'neuron', 'neurons', 'networks', 'representations', 'deep', 'dnn', 'dnns', 'learning', 'backpropagation']]
# 0.6118603293735194
# [['ai', 'shapley', 'feature', 'shapg', 'shap', 'features', 'predictive', 'interpretability', 'explanations', 'generalizability']]
# 0.490142152093832
# [['ai', 'autonomous', 'autonomy', 'safety', 'automated', 'driving', 'prediction', 'vehicles', 'vehicle', 'assessment']]
# 0.6389189769506327
# [['multimodal', 'attention', 'taskbot', 'modality', 'multidialog', 'depression', 'modal', 'features', 'conversational', 'visual']]
# 0.3014062021694451
# [['adversarially', 'adversarial', 'explainers', 'explainability', 'explanations', 'interpretability', 'privacy', 'ai', 'evasion', 'security']]
# 0.35393670385899856
# [['forecasting', 'forecast', 'forecasts', 'prediction', 'bidding', 'schedulers', 'predictions', 'trading', 'markets', 'bids']]
# 0.4095944050389947
# [['generative', 'counterfactuals', 'counterfactual', 'images', 'causal', 'leveraging', 'causaldiffae', 'explanations', 'classifiers', 'inference']]
# 0.4274678552316189
# [['hypergraph', 'laplacian', 'graphs', 'manifolds', 'regularization', 'manifold', 'dimensionality', 'clustering', 'graphons', 'supervised']]
# 0.3554752962954072
# [['imputation', 'missingness', 'data', 'datasets', 'imputing', 'impute', 'missing', 'records', 'comprehensive', 'rows']]
# 0.40622403489164693
# [['bioinformatics', 'proteins', 'knowledgebase', 'molecular', 'protein', 'bio', 'molecule', 'biomedical', 'gene', 'enzyme']]
# 0.3834942326304288
# [['multilingual', 'multilinguality', 'monolingual', 'lingual', 'languages', 'language', 'linguistic', 'corpora', 'code', 'switching']]
# 0.4255834394254413
# [['classifiers', 'prediction', 'probabilistic', 'bayes', 'predictive', 'uncertainties', 'uncertainty', 'predictions', 'boosting', 'probabilities']]
# 0.5340284530643844
# [['generative', 'populations', 'census', 'generating', 'population', 'autoencoders', 'data', 'generation', 'samples', 'sample']]
# 0.4351991994112825
# [['deepinfomax', 'supervised', 'dimensionality', 'embedding', 'embeddings', 'regularization', 'dimensional', 'learning', 'representations', 'dimension']]
# 0.4939184762881859
# [['tensorization', 'tensors', 'tensorflow', 'tensor', 'tensorial', 'tensorkrowch', 'sparse', 'pytorch', 'decomposition', 'decompositions']]
# 0.33211816179013476
# [['autoencoders', 'autoencoder', 'embeddings', 'encoder', 'dimensionality', 'dimensional', 'manifolds', 'manifold', 'representations', 'descriptors']]
# 0.5633050877944189
# [['search', 'retrieval', 'crowdsourced', 'google', 'bing', 'snippets', 'bingchat', 'responses', 'relevance', 'generative']]
# 0.36050896874959476
# [['automata', 'neural', 'evolution', 'neuronal', 'evolved', 'developmental', 'morphogenesis', 'dynamics', 'automaton', 'cells']]
# 0.4244411829459346
# [['multimodal', 'modality', 'audio', 'videos', 'nonverbal', 'modal', 'recognition', 'fusionnets', 'supervised', 'decoder']]
# 0.4166515691377655
# [['storytelling', 'narratives', 'narrative', 'gameplay', 'procedural', 'storyline', 'rpgs', 'drama', 'characters', 'dialogue']]
# 0.4673868494322246
# [['relational', 'neural', 'relations', 'inference', 'embeddings', 'database', 'reasoning', 'gmpnn', 'algorithmic', 'logic']]
# 0.46720346537328833
# [['neural', 'cnns', 'tensorflow', 'networks', 'backpropagation', 'cvnn', 'cvnns', 'hypercomplex', 'deepshap', 'multidimensional']]
# 0.2957868801187956
# [['recommender', 'recommenders', 'explanations', 'ai', 'predictability', 'explainability', 'visualizations', 'personalised', 'suggesting', 'predictable']]
# 0.2752199138048618
# [['visualizations', 'visualization', 'charts', 'visual', 'interactive', 'colormaps', 'analytics', 'colormap', 'tools', 'bioinformatics']]
# 0.3659789779180024
# [['agricultural', 'agriculture', 'ai', 'farming', 'farmers', 'automating', 'gardening', 'crop', 'machinery', 'expertise']]
# 0.3956540207404325
# [['ontology', 'ontological', 'agents', 'owl', 'agent', 'semantics', 'services', 'netlogo', 'infrastructures', 'modelling']]
# 0.3283664784440192
# [['intelligencetest', 'intelligence', 'visual', 'abstraction', 'iq', 'attributes', 'learner', 'tasks', 'deductive', 'solvers']]
# 0.243861126276955
# [['orbit', 'orbiting', 'satellites', 'spacecraft', 'satellite', 'orbits', 'orbital', 'jupiter', 'prediction', 'asteroids']]
# 0.5527572287728576
# [['automated', 'willingness', 'technology', 'tools', 'collusion', 'detection', 'auditing', 'awareness', 'service', 'reviewers']]
# 0.31886372637282545
# [['analogical', 'analogies', 'analogy', 'abstraction', 'algebras', 'proportions', 'similarity', 'proportion', 'logic', 'reasoning']]
# 0.4241749418737138
# [['clustering', 'cluster', 'clusters', 'organizing', 'dataset', 'map', 'maps', 'visualization', 'soms', 'unsupervised']]
# 0.3720684933902553
# [['multimodal', 'mllm', 'mllms', 'textual', 'detection', 'toolkit', 'benchmarking', 'modal', 'empirically', 'lvlm']]
# 0.29313902882944276
# [['neural', 'neuron', 'hippocampal', 'hippocampus', 'autoencoders', 'neuroscience', 'neocortical', 'memory', 'synaptic', 'brain']]
# 0.4210796305285325
# [['uplift', 'coupon', 'coupons', 'promotion', 'roi', 'modeling', 'discounts', 'sales', 'revenue', 'marketing']]
# 0.3177311687806475
# [['neural', 'shape', '3d', 'shapes', 'deep', 'sensing', 'mechanics', 'rigid', 'dynamics', 'linearization']]
# 0.38531537088297907
# [['expertise', 'explanations', 'automated', 'experts', 'understandability', 'expert', 'prediction', 'information', 'interactive', 'predictions']]
# 0.47662533066475304
# [['bridge', 'autoencoder', 'generative', 'keras', 'tensorflow', 'pixelcnn', 'span', 'dataset', 'variational', 'arch']]
# 0.4377589015875352
#      Topic                                           Keywords  Coherence c_v
# 0        0  [hypergraph, subgraph, graphs, hypergraphs, gr...       0.574246
# 1        1  [federated, privacy, learning, datasets, colla...       0.573665
# 2        2  [graphs, subgraph, nodes, networks, graph, sub...       0.625583
# 3        3  [captioning, multimodal, embeddings, recogniti...       0.652074
# 4        4  [learns, reinforcement, robotic, robotics, rob...       0.690112
# ..     ...                                                ...            ...
# 308    308  [neural, neuron, hippocampal, hippocampus, aut...       0.421080
# 309    309  [uplift, coupon, coupons, promotion, roi, mode...       0.317731
# 310    310  [neural, shape, 3d, shapes, deep, sensing, mec...       0.385315
# 311    311  [expertise, explanations, automated, experts, ...       0.476625
# 312    312  [bridge, autoencoder, generative, keras, tenso...       0.437759
#
# [313 rows x 3 columns]

# %%
results.to_csv('First_Level_Second_Step_coherence.csv')

# %%
average_coherence_cv = results['Coherence c_v'].mean()
average_coherence_cv
# Out:
# 0.5132173039549905
