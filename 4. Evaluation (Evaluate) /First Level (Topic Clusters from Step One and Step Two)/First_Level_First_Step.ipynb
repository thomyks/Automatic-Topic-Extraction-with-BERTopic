# %% [markdown]
# # This notebook calculates topic diversity and topic coherence using tokenized documents
# # and topic representations from a topic modeling pipeline.
#
# ## Steps:
# 1. **Preprocessing the text data**:
#    - Loads the dataset and filters out outliers (topics labeled as -1).
#    - Preprocesses the text documents by removing stopwords and non-alphabetic tokens.
#
# 2. **Topic diversity calculation**:
#    - Groups the data by 'Topic Label' and extracts keywords from the 'First_Step_Topic_Keywords' column.
#    - Calculates topic diversity by computing the ratio of unique words to total words across all topics.
#
# 3. **Topic coherence calculation**:
#    - Uses the Gensim library to compute the c_v coherence score for each topic.
#    - Tokenized documents are used to create a Gensim dictionary.
#    - The c_v coherence score is calculated for each topic, and results are stored in a CSV file.
#
# 4. **Results output**:
#    - The results of the topic diversity and coherence calculations are displayed and saved to CSV files for further analysis.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load your dataset
file_path = 'First_Step_BERTopic_result.csv'  # Replace with your file path
data = pd.read_csv(file_path)

data_filtered = data[data['Topic Label'] != -1]

# Example: Assuming you have a separate list of documents
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

# Extract topics after filtering
topic_representations = data.groupby('Topic Label')['First_Step_Topic_Keywords'].apply(lambda x: x.iloc[0].split(', '))
topics = topic_representations.tolist()

# Calculate Topic Diversity
def calculate_topic_diversity(topics):
    unique_words = set()
    total_words = 0

    for topic in topics:
        unique_words.update(topic)  # Add words to the unique set
        total_words += len(topic)   # Count total words in all topics

    # Topic diversity is the proportion of unique words to total words
    topic_diversity = len(unique_words) / total_words
    return topic_diversity

# Calculate topic diversity
topic_diversity = calculate_topic_diversity(topics)

# Display the topic diversity score
print(f"\nTopic Diversity: {topic_diversity}")
# Out:
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /w0/tmp/slurm_yc656703.49701214/ipykernel_131374/881080332.py:12: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Topic Diversity: 0.5280534351145039

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load your dataset
file_path = 'First_Step_BERTopic_result.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Filter out outliers (-1 topic label)
data_filtered = data[data['Topic Label'] != -1]

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return tokens

# Preprocess the documents (optional, used if needed elsewhere)
documents = data['text']
processed_docs = [preprocess(doc) for doc in documents]

# Preprocess the topic keywords
def preprocess_keywords(keywords):
    return preprocess(' '.join(keywords.split(', ')))

# Extract and preprocess topic keywords
topic_representations = data_filtered.groupby('Topic Label')['First_Step_Topic_Keywords'].apply(lambda x: preprocess_keywords(x.iloc[0]))
topics = topic_representations.tolist()

# Adjusted Dieng's Topic Diversity calculation
def calculate_topic_diversity_dieng(topics):
    word_counts = {}
    total_words = 0

    # Count the occurrences of each word across all topics
    for topic in topics:
        for word in topic:
            word_counts[word] = word_counts.get(word, 0) + 1
        total_words += len(topic)  # Count total words in all topics

    # Handle case where no words are found
    if total_words == 0:
        return 0.0

    # Calculate number of unique words (words that occur exactly once)
    unique_words_count = sum(1 for count in word_counts.values() if count == 1)

    # Topic diversity is the proportion of unique words to total words
    topic_diversity = unique_words_count / total_words
    return topic_diversity

# Calculate topic diversity using Dieng's metric
topic_diversity = calculate_topic_diversity_dieng(topics)

# Display the topic diversity score
print(f"\nTopic Diversity (Dieng's Metric): {topic_diversity}")
# Out:
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /w0/tmp/slurm_yc656703.50280714/ipykernel_41628/3827056287.py:12: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
# Topic Diversity (Dieng's Metric): 0.3770364623739333

# %% [markdown]
# Topic Coherence

# %%
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
import pandas as pd

# Assuming 'processed_docs' is a list of tokenized documents
# Create a Gensim dictionary from the processed documents
dictionary = Dictionary(processed_docs)

# Initialize a list to store c_v coherence scores
per_topic_coherence_cv = []

for topic in topics:
    # Create a list containing just the current topic
    current_topic = [topic]
    
    print(current_topic)
    # print(processed_docs)
    # print(dictionary)
    
    # Initialize the CoherenceModel for the current topic using 'c_v'
    coherence_model_cv = CoherenceModel(topics=current_topic, texts=processed_docs, dictionary=dictionary, coherence='c_v')
    
    # Compute the c_v coherence score
    coherence_cv = coherence_model_cv.get_coherence()
    print(coherence_cv)
    # Append the c_v score to the list
    per_topic_coherence_cv.append(coherence_cv)
    
    

# Create a DataFrame to display the results
results = pd.DataFrame({
    "Topic": topic_ids,
    "Keywords": topic_representations.values,
    "Coherence c_v": per_topic_coherence_cv,
})


# Display overall and per-topic coherence scores
print(results)
results.to_csv('First_Level_First_Step_coherence.csv')
# Out:
# [['features', 'classification', 'learning', 'datasets', 'models', 'ai', 'networks', 'neural', 'trained', 'dataset']]
# 0.4223467978785219
# [['medical', 'clinical', 'patients', 'medicine', 'med', 'clinician', 'physician', 'doctor', 'annotated', 'physicians']]
# 0.6112921288535738
# [['recommender', 'recommenders', 'personalized', 'conversational', 'recommendation', 'recommendations', 'factorization', 'embeddings', 'attention', 'ranking']]
# 0.6114976209565052
# [['translations', 'translators', 'multilingual', 'lingual', 'translating', 'bilingual', 'translation', 'monolingual', 'translated', 'languages']]
# 0.7344624704245789
# [['robotic', 'robot', 'robotics', 'robots', 'grasping', 'manipulator', 'teleoperation', 'embodied', 'grasp', 'humanoid']]
# 0.7726833424143702
# [['cnn', 'segmentation', 'cnns', 'segmentations', 'segmenting', 'supervised', 'deep', 'convolutional', 'attention', 'ultrasound']]
# 0.616960762040347
# [['quantum', 'qubits', 'qubit', 'qcnns', 'qcnn', 'grover', 'entanglement', 'qnns', 'qiskit', 'qnn']]
# 0.6627869754452159
# [['adversarial', 'adversarially', 'adversary', 'attacks', 'attacker', 'adversaries', 'backdoors', 'defenses', 'classifiers', 'threats']]
# 0.7715141577284971
# [['agent', 'agents', 'planning', 'ai', 'planner', 'automation', 'planners', 'tasks', 'plans', 'autonomous']]
# 0.6533680155251687
# [['molecular', 'molecule', 'molecules', 'ligands', 'proteins', 'ligand', 'protein', 'receptor', 'modeling', 'models']]
# 0.7937834017245111
# [['reasoning', 'prompting', 'thinking', 'prompts', 'inference', 'deductive', 'prompt', 'tasks', 'knowledge', 'logic']]
# 0.5357633009907683
# [['compilers', 'programming', 'coding', 'compiler', 'code', 'programmers', 'snippets', 'developers', 'programmer', 'apis']]
# 0.6983573284345733
# [['causal', 'causality', 'causally', 'confounders', 'unobserved', 'inference', 'discovery', 'observational', 'data', 'inferring']]
# 0.6500965183087957
# [['retrieval', 'semantic', 'search', 'relevance', 'corpus', 'ranking', 'recall', 'retrieved', 'indexing', 'retrievers']]
# 0.6684916958849507
# [['multimodal', 'visual', 'captioning', 'mllm', 'modality', 'mllms', 'comprehension', 'textual', 'text', 'answering']]
# 0.8058222988468005
# [['forecasting', 'forecasts', 'forecast', 'lstm', 'prediction', 'predictive', 'seasonal', 'future', 'attention', 'models']]
# 0.6449859082629075
# [['highway', 'driving', 'autonomous', 'traffic', 'road', 'vehicles', 'lane', 'planning', 'vehicle', 'cars']]
# 0.8468056501453409
# [['optimizers', 'sgd', 'optimizer', 'gradient', 'gradients', 'adaptive', 'optimization', 'stochastic', 'adam', 'hessian']]
# 0.7992779257118536
# [['neural', 'networks', 'regularization', 'neurons', 'relu', 'gradient', 'resnets', 'layers', 'weights', 'approximation']]
# 0.5941759889865784
# [['reward', 'reinforcement', 'rewards', 'supervised', 'learning', 'trained', 'language', 'preference', 'ranking', 'sampling']]
# 0.5087237123210426
# [['transcription', 'voice', 'transcriptions', 'corpus', 'wav2vec', 'speech', 'asr', 'transcribed', 'wav2vec2', 'phonetic']]
# 0.8885102777582823
# [['bandit', 'bandits', 'optimal', 'regret', 'optimality', 'reward', 'rewards', 'exploration', 'exploitation', 'guarantees']]
# 0.7811604175304121
# [['pdes', 'pde', 'learning', 'neural', 'solvers', 'pinn', 'nonlinear', 'pinns', 'solver', 'networks']]
# 0.7459936960143085
# [['electroencephalogram', 'eeg', 'electroencephalography', 'bci', 'neural', 'eeg_glt', 'brain', 'bcis', 'fmri', 'electrode']]
# 0.7523286908688043
# [['forgetting', 'continual', 'learning', 'retention', 'learned', 'memory', 'forget', 'learn', 'continually', 'retaining']]
# 0.673970279694444
# [['privacy', 'private', 'privately', 'sgd', 'differentially', 'public', 'gradients', 'leakage', 'protection', 'algorithms']]
# 0.7040159897521896
# [['3d', 'scenes', 'scene', 'depth', 'viewpoints', 'generative', 'rendering', 'view', '3dgs', 'viewpoint']]
# 0.6906735140478054
# [['softmax', 'imagenet', 'classification', 'detection', 'accuracy', 'datasets', 'deep', 'ood', 'robust', 'neural']]
# 0.48874771485490703
# [['fairness', 'unfairness', 'discrimination', 'discriminatory', 'bias', 'unfair', 'biases', 'equalized', 'classifiers', 'classifier']]
# 0.7048316113674474
# [['anomaly', 'anomalies', 'anomalous', 'detections', 'detection', 'detecting', 'detect', 'autoencoders', 'supervised', 'unusual']]
# 0.6685259602582483
# [['musicgen', 'music', 'midi', 'musicrl', 'songs', 'musical', 'genres', 'musicians', 'melodies', 'composers']]
# 0.5387344174411897
# [['rnns', 'lstms', 'memory', 'softmax', 'attention', 'rnn', 'neural', 'recurrent', 'transformers', 'models']]
# 0.6340704715676831
# [['ai', 'accountability', 'ethics', 'ethical', 'intelligence', 'aia', 'governance', 'oversight', 'regulations', 'responsibility']]
# 0.7608572820679407
# [['graphs', 'subgraph', 'networks', 'subgraphs', 'graph', 'nodes', 'node', 'vertices', 'neural', 'edge']]
# 0.7816560217060975
# [['forecast', 'forecasts', 'forecasting', 'meteorological', 'weather', 'climate', 'ensembles', 'prediction', 'predictions', 'precipitation']]
# 0.8259894987604112
# [['spiking', 'neuron', 'neuromorphic', 'neurons', 'neural', 'neuronal', 'spike', 'dsnns', 'synapses', 'rsnns']]
# 0.654633666262397
# [['safety', 'reinforcement', 'unsafe', 'safely', 'safe', 'autonomous', 'control', 'learning', 'barrier', 'learned']]
# 0.6091339796054898
# [['citations', 'citing', 'citation', 'cited', 'cite', 'bibliometric', 'references', 'scholarly', 'attributions', 'researchers']]
# 0.5543414615297504
# [['federated', 'collaborative', 'learning', 'collaboratively', 'distributed', 'generalization', 'datasets', 'classifier', 'clients', 'sharing']]
# 0.5946986885538095
# [['optimizing', 'optimizer', 'optimization', 'optimisation', 'optimal', 'metaheuristics', 'objective', 'pareto', 'metaheuristic', 'objectives']]
# 0.5696836748133085
# [['particles', 'particle', 'collider', 'lhc', 'qcd', 'detectors', 'quarks', 'quark', 'detector', 'lhcb']]
# 0.6381506000433566
# [['crystals', 'crystal', 'crystalline', 'molecular', 'lattice', 'atoms', 'atom', 'alloys', 'predicting', 'molecules']]
# 0.7024563900832181
# [['finance', 'financial', 'textual', 'nlp', 'text', 'investors', 'investor', 'lexicon', 'accounting', 'investment']]
# 0.5405363112498722
# [['explainability', 'explanations', 'interpretability', 'ai', 'explainers', 'interpretable', 'explaining', 'explainer', 'predictive', 'predictors']]
# 0.6642873399186844
# [['dialogs', 'dialogue', 'dialogues', 'dialog', 'conversation', 'conversational', 'conversations', 'utterances', 'dialogstudio', 'utterance']]
# 0.705861117726036
# [['summarizers', 'summarizer', 'summarizing', 'summarization', 'summarisation', 'summaries', 'summary', 'sentences', 'transcripts', 'paragraph']]
# 0.5584607694927008
# [['cropland', 'sensed', 'imagery', 'land', 'satellite', 'crop', 'vegetation', 'cnn', 'earth', 'sensing']]
# 0.6895866670975983
# [['emotions', 'emotion', 'multimodal', 'emotional', 'utterances', 'conversations', 'dialogues', 'affective', 'contextual', 'arousal']]
# 0.6800291324263388
# [['courts', 'judicial', 'court', 'legalsemi', 'lawyers', 'lawyer', 'law', 'legalai', 'retrieval', 'jurisdiction']]
# 0.514933685227486
# [['offloading', 'vehicular', 'edge', 'congestion', 'scheduling', 'traffic', 'networks', 'vehicles', 'throughput', 'network']]
# 0.6880622579611668
# [['attention', 'generative', 'editing', 'images', 'scenes', 'text', 'guided', 'image', 'visual', 'scene']]
# 0.6261735391245027
# [['reinforcement', 'reward', 'rewards', 'learning', 'learned', 'exploration', 'learn', 'deepmind', 'tasks', 'rl']]
# 0.6479058503889641
# [['ecg', 'electrocardiogram', 'electrocardiograms', 'ecgs', 'arrhythmia', 'heartbeat', 'arrhythmias', 'electrocardiography', 'cardiac', 'recordings']]
# 0.7017498597344525
# [['activity', 'activities', 'wearable', 'sensing', 'tracking', 'fitness', 'pose', 'recognizing', 'recognition', 'datasets']]
# 0.5136737194212869
# [['hatecheck', 'hatred', 'hateful', 'offensiveness', 'hate', 'bullying', 'cyberbullying', 'profanity', 'dehumanization', 'speech']]
# 0.4376483672115544
# [['offline', 'reinforcement', 'learning', 'learned', 'reward', 'rewards', 'critic', 'exploration', 'imitation', 'learn']]
# 0.6885250892185519
# [['labeling', 'labeled', 'supervised', 'labels', 'label', 'classification', 'unlabelled', 'unlabeled', 'classifier', 'regularization']]
# 0.6932104520388933
# [['bias', 'biases', 'genders', 'gender', 'gendered', 'biased', 'stereotypes', 'languages', 'language', 'demographics']]
# 0.7629589428986705
# [['satisfiability', 'semantics', 'unsatisfiable', 'logics', 'propositional', 'solvers', 'logic', 'constraints', 'conjunctive', 'clauses']]
# 0.5353793977433765
# [['texts', 'text', 'autextification', 'ai', 'mixtext', 'paraphrasing', 'linguistic', 'gram2vec', 'writing', 'plagiarism']]
# 0.4559376125952475
# [['jailbreaks', 'jailbreaking', 'jailbreak', 'jailbreakbench', 'vulnerabilities', 'vulnerable', 'vulnerability', 'security', 'adversarial', 'attacks']]
# 0.8203853512032244
# [['loras', 'lora', 'tuning', 'rank', 'adapting', 'adaptation', 'lorahub', 'tuned', 'sparse', 'trained']]
# 0.3765269368406602
# [['traffic', 'spatiotemporal', 'transportation', 'networks', 'forecast', 'citynet', 'prediction', 'forecasting', 'predicting', 'congestion']]
# 0.5162708126158393
# [['communities', 'hypergraph', 'hypergraphs', 'subgraph', 'graphs', 'cluster', 'nodes', 'adjacency', 'clusters', 'clustering']]
# 0.4957322628202993
# [['radiology', 'radiological', 'radiologists', 'radiologist', 'radiologic', 'multimodal', 'textual', 'reporting', 'medical', 'diagnostic']]
# 0.7331700265864958
# [['predicting', 'sepsis', 'mortality', 'hospital', 'predict', 'prediction', 'cohorts', 'icu', 'biomarkers', 'healthcare']]
# 0.6989948010672535
# [['optimality', 'optimal', 'reinforcement', 'mdps', 'reward', 'mdp', 'complexity', 'markov', 'minimax', 'discount']]
# 0.7507090303251726
# [['quantization', 'quantizing', 'quantize', 'quantized', 'memory', 'compression', 'compressed', 'weights', 'compressing', 'bits']]
# 0.8829432114609507
# [['programming', 'tutoring', 'tutor', 'tutors', 'chatbots', 'learners', 'students', 'pedagogical', 'educational', 'student']]
# 0.8449142520384593
# [['hallucination', 'hallucinations', 'hallucinating', 'hallucinate', 'hallucinatory', 'hallucinated', 'decoding', 'annotator', 'text', 'halludial']]
# 0.5316573575900668
# [['convnets', 'cnn', 'imagenet', 'cnns', 'convnet', 'convolutions', 'attention', 'convolutional', 'vision', 'visual']]
# 0.5745485068794812
# [['optimizing', 'optimize', 'optimization', 'optimisation', 'optimal', 'hyperparameters', 'optimum', 'hyperparameter', 'algorithms', 'prior']]
# 0.520960827355841
# [['context', 'learning', 'icl', 'learn', 'retrieval', 'examples', 'example', 'ica', 'nlp', 'language']]
# 0.38381278149359294
# [['intrusions', 'intrusion', 'cybersecurity', 'iot', 'botnet', 'attacks', 'ddos', 'ids2018', 'security', 'attack']]
# 0.792871812446522
# [['routes', 'planning', 'metaheuristics', 'salesman', 'heuristics', 'optimization', 'metaheuristic', 'heuristic', 'learning', 'routing']]
# 0.5663128323771078
# [['galaxies', 'galactic', 'galaxy', 'astronomical', 'astronomy', 'astrophysical', 'cosmology', 'cosmic', 'cosmological', 'quasars']]
# 0.6164989348974222
# [['backdoors', 'adversarial', 'backdoor', 'attacks', 'vulnerabilities', 'malicious', 'security', 'vulnerability', 'backdoored', 'anydoor']]
# 0.7616491963132136
# [['semantic', 'knowledge', 'relational', 'entities', 'embeddings', 'subgraph', 'entity', 'completion', 'relations', 'kgexplainer']]
# 0.5300703243609122
# [['prediction', 'conformity', 'conformalized', 'conformal', 'predictions', 'predictors', 'predictive', 'predictor', 'classification', 'regression']]
# 0.5971034137958351
# [['quantization', 'quantizing', 'quantized', 'quantize', 'quanvolutional', 'imagenet', 'cnns', 'bits', 'fpgas', 'compression']]
# 0.627584538095518
# [['pruning', 'cnn', 'prune', 'pruned', 'cnns', 'imagenet', 'rnns', 'networks', 'neural', 'deep']]
# 0.5363004722063109
# [['datasets', 'dataset', 'tables', 'tabular', 'table', 'learning', 'tabpfn', 'neural', 'features', 'data']]
# 0.49882700189421686
# [['vulnerabilities', 'vulnerability', 'vulnerable', 'developers', 'security', 'fuzzing', 'bugs', 'code', 'programming', 'malicious']]
# 0.6769002833918036
# [['consciousness', 'conscious', 'cognition', 'ai', 'brain', 'cognitive', 'philosophical', 'artificial', 'neuroscience', 'intelligence']]
# 0.6863760525579437
# [['adversarial', 'adaptation', 'supervised', 'domainnet', 'learn', 'features', 'feature', 'classification', 'training', 'regularization']]
# 0.41396984531799197
# [['flow', 'flows', 'generative', 'modeling', 'perflow', 'diffusion', 'sde', 'denoising', 'stochastic', 'unnormalized']]
# 0.5327476426459047
# [['activelab', 'supervised', 'activellm', 'classification', 'annotators', 'annotations', 'annotation', 'annotate', 'labeled', 'learning']]
# 0.4583111130048202
# [['videos', 'captioning', 'captions', 'vid', 'textual', 'videoqa', 'videotree', 'video', 'clips', 'multimodal']]
# 0.4907389391374847
# [['relations', 'relation', 'entities', 'entity', 'relational', 'semantic', 'textual', 'supervised', 'annotated', 'tagging']]
# 0.6595563160864055
# [['crop', 'agriculture', 'agricultural', 'crops', 'cnn', 'farming', 'images', 'livestock', 'vision', 'image']]
# 0.6504860292807073
# [['editing', 'editor', 'editors', 'edits', 'modifying', 'modify', 'edit', 'retraining', 'edited', 'forgetting']]
# 0.6274119957370472
# [['credibility', 'factagent', 'news', 'disinformation', 'tweets', 'veracity', 'journalists', 'hoax', 'content', 'debunking']]
# 0.3627687604290444
# [['auction', 'bidding', 'auctions', 'bids', 'bid', 'bidders', 'bandit', 'optimal', 'pricing', 'bidder']]
# 0.9089444750757527
# [['models', 'knowledge', 'trained', 'training', 'teacher', 'students', 'distillation', 'teachers', 'distilling', 'model']]
# 0.5817300565083517
# [['clusterings', 'clustering', 'cluster', 'clusters', 'clustered', 'dbscan', 'algorithms', 'algorithm', 'hpclust', 'unsupervised']]
# 0.594159279539581
# [['mri', 'imaging', 'denoising', 'tomography', 'reconstructed', 'undersampled', 'undersampling', 'deep', 'reconstruction', 'reconstructions']]
# 0.7330513535308316
# [['unlearning', 'privacy', 'adversary', 'obfuscation', 'security', 'attacks', 'attacker', 'defenses', 'adversaries', 'trained']]
# 0.6977096626790379
# [['forecasting', 'lstm', 'stocks', 'predicting', 'stock', 'investing', 'prediction', 'stockformer', 'predict', 'stockgpt']]
# 0.4491831866353751
# [['ensembles', 'treeshap', 'ensemble', 'boosting', 'forests', 'forest', 'trees', 'classification', 'tree', 'metatree']]
# 0.628391029947728
# [['microgrid', 'renewable', 'scheduling', 'reinforcement', 'electricity', 'ev', 'energy', 'discharging', 'hvac', 'agent']]
# 0.5652025109115316
# [['faults', 'fault', 'detect', 'feature', 'detection', 'features', 'monitoring', 'machinery', 'wavelet', 'machines']]
# 0.546433863511224
# [['soccernet', 'esports', 'sports', 'soccer', 'sport', 'athletes', 'soccerrag', 'players', 'athlete', 'matches']]
# 0.4462934151292318
# [['topological', 'topologically', 'topology', 'homeomorphic', 'networks', 'manifolds', 'homology', 'classification', 'graphcodes', 'neural']]
# 0.5018188252902963
# [['gans', 'gan', 'generative', 'adversarial', 'flowgan', 'codegan', 'cgan', 'cyclegan', 'stylegan', 'inception']]
# 0.5344145761448416
# [['instruction', 'language', 'instructmining', 'texttuning', 'tuning', 'training', 'tuned', 'curriculum', 'benchmarks', 'tasks']]
# 0.3963376707930876
# [['graphllm', 'graphprompter', 'graphs', 'embeddings', 'textual', 'nodes', 'graph', 'networks', 'supervised', 'node']]
# 0.4621917912564776
# [['confidence', 'confident', 'reliable', 'language', 'verbalized', 'reliability', 'models', 'uncertainties', 'prediction', 'semantic']]
# 0.4133555090371696
# [['channels', 'channel', 'decoding', 'decoders', 'mimo', 'decoder', 'multiplexing', 'communications', 'wireless', 'receiver']]
# 0.6483676167180767
# [['symbolic', 'ai', 'neural', 'neuro', 'symbols', 'neurosymbolic', 'semantic', 'semantics', 'knowledge', 'deductive']]
# 0.4131604471584165
# [['cybersecurity', 'cyberattacks', 'cyberattack', 'cybercrime', 'llm4security', 'security', 'malware', 'cybermetric', 'threats', 'phishing']]
# 0.5406850108869159
# [['creativity', 'creative', 'generative', 'ai', 'ideation', 'storymaking', 'creation', 'creators', 'generated', 'writers']]
# 0.47008958072280516
# [['turbulent', 'flows', 'turbulence', 'flow', 'aerodynamic', 'reynolds', 'vortex', 'stokes', 'vorticity', 'fluids']]
# 0.5925270261275977
# [['nl2sql', 'database', 'sql', 'databases', 'querying', 'sqlfuse', 'queries', 'schemas', 'metasql', 'schema']]
# 0.6390606633259198
# [['imagenet', 'recognition', 'clips', 'descriptors', 'classification', 'visual', 'trained', 'features', 'learnable', 'datasets']]
# 0.4410007712226743
# [['safety', 'unsafe', 'safepatching', 'safeguards', 'safeguarding', 'safeguard', 'harmfulness', 'safe', 'malicious', 'risks']]
# 0.6897912211195378
# [['drafts', 'draft', 'speculative', 'decoding', 'memory', 'drafter', 'drafters', 'drafting', 'language', 'speedups']]
# 0.6232880606592441
# [['embeddings', 'textual', 'nlp', 'similarity', 'embedding', 'semantic', 'word2vec', 'sentences', 'fasttext', 'similarities']]
# 0.5975453162580949
# [['adversarial', 'backdoors', 'backdoor', 'attacks', 'networks', 'vulnerabilities', 'graphs', 'graphmu', 'gnns', 'adversary']]
# 0.5261265507125384
# [['proofnet', 'formalizations', 'provers', 'prover', 'deductive', 'formalization', 'formalized', 'verifiable', 'proofs', 'solvers']]
# 0.4396932047752184
# [['solvers', 'symbolic', 'regression', 'expressions', 'formulas', 'formulagpt', 'variables', 'neural', 'discovering', 'mathematical']]
# 0.47040014925045226
# [['bound', 'generalization', 'bounds', 'learning', 'optimal', 'learnability', 'learnable', 'bayes', 'complexity', 'compression']]
# 0.4607879155441944
# [['explanations', 'networks', 'explainers', 'attention', 'subgraph', 'explainability', 'graphs', 'explaining', 'neural', 'explainer']]
# 0.6011411215889988
# [['denoising', 'inverse', 'inverses', 'diffusion', 'regularization', 'inversion', 'denoiser', 'regularisation', 'iterative', 'priors']]
# 0.4520872904694394
# [['annotations', 'annotation', 'entities', 'entity', 'annotated', 'nlp', 'corpus', 'labeling', 'supervised', 'sentences']]
# 0.6884720859108244
# [['lidar', 'lidars', 'laser', 'radar', 'lasermix', 'fusion', '3d', 'deepipcv2', 'detection', 'clouds']]
# 0.5044845212165305
# [['wifi', 'fingerprinting', 'gps', 'wi', 'wireless', 'fingerprint', 'localization', 'ranging', 'sensing', 'indoor']]
# 0.43905303785315264
# [['assessment', 'assessments', 'educational', 'education', 'academic', 'ai', 'academia', 'pedagogical', 'students', 'educators']]
# 0.7686938437282306
# [['veracity', 'factuality', 'factdetect', 'credibility', 'evidence', 'factscore', 'corpus', 'semantic', 'claims', 'factual']]
# 0.44725332363977977
# [['hallucinations', 'hallucination', 'hallucinate', 'hallucinatory', 'hallucinated', 'multimodal', 'hallusionbench', 'captioning', 'lvlm', 'visual']]
# 0.6011779748161976
# [['alzheimer', 'dementia', 'neurodegenerative', 'neuroimaging', 'neurodegeneration', 'mri', 'amyloid', 'predicting', 'fmri', 'mris']]
# 0.646129768638844
# [['aspects', 'aspect', 'sentiment', 'sentiments', 'annotated', 'sentences', 'parsing', 'syntactic', 'attention', 'insightnet']]
# 0.5068876718955344
# [['adversarial', 'fedsecurity', 'adversary', 'datadefense', 'feddefender', 'malicious', 'attacks', 'federated', 'aggregators', 'adversaries']]
# 0.47369434554294526
# [['parsers', 'treebanks', 'treebank', 'parsing', 'parser', 'parses', 'parse', 'syntactic', 'corpus', 'grammars']]
# 0.7289626535043248
# [['circuits', 'circuitsynth', 'analogcoder', 'circuitvae', 'hardware', 'circuit', 'analog', 'chip', 'transistor', 'engineers']]
# 0.5195583332361184
# [['privacy', 'federated', 'private', 'distributed', 'decentralized', 'sharing', 'security', 'secret', 'cryptographic', 'secure']]
# 0.8588175011649094
# [['memory', 'attention', 'cachegen', 'caches', 'cache', 'caching', 'bottlenecks', 'cacheblend', 'bottleneck', 'decoding']]
# 0.46756357455866304
# [['tutoring', 'students', 'learners', 'tracing', 'learning', 'student', 'knowledge', 'assessment', 'classroom', 'learner']]
# 0.5968231820823657
# [['ontologies', 'ontology', 'ontological', 'semantic', 'ontologically', 'owl', 'rdf', 'owl2vec', 'entities', 'semantically']]
# 0.6079029493316938
# [['topics', 'topicgpt', 'topic', 'topical', 'contextualized', 'embeddings', 'corpus', 'semantic', 'keywords', 'unsupervised']]
# 0.4384165817847491
# [['reservoir', 'reservoirs', 'neural', 'rnn', 'lstm', 'chaotic', 'forecasting', 'predicting', 'computing', 'memory']]
# 0.6491312721648891
# [['classifiers', 'classifier', 'classification', 'classifications', 'imbalance', 'imbalanced', 'svm', 'roc', 'accuracy', 'classes']]
# 0.6354257866274998
# [['prompts', 'prompt', 'prompting', 'promptwizard', 'language', 'automatic', 'feedback', 'instruction', 'tasks', 'examples']]
# 0.5511261102601359
# [['pruning', 'pruningbench', 'pruner', 'prune', 'pruned', 'compression', 'sparse', 'sparsegpt', 'compressing', 'efficient']]
# 0.44198588156174196
# [['events', 'event', 'annotations', 'annotation', 'corpus', 'annotated', 'entity', 'extracting', 'triggers', 'coreference']]
# 0.5767300839760601
# [['equivariance', 'symmetries', 'equivariant', 'invariance', 'invariants', 'symmetry', 'representations', 'cnns', 'convolutions', 'neural']]
# 0.6455300508350598
# [['contexts', 'attention', 'lengthy', 'context', 'embedding', 'memory', 'positional', 'position', 'positions', 'longer']]
# 0.5684218044743387
# [['priors', 'bayesian', 'posteriors', 'bayes', 'neural', 'posterior', 'deep', 'prior', 'likelihood', 'inference']]
# 0.6708166842521258
# [['anonymization', 'spoofing', 'hiddenspeaker', 'anonymized', 'adversarial', 'voice', 'spoof', 'spoofed', 'speaker', 'audioseal']]
# 0.28612561069300424
# [['diffusionmtl', 'denoising', 'diffusion', 'generative', 'models', 'noisy', 'training', 'imagenet', 'noise', 'dtr']]
# 0.4101916534265041
# [['distributed', 'compression', 'optimization', 'sgd', 'minimizer', 'compressed', 'gradient', 'bottleneck', 'gradients', 'optimal']]
# 0.5586643610024308
# [['imitation', 'reinforcement', 'mimic', 'demonstrations', 'imitate', 'learning', 'adversarial', 'cloning', 'reward', 'learned']]
# 0.6511914981533014
# [['games', 'gameplay', 'chess', 'ai', 'game', 'strategy', 'gaming', 'poker', 'hearthstone', 'play']]
# 0.52306741717846
# [['adversarial', 'adversary', 'adversaries', 'malicious', 'attacks', 'vulnerabilities', 'attacking', 'threat', 'attack', 'vulnerability']]
# 0.9111207165026072
# [['signwriting', 'gestures', 'gesture', 'signbank', 'sign', 'signllm', 'signcl', 'signclip', 'signers', 'signing']]
# 0.3954503687081809
# [['watermarking', 'watermark', 'watermarked', 'watermarks', 'postmark', 'text', 'steganographic', 'tokens', 'steganography', 'embedding']]
# 0.6566224500025715
# [['wasserstein', 'metrics', 'distances', 'metric', 'distance', 'measures', 'gaussian', 'distributions', 'optimal', 'embedding']]
# 0.609271702898887
# [['optimal', 'optimization', 'bandit', 'minimize', 'convex', 'minimization', 'adversary', 'convexity', 'regret', 'guarantees']]
# 0.6900903040575823
# [['counterfactuals', 'counterfactual', 'explanations', 'classifier', 'robustness', 'explaining', 'interpretable', 'predictions', 'robust', 'algorithmic']]
# 0.5277108843769185
# [['raman', 'spectroscopy', 'microscopy', 'nanoscale', 'microscope', 'spectroscopic', 'nanostructures', 'optical', 'optics', 'imaging']]
# 0.30656353478669696
# [['privacy', 'anonymization', 'privacyrestore', 'anonymized', 'anonymisation', 'disclosures', 'security', 'obfuscation', 'disclosure', 'incognitext']]
# 0.26405335189167
# [['multimodal', 'modality', 'modal', 'supervised', 'unlearning', 'embeddings', 'unimodal', 'modalities', 'learning', 'learnt']]
# 0.46427023211702023
# [['faces', 'facial', 'face', 'recognition', 'classifiers', 'biometrics', 'biometric', 'generative', 'siamese', 'classifier']]
# 0.4217770344281696
# [['causalbench', 'causal', 'causality', 'causalnlp', 'reasoning', 'inference', 'knowledge', 'relational', 'counterfactual', 'entailment']]
# 0.35822273645781577
# [['networks', 'graphs', 'nodes', 'rnns', 'graph', 'temporal', 'rnn', 'node', 'prediction', 'embeddings']]
# 0.607801266790315
# [['empathy', 'empatheticdialogues', 'empathicstories', 'empathetic', 'empathic', 'conversations', 'empathically', 'dialogue', 'conversation', 'emotionbench']]
# 0.5663600965420953
# [['sparse', 'expert', 'experts', 'moe', 'models', 'specialization', 'sparsely', 'moerging', 'training', 'moes']]
# 0.4636714034969218
# [['scaling', 'models', 'smaller', 'scale', 'autoscale', 'larger', 'predicting', 'performance', 'predictable', 'language']]
# 0.39233297588989646
# [['imagenet', 'neural', 'rnn', 'supernet', 'architecture', 'architectures', 'nas', 'searching', 'networks', 'architectural']]
# 0.6121624916700111
# [['subgraph', 'hypergraph', 'graphs', 'graphmae', 'graphacl', 'graphlearner', 'hypergraphs', 'embeddings', 'graph', 'supervised']]
# 0.33107622796809344
# [['personality', 'personalities', 'traits', 'trait', 'profiles', 'conversational', 'personas', 'profile', 'extraversion', 'psychometrics']]
# 0.5487136769742633
# [['photonics', 'photonic', 'optical', 'nanophotonic', 'optics', 'multiplexing', 'laser', 'wavelength', 'waveguide', 'throughput']]
# 0.5116793474477429
# [['sentiment', 'nlp', 'sentiments', 'sentiment140', 'sentimentality', 'subjectivity', 'tweets', 'texts', 'microblog', 'text']]
# 0.49432109471668567
# [['verilog', 'programmable', 'programming', 'hardware', 'verilogeval', 'generate', 'tools', 'automation', 'vhdl', 'veribug']]
# 0.4886646416226684
# [['actions', 'action', 'multimodal', 'activities', 'videos', 'activity', 'recognition', 'features', 'cnn', 'motion']]
# 0.500908246161385
# [['counseling', 'psychotherapeutic', 'conversations', 'counselor', 'psychotherapists', 'dialogue', 'counselors', 'dialogues', 'conversational', 'interventions']]
# 0.5683919357992705
# [['privacy', 'federated', 'datasets', 'learning', 'personalized', 'distributed', 'sharing', 'data', 'collaborative', 'healthcare']]
# 0.6072809314050974
# [['retina', 'retinal', 'macular', 'retinopathy', 'ophthalmologists', 'ophthalmology', 'ocular', 'blindness', 'glaucoma', 'supervised']]
# 0.572110339663614
# [['reinforcement', 'agents', 'agent', 'learning', 'rewards', 'multiagent', 'reward', 'starcraft', 'cooperation', 'exploration']]
# 0.7225727058446456
# [['captioning', 'captions', 'caption', 'multimodal', 'alttexts', 'visual', 'coco', 'descriptions', 'images', 'nlg']]
# 0.562206965497792
# [['malware', 'adversarial', 'malicious', 'ransomware', 'antivirus', 'classifiers', 'classifier', 'cybersecurity', 'executable', 'obfuscation']]
# 0.5312009433750962
# [['unlearning', 'ununlearning', 'unlearn', 'memorization', 'forgetting', 'memorize', 'memorized', 'unlearned', 'corpus', 'forget']]
# 0.6337434962743475
# [['ocr', 'handwriting', 'handwritten', 'recognition', 'text', 'inscriptions', 'locr', 'manuscripts', 'marksheet', 'documents']]
# 0.43227850144332847
# [['audioset', 'captioning', 'captions', 'audiocaps', 'caption', 'audio', 'voice', 'audios', 'speech', 'clips']]
# 0.4665464309482594
# [['temporal', 'timelines', 'answering', 'timebench', 'timeline', 'reasoning', 'timeml', 'knowledge', 'questions', 'answers']]
# 0.22720806868703242
# [['forecasting', 'forecast', 'forecasts', 'prediction', 'electricity', 'microgrids', 'microgrid', 'demand', 'appliance', 'renewable']]
# 0.5565484362655315
# [['tables', 'tablellm', 'table', 'tableinstruct', 'tabular', 'texttableqa', 'sql', 'spreadsheets', 'queries', 'spreadsheetbench']]
# 0.4133576682758641
# [['arabic', 'arabicaqa', 'arab', 'arablegaleval', 'language', 'wordnet', 'moroccan', 'persian', 'arabiangpt', 'corpus']]
# 0.36038475050821195
# [['argumentation', 'argumentative', 'arguments', 'debates', 'debater', 'annotators', 'annotations', 'argument', 'debate', 'annotation']]
# 0.46631406637538986
# [['optimal', 'reinforcement', 'games', 'equilibrium', 'equilibria', 'nash', 'markov', 'agents', 'game', 'complexity']]
# 0.7411925198472675
# [['blockchain', 'cryptocurrencies', 'bitcoin', 'ethereum', 'fraud', 'frauds', 'cryptocurrency', 'ponzi', 'vulnerabilities', 'phishing']]
# 0.5405864951313749
# [['retrieval', 'nearest', 'search', 'locality', 'indexing', 'similarity', 'embeddings', 'hashing', 'algorithms', 'indexes']]
# 0.5657306682384216
# [['elasticity', 'deformation', 'elastic', 'microstructures', 'neural', 'multiscale', 'microstructure', 'mechanical', 'microscale', 'mechanics']]
# 0.6864534189398218
# [['robot', 'robots', 'robotic', 'robotics', 'humanoid', 'interactive', 'cobots', 'gestures', 'conversations', 'cobot']]
# 0.5901795634002485
# [['attributes', 'products', 'advertisements', 'attribute', 'commerce', 'product', 'items', 'retailers', 'marketplaces', 'shopping']]
# 0.41887626901222524
# [['anomaly', 'anomalyllm', 'outliers', 'outlier', 'graphs', 'anomalies', 'anomalous', 'graph', 'nodes', 'detecting']]
# 0.5802790124339093
# [['neural', 'networks', 'computability', 'deepinfer', 'neuralsat', 'robustness', 'neurons', 'dnns', 'dnn', 'deep']]
# 0.445480921791226
# [['vision', 'driving', 'lanesegnet', 'trafficvlm', 'vehicles', 'cameras', 'camera', 'vehicle', 'hdmaps', 'road']]
# 0.42144749667041814
# [['regularization', 'regularized', 'sparse', 'factorization', 'matrix', 'completion', 'matrices', 'overparameterization', 'minimization', 'rank']]
# 0.6747395735504244
# [['emissions', 'carbon', 'energy', 'co2', 'efficiency', 'efficient', 'models', 'emission', 'environmentally', 'footprint']]
# 0.6126451898944203
# [['locomotion', 'stepping', 'terrain', 'legged', 'robotics', 'walking', 'jumps', 'terrains', 'jumping', 'robotic']]
# 0.5919663865694995
# [['tensors', 'tensor', 'kronecker', 'factorization', 'tucker', 'multilinear', 'multidimensional', 'decompositions', 'decomposition', 'dimensional']]
# 0.5734741851343992
# [['pose', 'poses', '3d', 'camera', '3dhp', 'cameras', 'posture', '3dsp', 'human3', 'dor3d']]
# 0.5294703887903952
# [['transport', 'regularization', 'transportation', 'optimal', 'optimization', 'regularized', 'distributions', 'maps', 'divergence', 'densities']]
# 0.5277400309038996
# [['powerflownet', 'powerflowmultinet', 'networks', 'powergraph', 'grid', 'safepowergraph', 'grids', 'flow', 'blackout', 'optimal']]
# 0.41186885852530863
# [['ai', 'healthcare', 'medical', 'biomedical', 'medicine', 'med', 'clinical', 'trustworthy', 'patients', 'mllms']]
# 0.5345003793694854
# [['learning', 'learned', 'training', 'learn', 'learners', 'overfitting', 'regularization', 'learner', 'meta', 'multitask']]
# 0.41319165562308147
# [['transcriptomics', 'transcriptomic', 'transcriptome', 'rna', 'bioinformatics', 'cell', 'cells', 'gene', 'genes', 'cellular']]
# 0.8387590972524788
# [['pathfinding', 'agents', 'planning', 'agent', 'paths', 'planner', 'robots', 'algorithms', 'robotics', 'robot']]
# 0.6393525939364707
# [['unlearning', 'federated', 'privacy', 'learning', 'unlearned', 'distributed', 'disclosure', 'collaborative', 'private', 'decentralized']]
# 0.5523161009765077
# [['multimodal', 'recommender', 'embeddings', 'modality', 'personalized', 'modal', 'recommendation', 'recommendations', 'collaborative', 'features']]
# 0.6085212903017706
# [['blockchain', 'blockchains', 'blockchained', 'mainchain', 'federated', 'ledger', 'decentralized', 'privacy', 'ipfs', 'security']]
# 0.6246674683208252
# [['biases', 'bias', 'genderbias', 'stereotypes', 'biaspainter', 'stereotype', 'debiasing', 'demographic', 'counterfactual', 'stereotyped']]
# 0.5933892506619248
# [['kalmannet', 'kalman', 'filtering', 'estimation', 'bayesian', 'filter', 'state', 'probabilistic', 'gpssm', 'states']]
# 0.4089101651288603
# [['trading', 'portfolio', 'portfolios', 'learning', 'stocks', 'investment', 'finance', 'agents', 'markets', 'arbitrage']]
# 0.7003531267146391
# [['depressive', 'depression', 'tweets', 'twitter', 'cnn', 'nlp', 'depressed', 'facebook', 'suicide', 'lstm']]
# 0.44138597324505546
# [['homomorphic', 'homomorphically', 'privacy', 'encryption', 'cryptographic', 'cryptonets', 'encrypted', 'confidentiality', 'confidential', 'secure']]
# 0.8597410156401916
# [['parallelization', 'unifiednn', 'distributed', 'throughput', 'bottleneck', 'cloud', 'streaming', 'memory', 'network', 'deep']]
# 0.3985108302424479
# [['attention', 'scene', 'visual', 'memory', 'semantic', 'mpnn', 'features', 'videos', 'objects', 'segmentation']]
# 0.4713173427958989
# [['ssl', 'ssl4ns', 'supervised', 'imagenet', 'learning', 'memorization', 'ssfa', 'encoders', 'learned', 'regularization']]
# 0.3498120018961417
# [['sarcasm', 'sarcastic', 'emoticons', 'sentiment', 'humor', 'irony', 'multimodal', 'emojis', 'text', 'modality']]
# 0.4920310071894054
# [['imputations', 'imputation', 'missingness', 'imputing', 'imputed', 'completion', 'missforestpredict', 'datasets', 'imputes', 'impute']]
# 0.500894671632618
# [['chartmimic', 'charts', 'visualizations', 'visual', 'chartformer', 'chart', 'chartcheck', 'visualization', 'chartqa', 'flowcharts']]
# 0.5208998229188258
# [['survival', 'predicting', 'prediction', 'predict', 'coxtime', 'predictive', 'cox', 'hazards', 'outcomes', 'survmixclust']]
# 0.5952272446458268
# [['gans', 'gan', 'generative', 'cyclegan', 'imaging', 'mri', 'echogan', 'segmentation', 'tomography', 'adversarial']]
# 0.5706965409434408
# [['concepts', 'cnn', 'imagenet', 'cnns', 'neural', 'concept', 'explainability', 'explanations', 'classification', 'interpretability']]
# 0.5215527024351487
# [['multitask', 'merging', 'merge', 'combine', 'taskonomy', 'tasking', 'models', 'merged', 'tasks', 'task']]
# 0.3414837367257132
# [['tools', 'toolkits', 'toollens', 'toolsets', 'tool', 'toolflow', 'toolnet', 'toolbench', 'toolset', 'toolname']]
# 0.33358872345863455
# [['epidemics', 'epidemic', 'outbreak', 'pandemics', 'pandemic', 'outbreaks', 'influenza', 'covid', 'infectious', 'pandemicllm']]
# 0.5825681719224085
# [['processes', 'process', 'bpm', 'mining', 'analytics', 'discovering', 'activity', 'discovery', 'activities', 'manufacturing']]
# 0.3898872815680228
# [['videos', 'recognition', 'surgicalpart', 'pose', 'surgeons', 'laparoscopic', 'neurosurgical', 'camera', 'vision', 'intraoperative']]
# 0.3310141724343769
# [['stances', 'stance', 'annotators', 'annotation', 'sentiment', 'semantics', 'annotated', 'contextual', 'tweets', 'bias']]
# 0.549727256926442
# [['deformation', 'deforming', 'registration', 'pose', 'deformations', 'registrations', 'imaging', 'deformable', 'images', 'anatomy']]
# 0.5038104775461494
# [['adversarial', 'privacy', 'datasets', 'generative', 'gans', 'anonymization', 'data', 'anonymized', 'gan', 'synthetic']]
# 0.662676860664537
# [['phishing', 'spam', 'cybersecurity', 'emails', 'malicious', 'phisnet', 'threats', 'phishlang', 'security', 'attackers']]
# 0.6308154738139994
# [['videos', 'videopoet', 'videoscore', 'videodrafter', 'videofeedback', 'scenes', 'videodirectorgpt', 'magicvideo', 'generative', 'video']]
# 0.4973322839902575
# [['adversarial', 'captioner', 'multimodal', 'captioning', 'embeddings', 'captions', 'visual', 'adversary', 'vulnerabilities', 'attacking']]
# 0.31652430710774654
# [['fmri', 'neuroimaging', 'networks', 'brain', 'connectome', 'connectivity', 'hippocampal', 'hippocampus', 'functional', 'embedding']]
# 0.6044928425128979
# [['kernels', 'regularization', 'kernel', 'ridge', 'regularized', 'ridgeless', 'generalization', 'generalized', 'optimal', 'overfitting']]
# 0.6456837413921895
# [['minds', 'mentalizing', 'mind', 'reasoning', 'cognition', 'mental', 'inferences', 'language', 'belief', 'think']]
# 0.6099832909146018
# [['trajectories', 'mobilitygpt', 'gps', 'mobility', 'trips', 'trajcl', 'trajectory', 'travel', 'trip', 'planning']]
# 0.6170343119669786
# [['reinforcement', 'rewards', 'learning', 'reward', 'optimal', 'mdps', 'optimization', 'approximation', 'policies', 'gradient']]
# 0.6705630433183354
# [['reinforcement', 'sepsis', 'interventions', 'adaptive', 'reward', 'medication', 'cpr', 'medications', 'policies', 'outcomes']]
# 0.328186407629567
# [['fairness', 'unfairness', 'recommender', 'unfair', 'biases', 'discrimination', 'incentives', 'rankings', 'personalization', 'equitable']]
# 0.4883791806180054
# [['semantic', 'parsing', 'sparql', 'knowledge', 'answering', 'retrieval', 'parse', 'answerability', 'unanswerability', 'schemas']]
# 0.37968945699382206
# [['compression', 'encoder', 'encoding', 'compressing', 'compressed', 'decoding', 'decoder', 'bitrate', 'coding', 'jpeg']]
# 0.5811759663822725
# [['cnn', 'cnns', 'defects', 'features', 'feature', 'defect', 'inspection', 'classification', 'visual', 'yolov5']]
# 0.6108960451515025
# [['documentation', 'datasets', 'dataset', 'researchers', 'developers', 'categories', 'repositories', 'frameworks', 'tools', 'guidelines']]
# 0.5110497512230671
# [['adapting', 'adaptation', 'tta', 'test', 'batches', 'batch', 'cta', 'memory', 'drift', 'ctta']]
# 0.36819036950757583
# [['perceptrons', 'neural', 'networks', 'imagenet1k', 'neurons', 'perceptron', 'kolmogorov', 'learnable', 'convolutional', 'fcnns']]
# 0.4832063232241686
# [['spingnn', 'spin', 'ferromagnetic', 'isingnets', 'magnetization', 'boltzmann', 'lattice', 'magnetic', 'neural', 'networks']]
# 0.3753374743967759
# [['decoders', 'digits', 'transformers', 'encodings', 'rnns', 'turing', 'digit', 'decoder', 'addition', 'transformer']]
# 0.2922160279024998
# [['deepfake', 'deepfakes', 'multimodal', 'faceforensics', 'detecting', 'detection', 'embedders', 'dataset', 'datasets', 'faces']]
# 0.47758222319215654
# [['wireless', 'decoding', 'transmit', 'bandwidth', 'channels', 'channel', 'broadcast', 'modulation', 'aircomp', 'quantization']]
# 0.691182222255112
# [['hydrological', 'hydrology', 'hydrologic', 'flooding', 'floods', 'forecasting', 'runoff', 'flood', 'catchment', 'catchments']]
# 0.591047521769017
# [['conversational', 'retrieval', 'conversations', 'conversation', 'searchers', 'search', 'dialogue', 'queries', 'chat', 'seeking']]
# 0.5594987625468253
# [['supervised', 'segmentation', 'segmenting', 'classifier', 'classes', 'foreground', 'masks', 'coco', 'labels', 'background']]
# 0.5586915552884401
# [['gaze', 'eyedentify', 'eye', 'eyes', 'ocular', 'saliency', 'pupil', 'visual', 'attention', 'viewing']]
# 0.4575571403997598
# [['hyperspectral', 'multispectral', 'spectral', 'supervised', 'imagery', 'sensing', 'classification', 'denoising', 'hyperview', 'images']]
# 0.5190967553442126
# [['voice', 'audio', 'vocalizing', 'enhancement', 'speech', 'denoising', 'speaker', 'hearing', 'noisy', 'acoustic']]
# 0.5100014072619421
# [['forecast', 'solar', 'forecasting', 'forecasts', 'meteorological', 'photovoltaic', 'predicting', 'prediction', 'predict', 'renewable']]
# 0.7463770280728299
# [['memorization', 'memorisation', 'memorized', 'memorise', 'linguistic', 'neural', 'language', 'sentences', 'attentional', 'lexical']]
# 0.22758705281181527
# [['lexical', 'semantic', 'lexicon', 'corpus', 'wordnet', 'linguistics', 'contextualized', 'contextualised', 'corpora', 'words']]
# 0.5142714478589714
# [['batteryml', 'batteries', 'battery', 'lithium', 'predicting', 'prediction', 'prognostics', 'estimating', 'lifespan', 'degradation']]
# 0.523916475007555
# [['recipes', 'cuisine', 'foods', 'recipe', 'recipemc', 'chef', 'food', 'culinary', 'meals', 'meal']]
# 0.6283309141391042
# [['adversarial', 'watermarking', 'watermark', 'watermarked', 'watermarks', 'unmarker', 'deeptaster', 'protect', 'tampering', 'stealing']]
# 0.6097553685975046
# [['contexts', 'longwriter', 'context', 'retrieval', 'longbench', 'language', 'longer', 'texts', 'longins', 'short']]
# 0.50874726791286
# [['morality', 'moral', 'morally', 'ethics', 'ethical', 'persuasion', 'judgments', 'ai', 'languages', 'language']]
# 0.5299577194038597
# [['braille', 'impaired', 'accessibility', 'blind', 'impairments', 'disabilities', 'accessible', 'sighted', 'recognition', 'visual']]
# 0.591976194168865
# [['personas', 'persona', 'personascore', 'personae', 'profiles', 'agent', 'personality', 'characters', 'character', 'roleeval']]
# 0.41884242947824835
# [['linguistic', 'linguistics', 'psycholinguistics', 'syntactic', 'sentences', 'psycholinguistic', 'linguists', 'grammaticality', 'judgments', 'language']]
# 0.5665670180743594
# [['recommender', 'recommendation', 'personalized', 'collaborative', 'domains', 'cdsr', 'interests', 'domain', 'cdr', 'hypergraph']]
# 0.5998968639372039
# [['fairness', 'discrimination', 'unfairness', 'ai', 'discriminatory', 'ethical', 'bias', 'ethics', 'unfair', 'biases']]
# 0.8072490706916646
# [['autoencoders', 'autoencoder', 'transcoders', 'sparse', 'attention', 'features', 'interpretable', 'interpretability', 'activations', 'circuits']]
# 0.47413955970247484
# [['fairness', 'graphpar', 'bias', 'discriminatory', 'networks', 'graphgini', 'biases', 'unfair', 'unfairness', 'fairgb']]
# 0.42814583398557327
# [['pollution', 'emissions', 'meteorological', 'environmental', 'predicting', 'forecasting', 'climate', 'aerosol', 'pollutants', 'pollutant']]
# 0.7061234769763313
# [['gestures', 'gesture', 'gestureprint', 'touch', 'hands', 'hand', 'multimodal', 'touchpad', 'recognition', 'classifiers']]
# 0.4395198178877718
# [['acoustic', 'bioacoustics', 'recordings', 'bioacoustic', 'birdnet', 'audio', 'supervised', 'recognizing', 'recognition', 'underwater']]
# 0.3515930253935153
# [['drift', 'drifts', 'driftlens', 'drifting', 'classifiers', 'drifted', 'streams', 'adaptive', 'stream', 'detection']]
# 0.5239241514510777
# [['transcription', 'transcriptions', 'speech', 'voice', 'multilingual', 'decoder', 's2st', 'audio', 'decoding', 'translating']]
# 0.6599055127882014
# [['retrieval', 'multimodal', 'embeddings', 'embedding', 'modality', 'modal', 'discriminative', 'search', 'images', 'text']]
# 0.511100186760651
# [['magnetosphere', 'solar', 'flare', 'geomagnetic', 'flares', 'solarcnn', 'sun', 'observatory', 'thermosphere', 'magnetogram']]
# 0.669996959193352
# [['cloud', 'virtualization', 'scheduling', 'workloads', 'workload', 'microservices', 'microservice', 'supercomputing', 'service', 'aws']]
# 0.3905700980574278
# [['optimizing', 'optimization', 'hyperparameters', 'deepsdp', 'multitask', 'learning', 'hyperparameter', 'minimization', 'regularization', 'algorithms']]
# 0.421541708727708
# [['alignment', 'annotation', 'aligned', 'aligner', 'language', 'aligning', 'models', 'automated', 'position', 'aligncot']]
# 0.3534900812496977
# [['paragraphs', 'text', 'autoregressively', 'autoregressive', 'decoding', 'writing', 'planner', 'generation', 'language', 'predict']]
# 0.4175076420590577
# [['fraud', 'banking', 'classification', 'bank', 'banks', 'credit', 'fraudulent', 'lending', 'card', 'lenders']]
# 0.46247176321638417
# [['forgetting', 'memorization', 'continual', 'learning', 'memory', 'retrieval', 'retaining', 'lifelong', 'continually', 'incrementally']]
# 0.573451364375521
# [['chatbots', 'chatbot', 'conversational', 'conversation', 'chat', 'chatatc', 'ai', 'prompts', 'assistant', 'eliza']]
# 0.5672489431568503
# [['distillation', 'distilling', 'datasets', 'dataset', 'distill', 'distilled', 'imagenet', 'data', 'training', 'samples']]
# 0.5138565095404914
# [['mandarin', 'chinese', 'languages', 'linguistic', 'language', 'nlp', 'taiwanese', 'english', 'subjects', 'conversational']]
# 0.576723465761821
# [['patents', 'patenting', 'patent', 'patenteval', 'inventors', 'invention', 'semantic', 'inventions', 'citation', 'texts']]
# 0.41740087316282565
# [['reinforcement', 'critic', 'learning', 'optimism', 'replay', 'reward', 'exploration', 'bias', 'control', 'prioritized']]
# 0.4928234553544869
# [['uav', 'uavs', 'unmanned', 'drone', 'aerial', 'swarm', 'offloading', 'optimization', 'optimizing', 'transmit']]
# 0.7074272505579622
# [['facetalk', 'lip', 'styletalker', 'audio', 'portrait', 'animations', 'talkformer', 'audio2rig', 'mouth', 'animation']]
# 0.4379068717747601
# [['partisan', 'political', 'biases', 'politically', 'politicians', 'elections', 'ideological', 'constituency', 'electoral', 'politician']]
# 0.4334400468314404
# [['forecasting', 'rnn', 'temporal', 'predicting', 'prediction', 'neural', 'events', 'models', 'future', 'autoregressive']]
# 0.5445780200777993
# [['resumes', 'resume', 'hiring', 'jobs', 'recruitment', 'workforce', 'employment', 'applicants', 'skills', 'occupations']]
# 0.5837523929459227
# [['machining', 'fabrication', 'manufacturing', 'welding', 'laser', 'machined', 'cad', 'fusion', 'porosity', 'machine']]
# 0.43067207871098195
# [['speechcodes', 'speechx', 'speechgpt', 'voice', 'voicecraft', 'voicebox', 'phonemes', 'speeches', 'speech', 'audio']]
# 0.3780410334084842
# [['graphs', 'graph_beta_diffusion', 'graph', 'graphebm', 'nodes', 'diffusion', 'graphaf', 'generative', 'edge', 'models']]
# 0.36675745642089136
# [['quadrotor', 'quadrotors', 'drones', 'drone', 'controllers', 'aerial', 'multirotor', 'aerodynamic', 'trajectory', 'robotics']]
# 0.556379809279661
# [['audioset', 'audiovisual', 'audio', 'visual', 'videos', 'scenes', 'supervised', 'auditory', 'embeddings', 'encoder']]
# 0.5142301485869823
# [['ensemble', 'ensembles', 'ensembling', 'diversity', 'classification', 'trained', 'fusionshot', 'fusion', 'models', 'generalization']]
# 0.4896664989595051
# [['autoencoders', 'autoencoder', 'masking', 'imagenet', 'mask', 'learning', 'masked', 'supervised', 'training', 'learned']]
# 0.5710753818402392
# [['disentangling', 'disentangled', 'disentanglement', 'representations', 'autoencoders', 'entangled', 'generative', 'representation', 'autoencoder', 'encode']]
# 0.6483505688831548
# [['audiological', 'audio', 'recordings', 'respiratory', 'recording', 'voice', 'hearing', 'lung', 'acoustic', 'als']]
# 0.36210866688665605
# [['gpu', 'memory', 'gpus', 'sparse', 'throughput', 'cpu', 'optimizer', 'hardware', 'speedup', 'efficient']]
# 0.7407377673266424
# [['3d', 'points', 'supervised', 'lidar', 'detr3d', 'annotations', 'scenes', 'segmentation', '2d', 'annotation']]
# 0.6251014829039917
# [['fusionnet', 'detection', 'images', 'imagery', 'lidar', 'yolov5', 'yolov3', 'yolov8', 'segmentation', 'videos']]
# 0.4734151034030799
# [['earthquakes', 'earthquake', 'seismic', 'seismicity', 'geotechnical', 'disasters', 'landslide', 'tsunami', 'ground', 'seismograms']]
# 0.368841394862068
# [['tokenizers', 'tokenization', 'tokenizer', 'tokenisation', 'tokenize', 'sentencepiece', 'morphemes', 'subwords', 'tokens', 'wordpiece']]
# 0.48287998382745895
# [['spellchecking', 'corpus', 'speller', 'spell', 'spelling', 'misspelled', 'pinyin', 'diacritics', 'bspell', 'phonetic']]
# 0.38362686889687037
# [['bottleneck', 'concepts', 'classification', 'concept', 'annotations', 'features', 'compositional_concepts', 'models', 'concept_realignment', 'representations']]
# 0.45253655919682384
# [['views', 'view', 'clustering', 'cluster', 'clusters', 'embedding', 'mvcan', 'representations', 'feature', 'learns']]
# 0.4616384259817554
# [['benchmarking', 'evaluations', 'language', 'benchmarks', 'benchmark', 'evaluation', 'assessment', 'vocabulary', 'evaluating', 'tests']]
# 0.5368641323957417
# [['bayesian', 'probabilistic', 'inference', 'bayes', 'graphs', 'posterior', 'prior', 'learning', 'likelihood', 'causal']]
# 0.5355047656405028
# [['tweets', 'crisistransformers', 'twitter', 'microblogs', 'disasters', 'crises', 'tweet', 'disaster', 'crisisfacts', 'textual']]
# 0.4569813350090072
# [['tensors', 'sparse', 'parallelization', 'tensor', 'gpus', 'gpu', 'cores', 'optimized', 'compilers', 'pytorch']]
# 0.6387081066633876
# [['gflownet', 'gflownets', 'generative', 'flow', 'eflownets', 'flows', 'networks', 'learned', 'reward', 'rewards']]
# 0.5269030566695523
# [['cnns', 'deepsets', 'neural', 'representations', 'deep', 'deepdrk', 'networks', 'convolutional', 'deeper', 'representational']]
# 0.41120934089314376
# [['wirelessllm', 'generative', 'ai', 'wireless', 'networks', 'network', 'mobile', 'communications', '6g', 'telecom']]
# 0.5199377888912653
# [['augmentation', 'mixup', 'mix', 'learning', 'mixing', 'trained', 'mixda', 'classifier', 'augmix', 'generalization']]
# 0.36381832268358055
# [['lasso', 'lassoglm', 'regularization', 'sparse', 'penalized', 'glmnet', 'predictors', 'robust', 'shrinkage', 'regression']]
# 0.45611303515356455
# [['attention', 'generative', 'blurring', 'conditioned', 'images', 'conditioning', 'models', 'guidance', 'denoised', 'diffusion']]
# 0.5140061426881692
# [['accelerator', 'accelerators', 'hardware', 'cnn', 'dataflows', 'cores', 'throughput', 'dataflow', 'memory', 'dnns']]
# 0.7893645505673195
# [['quantization', 'quantized', 'diffusion', 'imagenet', 'denoising', 'pixel', 'deblurring', 'noising', 'generative', 'images']]
# 0.4259726696774952
# [['memristor', 'memristors', 'memory', 'memristive', 'baynn', 'hardware', 'neural', 'baynns', 'bayesnns', 'spintronics']]
# 0.4909823216109175
# [['variational', 'unnormalized', 'inference', 'posteriors', 'gradient', 'probabilistic', 'divergence', 'likelihood', 'reparameterization', 'posterior']]
# 0.5661942773427033
# ...
# 0.5032165177583696
# [['clicks', 'advertiser', 'recommender', 'ctr', 'feature', 'advertisers', 'prediction', 'ads', 'advertising', 'click']]
# 0.5955816343042339
# [['fuzzy', 'sets', 'rough', 'soft', 'vague', 'granular', 'approximations', 'granularly', 'quantification', 'quantifier']]
# 0.31487643967582984
# [['autism', 'autistic', 'asd', 'speech', 'voice', 'neurodevelopment', 'diagnosing', 'developmental', 'linguistic', 'diagnostics']]
# 0.49670006775988157
# [['urban', 'urbanvlp', 'urbangenai', 'neighborhoods', 'landscape', 'visual', 'landscapes', 'planning', 'imagery', 'buildings']]
# 0.3445306522573722
# [['multilingual', 'languages', 'answering', 'language', 'translating', 'annotation', 'translation', 'linguistic', 'annotated', 'translated']]
# 0.7019571331286267
# [['robust', 'minimizes', 'optimization', 'minimax', 'distributional', 'distributionally', 'stochastic', 'convex', 'regularized', 'wasserstein']]
# 0.6737050158053449
# [['vehicular', 'supervised', 'vehicles', 'vehicle', 'driving', 'autonomous', 'cloud', 'federated', 'learning', 'networks']]
# 0.5890344990391292
# [['tactics', 'uav', 'maneuvers', 'uavs', 'evader', 'combat', 'drones', 'maneuver', 'maneuverability', 'drone']]
# 0.294636393968554
# [['ridesharing', 'taxis', 'passengers', 'taxi', 'intercity', 'passenger', 'routes', 'trips', 'dispatching', 'vehicles']]
# 0.6237189415501753
# [['heuristics', 'heuristic', 'optimized', 'generating', 'automate', 'evolutionary', 'algorithms', 'automated', 'generates', 'evolving']]
# 0.45146462785967956
# [['chemical', 'chemistry', 'molecular', 'molecule', 'chemllm', 'molecules', 'synthesis', 'chemdfm', 'automating', 'chemdata']]
# 0.4706610249217791
# [['learns', 'imitation', 'reinforcement', 'learning', 'exploration', 'learned', 'actions', 'demonstrations', 'tasks', 'robotic']]
# 0.6352628048604919
# [['dimensionality', 'dimensional', 'multidimensional', 'dimension', 'manifolds', 'manifold', 'clustering', 'eigenmaps', 'embedding', 'embeddings']]
# 0.503242401120765
# [['adversarial', 'attacks', 'cyberattacks', 'attack', 'security', 'supervised', 'mitigation', 'threats', 'vulnerability', 'grid']]
# 0.6584076987925717
# [['analogies', 'analogical', 'analogy', 'analogykb', 'semantic', 'cognition', 'analogous', 'cognitive', 'reasoning', 'thinking']]
# 0.6545546037219571
# [['bitrate', 'streaming', 'bitstream', 'videos', 'encoder', 'compression', 'encoding', 'vvc', 'decoding', 'decoder']]
# 0.45315084910358666
# [['valuation', 'valuing', 'shapley', 'value', 'data', 'values', 'ml', 'quantifying', 'usefulness', 'estimate']]
# 0.4625324228846104
# [['regularization', 'inversions', 'inverse', 'inversion', 'neural', 'deep', 'cnn', 'invertible', 'encoder', 'imaging']]
# 0.3582218063154604
# [['recommender', 'federated', 'privacy', 'collaborative', 'personalization', 'personalized', 'collaboratively', 'shared', 'recommendation', 'sharing']]
# 0.7531646949148332
# [['safegen', 'unsafe', 'malicious', 'safety', 'protecting', 'prevent', 'redacts', 'images', 'videos', 'content']]
# 0.3815571056607766
# [['erasing', 'unlearning', 'erasures', 'erasure', 'relearning', 'unlearn', 'erase', 'memorization', 'eraser', 'erased']]
# 0.5995864878990921
# [['reidentification', 'matching', 'discriminative', 'pedestrians', 'pedestrian', 'persons', 'feature', 'identification', 'infrared', 'cameras']]
# 0.31314249822616197
# [['3d', '3dis', '3dcompat', 'scenes', 'opensun3d', '3ddet', 'visual', 'vision', 'any2point', 'scene']]
# 0.8177420359201435
# [['imputations', 'imputation', 'missingness', 'data', 'personalized', 'ehrs', 'ehr', 'health', 'prediction', 'healthcare']]
# 0.6725702986970225
# [['linearization', 'koopman', 'linearizations', 'observables', 'operators', 'eigenfunctions', 'dynamical', 'nonlinear', 'dynamics', 'spectral']]
# 0.6408019891660619
# [['testing', 'bugs', 'apis', 'dllens', 'developers', 'deep', 'dl', 'reproducibility', 'projects', 'libraries']]
# 0.5677611691432577
# [['classifiers', 'classification', 'classifier', 'classifying', 'misclassify', 'classes', 'recognition', 'softmax', 'openness', 'wiseopen']]
# 0.3806298158952461
# [['lasso', 'sparse', 'regularization', 'optimization', 'convexity', 'convex', 'regularized', 'sparsity', 'regularizer', 'solvers']]
# 0.613153557443031
# [['phylogenies', 'protolanguage', 'phylogenetics', 'phylogenetic', 'linguistics', 'ancestral', 'linguists', 'ancestor', 'phonetic', 'linguistic']]
# 0.2969777258310501
# [['3d', 'referit3d', 'lv3d', 'scenes', '3ddc', 'visual', 'cube', '3dvg', 'llmi3d', 'annotations']]
# 0.3908528967601282
# [['automl', 'automate', 'automated', 'automating', 'automation', 'autorecsys', 'autommlab', 'automatically', 'autorul', 'expertise']]
# 0.4801322723695381
# [['distributional', 'quantile', 'reinforcement', 'learns', 'distributions', 'distribution', 'learning', 'dqn', 'reward', 'expectile']]
# 0.4717687852212912
# [['paraphrases', 'paraphrasing', 'paraphrastic', 'paraphrase', 'paraphrased', 'sentences', 'linguistic', 'nlg', 'semantic', 'corpora']]
# 0.6438080835707987
# [['surfaces', 'surface', 'curvature', 'curvatures', 'shapes', 'mesh', '3d', 'neural', 'shape', 'meshes']]
# 0.663289183924238
# [['captioning', 'embedding', 'captions', 'caption', 'clip', 'visual', 'recognition', 'modality', 'generatively', 'retrieval']]
# 0.5913117970101573
# [['rgb', 'camera', 'illumination', 'photography', 'dslr', 'cameras', 'srgb', 'brightness', 'dark', 'reflectance']]
# 0.39530223435118783
# [['mixtures', 'mixture', 'clustering', 'likelihood', 'clusterability', 'gaussian', 'estimation', 'estimating', 'mixing', 'gmms']]
# 0.5265377366254433
# [['stochastic', 'langevin', 'markovian', 'markovianity', 'dynamics', 'drift', 'trajectories', 'entropy', 'odinger', 'observations']]
# 0.5254965466910686
# [['networks', 'communities', 'social', 'influence', 'network', 'community', 'socially', 'friends', 'cohesion', 'distrust']]
# 0.31173367937687446
# [['activations', 'sparse', 'activation', 'neuron', 'neurons', 'progressive_gradient_flow_nm_sparsity', 'relu', 'sparsely', 'sparsity', 'sparsification']]
# 0.7812974956923318
# [['traffic', 'trafficgpt', 'packet', 'encryption', 'bytes', 'byte', 'classification', 'classifying', 'streams', 'encrypted']]
# 0.35478942004999375
# [['extracting', 'materials', 'parsing', 'extraction', 'structured', 'extract', 'material', 'extracted', 'tagging', 'automated']]
# 0.573937309279194
# [['selfreflection', 'responses', 'corrections', 'self', 'mistakes', 'revise', 'improve', 'feedback', 'refine', 'criticize']]
# 0.3439125597326915
# [['drones', 'drone', 'unmanned', 'uavs', 'nano', 'dronet', 'aerial', 'onboard', 'pose', 'chip']]
# 0.6553507129941163
# [['documentunderstanding', 'layoutllm', 'text', 'doclaynet', 'layouts', 'layout', 'document', 'textual', 'ocr', 'structured']]
# 0.49791351307720727
# [['nlp', 'classification', 'adapting', 'language', 'tasks', 'examples', 'generalization', 'models', 'training', 'accuracy']]
# 0.4396201729402295
# [['detoxify', 'detoxifying', 'detoxified', 'detoxifier', 'detoxifies', 'detoxification', 'detox', 'detoxifiable', 'detoxifiability', 'corpus']]
# 0.37156601848348547
# [['counterfactual_interventions', 'counterfactuals', 'counterfactual', 'causality', 'causal', 'causation', 'inference', 'outcomes', 'consistency', 'interventions']]
# 0.6843197099124958
# [['ctm_remote_sensing_change_detection', 'cnn', 'changes', 'changeanywhere', 'change', 'detection', 'features', 'sensing', 'imagery', 'mapchange']]
# 0.37544127119525583
# [['networks', 'graphs', 'gnn', 'vertex', 'gpus', 'graphscale', 'graph', 'bottleneck', 'gnns', 'gpu']]
# 0.5457223396768764
# [['bloodstream', 'nanodevice', 'nanodevices', 'microvascular', 'bloodstreams', 'macrovascular', 'flow', 'nanotechnology', 'arterial', 'vivo']]
# 0.20843397335724725
# [['influence', 'influencer', 'influential', 'influence_analysis_papers', 'annotated', 'attribution', 'predictions', 'evaluations', 'gradient', 'outlier']]
# 0.3366218985024181
# [['steganography', 'steganographic', 'steganalysis', 'watermarking', 'stegano', 'stegotexts', 'stegotext', 'watermark', 'covert', 'hide']]
# 0.5153677758440186
# [['rhythms', 'synchronization', 'oscillators', 'oscillating', 'synchronize', 'oscillator', 'bifurcation', 'fluctuations', 'dynamics', 'synchronized']]
# 0.31529179549018405
# [['dysarthric', 'dysarthria', 'speech', 'impaired', 'speaker', 'dsr', 'wav2vec2', 'classification', 'disability', 'assessment']]
# 0.5518669379089592
# [['twinning', 'twin', 'twinlab', 'twins', 'modelization', 'modeling', 'neural', 'modelling', 'simulations', 'digital']]
# 0.41074955113015965
# [['recommender', 'recommenders', 'reinforcement', 'rewards', 'reward', 'recommendation', 'planning', 'rl', 'offline', 'agent']]
# 0.5500429290456087
# [['confounders', 'confounder', 'recommender', 'recommending', 'bias', 'confounding', 'biases', 'recommendation', 'recommendations', 'causald']]
# 0.5603636116957762
# [['uav', 'unmanned', 'uavs', 'swarm', 'swarms', 'autonomous', 'flying', 'planning', 'aircraft', 'aerial']]
# 0.7062753925307892
# [['prediction', 'inferences', 'predict', 'predictions', 'inference', 'predicted', 'estimates', 'statistical', 'labeled', 'confidence']]
# 0.4896031789108058
# [['artistic', 'artworks', 'artwork', 'creativity', 'aesthetics', 'aesthetic', 'typography', 'wordart', 'calligraphy', 'aesthetically']]
# 0.48521240153001577
# [['tokamaks', 'tokamak', 'plasma', 'plasmas', 'fusion', 'simulations', 'modeling', 'magnetohydrodynamics', 'modelling', 'dynamics']]
# 0.5903256219168729
# [['pca', 'eigenvector', 'eigenspace', 'eigen', 'cpca', 'sparse', 'algorithms', 'spectral', 'matrix', 'eigenvalue']]
# 0.479529855335067
# [['translations', 'decoding', 'translation', 'mbr', 'mbrs', 'bayes', 'mbmbr', 'text', 'cbmbr', 'risk']]
# 0.6037419819099561
# [['gerrymandering', 'redistricting', 'gerrymanderer', 'candidates', 'elections', 'voting', 'candidate', 'electoral', 'ensemble', 'voters']]
# 0.6254212185794494
# [['imputations', 'imputation', '_imputation', 'missingness', 'imputed', 'imputing', 'forecasting', 'forecasts', 'impute', 'incomplete']]
# 0.5683781807604994
# [['gps', 'accelerometer', 'gyroscope', 'sensor', 'sensors', 'tracking', 'inertial', 'magnetometer', 'magnetometers', 'satellite']]
# 0.6254003107832344
# [['poetry2image', 'poetry', 'poems', 'poets', 'rhyme', 'rhyming', 'poem', 'syllables', 'literary', 'poetic']]
# 0.6272266064638755
# [['coreference', 'annotation', 'ontonotes', 'texts', 'corpora', 'translations', 'multilingual', 'nlp', 'referring', 'mentions']]
# 0.5565540851601048
# [['ai', 'automation', 'software', 'developers', 'programmers', 'development', 'architectural', 'automl', 'engineering', 'prototyping']]
# 0.5024361262553809
# [['gradients', 'differential', 'pdes', 'nonlinear', 'pde', 'solvers', 'neural', 'parameterized', 'dde', 'nonlinearity']]
# 0.5104491703057624
# [['networks', 'graphs', 'nodes', 'prediction', 'graph', 'classification', 'node', 'neural', 'gnns', 'predictions']]
# 0.6847767007919001
# [['promptcompressor', 'compression', 'prompts', 'decoder', 'compressed', 'prompt', 'compressing', 'encoder', 'compress', 'adacoder']]
# 0.5204440098896943
# [['autoencoder', 'accelerator', 'neuralized', 'autoencoded', 'accelerators', 'lstm', 'particle', 'beam', 'reactor', 'particles']]
# 0.34780557772268433
# [['dialogues', 'dialogue', 'conversational', 'personas', 'persona', 'personachat', 'conversation', 'conversations', 'personalizing', 'profiles']]
# 0.6044074758841532
# [['videos', 'video', 'attention', 'memory', 'vid', 'diffusion', 'webvid', 'frames', 'pixels', 'conditioned']]
# 0.45941673286638834
# [['reward', 'rewards', 'reinforcement', 'backpropagation', 'gradient', 'backpropagate', 'generative', 'diffusion', 'bias', 'optimizing']]
# 0.40938914114586417
# [['robot', 'robots', 'robotic', 'planning', 'autonomous', 'navigate', 'navigating', 'pedestrians', 'navigation', 'agent']]
# 0.803148264391093
# [['denoising', 'restoration', 'imaging', 'diffusion', 'inpainting', 'reconstructions', 'generative', 'residual', 'jpeg', 'restored']]
# 0.4946302789316889
# [['gans', 'generative', 'gan', 'autoencoders', 'adversarial', 'data', 'ehrs', 'healthcare', 'ehr', 'generate']]
# 0.5349916671075258
# [['cnns', 'cracknet', 'convolutional', 'pavement', 'cracks', 'segmentation', 'efficientnetv2', 'pavements', 'yolov5', 'images']]
# 0.6860904963106365
# [['ai', 'artmaking', 'deviantart', 'creators', 'artistic', 'artists', 'arts', 'copyright', 'imagery', 'media']]
# 0.4477772232484515
# [['changepoints', 'changepoint', 'observations', 'detection', 'detecting', 'cusum', 'detect', 'outliers', 'changes', 'cumulative']]
# 0.3212415666404227
# [['depressive', 'depression', 'depressed', 'speech', 'audio', 'distress', 'suicide', 'recordings', 'features', 'psychiatric']]
# 0.3691049299046424
# [['throughput', 'streaming', 'chatbot', 'batching', 'workloads', 'chatbots', 'serving', 'scheduling', 'concurrent', 'sglang']]
# 0.3937476327819255
# [['policies', 'policy', 'estimators', 'unbiasedness', 'estimation', 'unbiasedly', 'unbiased', 'evaluation', 'estimate', 'estimator']]
# 0.5747870715287402
# [['privacy', 'private', 'privately', 'memorization', 'secure', 'leak', 'protect', 'serializing', 'examples', 'context']]
# 0.511855508307923
# [['ecommerce', 'retailing', 'retail', 'customers', 'purchases', 'marketing', 'promotions', 'customer', 'willingness', 'categories']]
# 0.43958219921592806
# [['cultural', 'cultures', 'culturally', 'culturalvqa', 'culture', 'cultureadapt', 'multicultural', 'recognizing', 'captioning', 'multilingual']]
# 0.6279301152894277
# [['denoising', 'denoisers', 'denoiser', 'denoised', 'noise2noise', 'pixels', 'noisy', 'supervised', 'noise', 'images']]
# 0.5368715638860648
# [['learning', 'shot', 'classification', 'dataset', 'overfitting', 'trained', 'training', 'features', 'adaptation', 'labeled']]
# 0.4358228769933171
# [['multimodal', 'modality', 'crossmodal', 'federated', 'learning', 'fedmml', 'modal', 'modalities', 'regularization', 'distributed']]
# 0.41307268010431447
# [['byzantine', 'distributed', 'adversarial', 'mlmc', 'decentralized', 'robustscgmm', 'robust', 'federated', 'aggregators', 'adversaries']]
# 0.5136447962187795
# [['graphslim', 'graphs', 'graph', 'tinygraph', 'gnn', 'nodes', 'condense', 'gnns', 'node', 'condenses']]
# 0.7715964659251447
# [['detection', 'detecting', 'outliers', 'outlier', 'classifier', 'inlier', 'ood', 'classified', 'novelty', 'od']]
# 0.5364089636047936
# [['attention', 'tokenizers', 'tokenizer', 'tokenization', 'representations', 'recognition', 'imagenet', 'vision', 'visual', 'representation']]
# 0.48826255749601194
# [['ranking', 'rankings', 'rank', 'fairness', 'bias', 'merit', 'unfair', 'utility', 'predictors', 'redistribution']]
# 0.36515738020057104
# [['voices', 'voice', 'vocal', 'vocals', 'singing', 'singers', 'karaoker', 'singer', 'wav2vec', 'transcription']]
# 0.8392904624244478
# [['cultures', 'cultural', 'culture', 'nationalities', 'culturally', 'multicultural', 'nationality', 'diverse', 'attitudes', 'anthropology']]
# 0.5319486191357187
# [['logs', 'parsers', 'log', 'openlogparser', 'parsing', 'parser', 'parses', 'logprompt', 'loghub', 'logelectra']]
# 0.6259578990549647
# [['rumors', 'tweets', 'rumor', 'news', 'blogging', 'credibility', 'virality', 'viral', 'textual', 'debunk']]
# 0.4086534580048805
# [['inceptionv3', 'dnns', 'dnn', 'deepfault', 'tensorflow', 'deep', 'testability', 'deepgd', 'faults', 'neuron']]
# 0.4122442832254616
# [['shap', 'shapley', 'ranking', 'feature', 'generalising', 'probabilistic', 'kernelshap', 'attributions', 'rank', 'complexity']]
# 0.29563902612036774
# [['adversarial', 'exploitability', 'attacker', 'malicious', 'vulnerability', 'attacks', 'retrieval', 'security', 'attackers', 'adversary']]
# 0.6251601744650948
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 33
#      27     per_topic_coherence_cv.append(coherence_cv)
#      31 # Create a DataFrame to display the results
#      32 results = pd.DataFrame({
# ---> 33     "Topic": topic_ids,
#      34     "Keywords": topic_representations.values,
#      35     "Coherence c_v": per_topic_coherence_cv,
#      36 })
#      39 # Display overall and per-topic coherence scores
#      40 print(results)
#
# NameError: name 'topic_ids' is not defined

# %%
# Create a DataFrame to display the results
results = pd.DataFrame({
    "Keywords": topic_representations.values,
    "Coherence c_v": per_topic_coherence_cv,
})


# Display overall and per-topic coherence scores
print(results)
results.to_csv('First_Level_First_Step_coherence.csv')
# Out:
#                                               Keywords  Coherence c_v
# 0    [features, classification, learning, datasets,...       0.422347
# 1    [medical, clinical, patients, medicine, med, c...       0.611292
# 2    [recommender, recommenders, personalized, conv...       0.611498
# 3    [translations, translators, multilingual, ling...       0.734462
# 4    [robotic, robot, robotics, robots, grasping, m...       0.772683
# ..                                                 ...            ...
# 519  [logs, parsers, log, openlogparser, parsing, p...       0.625958
# 520  [rumors, tweets, rumor, news, blogging, credib...       0.408653
# 521  [inceptionv3, dnns, dnn, deepfault, tensorflow...       0.412244
# 522  [shap, shapley, ranking, feature, generalising...       0.295639
# 523  [adversarial, exploitability, attacker, malici...       0.625160
#
# [524 rows x 2 columns]

# %%
# Create a DataFrame from the list
df = pd.DataFrame(per_topic_coherence_cv, columns=['Topic Coherence Score'])

# Convert to CSV
df.to_csv('per_topic_coherence_cv.csv', index='Index')

# %%
file_path = 'per_topic_coherence_cv.csv'  # Replace with your file path
data = pd.read_csv(file_path)
mean_score = data['Topic Coherence Score'][1:].mean()
data['Topic Coherence Score'].mean()
mean_score
# Out:
# 0.5422169300954853
