# %% [markdown]
# # This notebook performs keyword extraction and topic coherence evaluation for the third hierarchical level of topic clustering.
#
# ## Steps:
# 1. **Preprocessing the text data**:
#    - Loads the dataset `Concatenated_First_Second_Step_BERTopic_Result.csv`.
#    - Preprocesses the text by removing stopwords and non-alphabetic tokens using NLTK, preparing the documents for keyword extraction.
#
# 2. **Keyword extraction with KeyBERT**:
#    - Groups the documents by 'Highest_Topic_Label' (third-level topic label).
#    - Uses the KeyBERT model to extract the top 10 keywords for each topic at the third level.
#    - The extracted keywords are stored in a dictionary and merged back into the original dataset.
#
# 3. **Coherence score calculation**:
#    - Creates a Gensim dictionary from the processed documents.
#    - For each third-level topic, the c_v coherence score is calculated using Gensim's `CoherenceModel`.
#    - The topic coherence scores, keywords, and topic labels are stored in a DataFrame and saved as `Third_Level_Topic_coherence.csv`.
#
# 4. **Results output**:
#    - Displays the results, including third-level topic labels, keywords, and their coherence scores.
#    - The average coherence score across all topics is calculated and displayed.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load your dataset
file_path = "Concatenated_First_Second_Step_BERTopic_Result.csv"  # Replace with your file path
data = pd.read_csv(file_path)
data
merged_second_step_df = data.drop_duplicates()
merged_second_step_df
# Out:
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /w0/tmp/slurm_yc656703.50590673/ipykernel_122344/4283704144.py:12: DtypeWarning: Columns (0,29,30,31,32,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
#                  id              submitter  \
# 0          806.1636     Ian Pratt-Hartmann
# 1          808.0521     Ian Pratt-Hartmann
# 2          905.3108     Ian Pratt-Hartmann
# 3         1104.2444      Claus-Peter Wirth
# 4          1301.387  Pierfrancesco La Mura
# ...             ...                    ...
# 60323    2408.08302                 Bin Hu
# 60324    2408.08307   Ahmed Imtiaz Humayun
# 60325    2408.08310             Ruihang Li
# 60326    cs/0701194       Andrij Rovenchak
# 60327  nlin/0408039            Yuzuru Sato
#
#                                                  authors  \
# 0                                     Ian Pratt-Hartmann
# 1                Ian Pratt-Hartmann and Lawrence S. Moss
# 2                 Yevgeny Kazakov and Ian Pratt-Hartmann
# 3                                      Claus-Peter Wirth
# 4                                  Pierfrancesco La Mura
# ...                                                  ...
# 60323  Usman Syed, Ethan Light, Xingang Guo, Huan Zha...
# 60324  Ahmed Imtiaz Humayun, Ibtihel Amara, Candice S...
# 60325  Ruihang Li, Yixuan Wei, Miaosen Zhang, Nenghai...
# 60326                  Solomija Buk and Andrij Rovenchak
# 60327    Yuzuru Sato, Eizo Akiyama, James P. Crutchfield
#
#                                                    title  \
# 0      Data-Complexity of the Two-Variable Fragment w...
# 1                  Logics for the Relational Syllogistic
# 2      A Note on the Complexity of the Satisfiability...
# 3      A Simplified and Improved Free-Variable Framew...
# 4                                          Game Networks
# ...                                                  ...
# 60323  Benchmarking the Capabilities of Large Languag...
# 60324  Understanding the Local Geometry of Generative...
# 60325  ScalingFilter: Assessing Data Quality through ...
# 60326  Menzerath-Altmann Law for Syntactic Structures...
# 60327   Stability and Diversity in Collective Adaptation
#
#                                                 comments  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Full proofs for paper presented at the IEEE Co...
# 3                                         ii + 114 pages
# 4      Appears in Proceedings of the Sixteenth Confer...
# ...                                                  ...
# 60323                                                NaN
# 60324  Pre-print. 11 pages main, 8 pages app., 28 fig...
# 60325                                                NaN
# 60326  8 pages; submitted to the Proceedings of the I...
# 60327  22 pages, 23 figures; updated references, corr...
#
#                                              journal-ref  \
# 0      Information and Computation, 207(8), 2009, pp....
# 1      Review of Symbolic Logic, 2(4), 2009, pp. 647-...
# 2      Proceedings, 24th Annual IEEE Symposium on Log...
# 3      IfCoLog Journal of Logics and their Applicatio...
# 4                                                    NaN
# ...                                                  ...
# 60323                                                NaN
# 60324                                                NaN
# 60325                                                NaN
# 60326       Glottotheory. Vol. 1, No. 1, pp 10-17 (2008)
# 60327                                                NaN
#
#                                doi  \
# 0         10.1016/j.ic.2009.02.004
# 1        10.1017/S1755020309990086
# 2             10.1109/LICS.2009.17
# 3                              NaN
# 4                              NaN
# ...                            ...
# 60323                          NaN
# 60324                          NaN
# 60325                          NaN
# 60326       10.1515/glot-2008-0002
# 60327  10.1016/j.physd.2005.06.031
#
#                                         report-no  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                          SEKI Report SR-2011-01
# 4                           UAI-P-2000-PG-335-342
# ...                                           ...
# 60323                                         NaN
# 60324                                         NaN
# 60325                                         NaN
# 60326                                         NaN
# 60327  Santa Fe Institute Working Paper 04-08-025
#
#                                   categories  \
# 0                          cs.LO cs.AI cs.CC
# 1                          cs.LO cs.CC cs.CL
# 2                          cs.LO cs.AI cs.CC
# 3                              cs.AI math.LO
# 4                                cs.GT cs.AI
# ...                                      ...
# 60323                      cs.AI cs.CL cs.LG
# 60324                            cs.LG cs.CV
# 60325                                  cs.CL
# 60326                                  cs.CL
# 60327  nlin.AO cs.LG math.DS nlin.CD stat.ML
#
#                                                  license  ...  \
# 0      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 1      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 2      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 3      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 4      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# ...                                                  ...  ...
# 60323  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 60324  http://creativecommons.org/licenses/by-nc-sa/4.0/  ...
# 60325  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 60326                                                NaN  ...
# 60327                                                NaN  ...
#
#                                    Human_Readable_Topic  \
# 0          Formal Reasoning and Satisfiability in Logic
# 1          Formal Reasoning and Satisfiability in Logic
# 2          Formal Reasoning and Satisfiability in Logic
# 3          Formal Reasoning and Satisfiability in Logic
# 4             Game Theory and Strategic Decision Making
# ...                                                 ...
# 60323      Transportation Systems and Mobility Analysis
# 60324               Manifold Learning with Autoencoders
# 60325      Large Language Models and Dataset Generation
# 60326  Multilingual Language Processing and Linguistics
# 60327      Optimal Decision-Making in Multi-Agent Games
#
#                                       Higher_Topic_Label  \
# 0      Reasoning and Problem-Solving with Logic, Lang...
# 1      Reasoning and Problem-Solving with Logic, Lang...
# 2      Reasoning and Problem-Solving with Logic, Lang...
# 3      Reasoning and Problem-Solving with Logic, Lang...
# 4              Game Theory and Strategic Decision Making
# ...                                                  ...
# 60323               Transportation and Mobility Analysis
# 60324               Geometric Deep Learning on Manifolds
# 60325                  Advances in Large Language Models
# 60326           Multilingual Natural Language Processing
# 60327  Multi-Agent Decision Making and Reinforcement ...
#
#                                      Highest_Topic_Label Unnamed: 0_x  \
# 0          Artificial Intelligence and Reasoning Systems          NaN
# 1          Artificial Intelligence and Reasoning Systems          NaN
# 2          Artificial Intelligence and Reasoning Systems          NaN
# 3          Artificial Intelligence and Reasoning Systems          NaN
# 4      Decision Making and Optimization under Uncerta...          NaN
# ...                                                  ...          ...
# 60323  Transportation Systems and Environmental Analy...      20548.0
# 60324            Geometric and Equivariant Deep Learning      20549.0
# 60325                              Large Language Models      20550.0
# 60326                        Natural Language Processing      20551.0
# 60327    Multi-Agent Systems and Artificial Intelligence      20552.0
#
#                                 Second_Step_Topic_Name  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 60323     36_transportation_traffic_routes_ridesharing
# 60324  291_autoencoders_autoencoder_embeddings_encoder
# 60325             146_tokenizers_language_datasets_nlp
# 60326     170_lingual_multilingual_corpus_translations
# 60327          199_reinforcement_optimal_games_bandits
#
#                               Second_Step_Topic_Keywords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  transportation, traffic, routes, ridesharing, ...
# 60324  autoencoders, autoencoder, embeddings, encoder...
# 60325  tokenizers, language, datasets, nlp, models, f...
# 60326  lingual, multilingual, corpus, translations, l...
# 60327  reinforcement, optimal, games, bandits, strate...
#
#                         Second_Step_Topic_Representation  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  transportation (0.48), traffic (0.47), routes ...
# 60324  autoencoders (0.58), autoencoder (0.52), embed...
# 60325  tokenizers (0.42), language (0.35), datasets (...
# 60326  lingual (0.52), multilingual (0.52), corpus (0...
# 60327  reinforcement (0.44), optimal (0.41), games (0...
#
#                          Second_Step_Representative_Docs Unnamed: 0_y  \
# 0                                                    NaN          NaN
# 1                                                    NaN          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 60323    Mobility service route design requires deman...         36.0
# 60324    Representing a manifold of very high-dimensi...        291.0
# 60325    The rapid advancement of large language mode...        146.0
# 60326    As Uzbek language is agglutinative, has many...        170.0
# 60327    Addressing the question of how to achieve op...        199.0
#
#                                              Final_Label
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  Transportation Systems and Environmental Analy...
# 60324            Geometric and Equivariant Deep Learning
# 60325                              Large Language Models
# 60326                        Natural Language Processing
# 60327    Multi-Agent Systems and Artificial Intelligence
#
# [54947 rows x 35 columns]

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from keybert import KeyBERT
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# file_path = 'Concatenated_First_Second_Step_BERTopic_Result.csv'  # Replace with your file path
data = data_cleaned.copy()

# Example: Assuming you have a separate list of documents
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return ' '.join(tokens)  # Join tokens back to a single string for KeyBERT

processed_docs = [preprocess(doc) for doc in documents]

# Initialize KeyBERT model
kw_model = KeyBERT()

# Group documents by 'Second_Level_Topic_Label'
grouped_docs = data.groupby('Highest_Topic_Label')['text'].apply(lambda texts: ' '.join(texts))

# Extract keywords per topic
def extract_keywords(text, model, num_keywords=10):
    keywords = model.extract_keywords(text, stop_words='english', top_n=num_keywords)
    return [keyword[0] for keyword in keywords]

topic_keywords = {}
for topic_label, docs in grouped_docs.items():
    processed_text = preprocess(docs)
    keywords = extract_keywords(processed_text, kw_model)
    topic_keywords[topic_label] = keywords

# Convert topic_keywords dictionary to DataFrame
keywords_df = pd.DataFrame(list(topic_keywords.items()), columns=['Highest_Topic_Label', 'KeyBERT_Keywords'])

# Merge the KeyBERT keywords back into the original dataset
data_with_keywords = pd.merge(data, keywords_df, on='Highest_Topic_Label', how='left')

# Display the resulting dataset with the KeyBERT keywords added
data_with_keywords
# Out:
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                  id            submitter  \
# 0          806.1636   Ian Pratt-Hartmann
# 1          808.0521   Ian Pratt-Hartmann
# 2          905.3108   Ian Pratt-Hartmann
# 3         1104.2444    Claus-Peter Wirth
# 4          1203.055  Afshin Rostamizadeh
# ...             ...                  ...
# 54942    2408.08313          Weiyang Liu
# 54943    cs/0512102     Andrij Rovenchak
# 54944    cs/0701039   Ian Pratt-Hartmann
# 54945    cs/0701194     Andrij Rovenchak
# 54946  nlin/0408039          Yuzuru Sato
#
#                                                  authors  \
# 0                                     Ian Pratt-Hartmann
# 1                Ian Pratt-Hartmann and Lawrence S. Moss
# 2                 Yevgeny Kazakov and Ian Pratt-Hartmann
# 3                                      Claus-Peter Wirth
# 4      Corinna Cortes, Mehryar Mohri, Afshin Rostamiz...
# ...                                                  ...
# 54942  Zeju Qiu, Weiyang Liu, Haiwen Feng, Zhen Liu, ...
# 54943                  Solomija Buk and Andrij Rovenchak
# 54944                                 Ian Pratt-Hartmann
# 54945                  Solomija Buk and Andrij Rovenchak
# 54946    Yuzuru Sato, Eizo Akiyama, James P. Crutchfield
#
#                                                    title  \
# 0      Data-Complexity of the Two-Variable Fragment w...
# 1                  Logics for the Relational Syllogistic
# 2      A Note on the Complexity of the Satisfiability...
# 3      A Simplified and Improved Free-Variable Framew...
# 4      Algorithms for Learning Kernels Based on Cente...
# ...                                                  ...
# 54942  Can Large Language Models Understand Symbolic ...
# 54943  Statistical Parameters of the Novel "Perekhres...
# 54944  On the Complexity of the Numerically Definite ...
# 54945  Menzerath-Altmann Law for Syntactic Structures...
# 54946   Stability and Diversity in Collective Adaptation
#
#                                                 comments  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Full proofs for paper presented at the IEEE Co...
# 3                                         ii + 114 pages
# 4                                                    NaN
# ...                                                  ...
# 54942  Technical Report v1 (44 pages, 23 figures, pro...
# 54943                                           11 pages
# 54944                                  24 pages 1 figure
# 54945  8 pages; submitted to the Proceedings of the I...
# 54946  22 pages, 23 figures; updated references, corr...
#
#                                              journal-ref  \
# 0      Information and Computation, 207(8), 2009, pp....
# 1      Review of Symbolic Logic, 2(4), 2009, pp. 647-...
# 2      Proceedings, 24th Annual IEEE Symposium on Log...
# 3      IfCoLog Journal of Logics and their Applicatio...
# 4      Journal of Machine Learning Research 13 (2012)...
# ...                                                  ...
# 54942                                                NaN
# 54943  Quantitative Linguistics 62: Exact methods in ...
# 54944  Bulletin of Symbolic Logic, 14(1), 2008, pp. 1...
# 54945       Glottotheory. Vol. 1, No. 1, pp 10-17 (2008)
# 54946                                                NaN
#
#                                doi  \
# 0         10.1016/j.ic.2009.02.004
# 1        10.1017/S1755020309990086
# 2             10.1109/LICS.2009.17
# 3                              NaN
# 4                              NaN
# ...                            ...
# 54942                          NaN
# 54943     10.1515/9783110894219.39
# 54944       10.2178/bsl/1208358842
# 54945       10.1515/glot-2008-0002
# 54946  10.1016/j.physd.2005.06.031
#
#                                         report-no  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                          SEKI Report SR-2011-01
# 4                                             NaN
# ...                                           ...
# 54942                                         NaN
# 54943                                         NaN
# 54944                                         NaN
# 54945                                         NaN
# 54946  Santa Fe Institute Working Paper 04-08-025
#
#                                   categories  \
# 0                          cs.LO cs.AI cs.CC
# 1                          cs.LO cs.CC cs.CL
# 2                          cs.LO cs.AI cs.CC
# 3                              cs.AI math.LO
# 4                                cs.LG cs.AI
# ...                                      ...
# 54942                cs.LG cs.AI cs.CL cs.CV
# 54943                                  cs.CL
# 54944                      cs.LO cs.AI cs.CC
# 54945                                  cs.CL
# 54946  nlin.AO cs.LG math.DS nlin.CD stat.ML
#
#                                                  license  ...  \
# 0      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 1      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 2      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 3      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 4      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# ...                                                  ...  ...
# 54942  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 54943                                                NaN  ...
# 54944                                                NaN  ...
# 54945                                                NaN  ...
# 54946                                                NaN  ...
#
#                                                  Aspect1  Count  \
# 0      ['logic', 'satisfiability', 'logics', 'clause'...    138
# 1      ['logic', 'satisfiability', 'logics', 'clause'...    138
# 2      ['logic', 'satisfiability', 'logics', 'clause'...    138
# 3      ['logic', 'satisfiability', 'logics', 'clause'...    138
# 4      ['data', 'learning', 'models', 'model', 'train...  20553
# ...                                                  ...    ...
# 54942  ['visual', 'multimodal', 'reasoning', 'vision'...    376
# 54943  ['dependency', 'syntactic', 'parsing', 'morpho...     67
# 54944  ['logic', 'satisfiability', 'logics', 'clause'...    138
# 54945  ['data', 'learning', 'models', 'model', 'train...  20553
# 54946  ['data', 'learning', 'models', 'model', 'train...  20553
#
#                                       Higher_Topic_Label  \
# 0      Reasoning and Problem-Solving with Logic, Lang...
# 1      Reasoning and Problem-Solving with Logic, Lang...
# 2      Reasoning and Problem-Solving with Logic, Lang...
# 3      Reasoning and Problem-Solving with Logic, Lang...
# 4                                                    NaN
# ...                                                  ...
# 54942           Multimodal Large Language Models (MLLMs)
# 54943        Natural Language Processing and Linguistics
# 54944  Reasoning and Problem-Solving with Logic, Lang...
# 54945                                                NaN
# 54946                                                NaN
#
#                                   Highest_Topic_Label  \
# 0       Artificial Intelligence and Reasoning Systems
# 1       Artificial Intelligence and Reasoning Systems
# 2       Artificial Intelligence and Reasoning Systems
# 3       Artificial Intelligence and Reasoning Systems
# 4                                                 NaN
# ...                                               ...
# 54942  Multimodal Learning and Vision-Language Models
# 54943                     Natural Language Processing
# 54944   Artificial Intelligence and Reasoning Systems
# 54945                                             NaN
# 54946                                             NaN
#
#                                  Human_Readable_Topic  \
# 0        Formal Reasoning and Satisfiability in Logic
# 1        Formal Reasoning and Satisfiability in Logic
# 2        Formal Reasoning and Satisfiability in Logic
# 3        Formal Reasoning and Satisfiability in Logic
# 4           Multimodal Models for Image-Text Analysis
# ...                                               ...
# 54942        Multimodal Large Language Models (MLLMs)
# 54943  Syntactic Parsing and Language Change Analysis
# 54944    Formal Reasoning and Satisfiability in Logic
# 54945       Multimodal Models for Image-Text Analysis
# 54946       Multimodal Models for Image-Text Analysis
#
#                                                    Name  \
# 0      57_satisfiability_semantics_unsatisfiable_logics
# 1      57_satisfiability_semantics_unsatisfiable_logics
# 2      57_satisfiability_semantics_unsatisfiable_logics
# 3      57_satisfiability_semantics_unsatisfiable_logics
# 4          -1_features_classification_learning_datasets
# ...                                                 ...
# 54942              13_multimodal_visual_captioning_mllm
# 54943            131_parsers_treebanks_treebank_parsing
# 54944  57_satisfiability_semantics_unsatisfiable_logics
# 54945      -1_features_classification_learning_datasets
# 54946      -1_features_classification_learning_datasets
#
#                                           Representation  \
# 0      ['satisfiability', 'semantics', 'unsatisfiable...
# 1      ['satisfiability', 'semantics', 'unsatisfiable...
# 2      ['satisfiability', 'semantics', 'unsatisfiable...
# 3      ['satisfiability', 'semantics', 'unsatisfiable...
# 4      ['features', 'classification', 'learning', 'da...
# ...                                                  ...
# 54942  ['multimodal', 'visual', 'captioning', 'mllm',...
# 54943  ['parsers', 'treebanks', 'treebank', 'parsing'...
# 54944  ['satisfiability', 'semantics', 'unsatisfiable...
# 54945  ['features', 'classification', 'learning', 'da...
# 54946  ['features', 'classification', 'learning', 'da...
#
#                                      Representative_Docs KeyBERT_Keywords_x  \
# 0      ['  We formulate discussion graph semantics of...                NaN
# 1      ['  We formulate discussion graph semantics of...                NaN
# 2      ['  We formulate discussion graph semantics of...                NaN
# 3      ['  We formulate discussion graph semantics of...                NaN
# 4      ['  With the significant advancements of Large...                NaN
# ...                                                  ...                ...
# 54942  ["  In production, multi-modal large language ...                NaN
# 54943  ["  Many studies have shown that human languag...                NaN
# 54944  ['  We formulate discussion graph semantics of...                NaN
# 54945  ['  With the significant advancements of Large...                NaN
# 54946  ['  With the significant advancements of Large...                NaN
#
#                                       KeyBERT_Keywords_y
# 0      [satisfiability, formalizations, logics, forma...
# 1      [satisfiability, formalizations, logics, forma...
# 2      [satisfiability, formalizations, logics, forma...
# 3      [satisfiability, formalizations, logics, forma...
# 4                                                    NaN
# ...                                                  ...
# 54942  [utterances, captioners, captioner, captioning...
# 54943  [corpus, lingual, multilinguals, linguistics, ...
# 54944  [satisfiability, formalizations, logics, forma...
# 54945                                                NaN
# 54946                                                NaN
#
# [54947 rows x 29 columns]

# %%
# Example: Assuming you have a separate list of documents
data = data_with_keywords.copy()
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

# Extract topics after filtering
# No need to split the 'KeyBERT_Keywords' column as it's already a list
topic_representations = data.groupby('Highest_Topic_Label')['KeyBERT_Keywords_y'].apply(lambda x: x.iloc[0])
topics = topic_representations.tolist()

# Calculate Topic Diversity
def calculate_topic_diversity(topics):
    unique_words = set()
    total_words = 0

    for topic in topics:
        unique_words.update(topic)  # Add words to the unique set
        total_words += len(topic)   # Count total words in all topics

    # Topic diversity is the proportion of unique words to total words
    topic_diversity = len(unique_words) / total_words if total_words > 0 else 0
    return topic_diversity

# Calculate topic diversity
topic_diversity = calculate_topic_diversity(topics)

# Display the topic diversity score
print(f"\nTopic Diversity: {topic_diversity}")
# Out:
# Topic Diversity: 0.69

# %% [markdown]
# Topic Coherence

# %%
import os
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
import pandas as pd

# Disable Hugging Face tokenizers parallelism to avoid the warning
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Assuming 'processed_docs' is a list of tokenized documents from the previous code
# Create a Gensim dictionary from the processed documents
dictionary = Dictionary(processed_docs)

# Initialize a list to store the per-topic coherence c_v scores
per_topic_coherence_cv = []

# Calculate coherence for each topic in 'topics'
for topic in topics:
    # Create a list containing just the current topic
    current_topic = [topic]
    
    # Initialize the CoherenceModel for the current topic using 'c_v'
    coherence_model_cv = CoherenceModel(topics=current_topic, texts=processed_docs, dictionary=dictionary, coherence='c_v')
    
    # Compute the c_v coherence score
    coherence_cv = coherence_model_cv.get_coherence()
    print(f"Current topic: {current_topic}")
    print(f"Coherence c_v: {coherence_cv}")
    
    # Append the c_v score to the list
    per_topic_coherence_cv.append(coherence_cv)
    
# Create a DataFrame to display the results
results = pd.DataFrame({
    "Third_Level_Topic_Label": topic_representations.index,  # Use topic labels from topic_representations
    "Keywords": topic_representations.values,  # Keywords from earlier processing
    "Coherence c_v": per_topic_coherence_cv,  # Coherence scores
})

# Display the results
print(results)

# Save the results to a CSV file
results.to_csv('Third_Level_Topic_coherence.csv', index=False)
# Out:
# Current topic: [['crisistransformers', 'webnews', 'crises', 'disasters', 'tweets', 'twitter', 'crisisfacts', 'microblogs', 'semantic', 'thematic']]
# Coherence c_v: 0.29306551466275194
# Current topic: [['lasso', 'lassoglm', 'optimizations', 'optimizer', 'optimizers', 'penalized', 'penalizes', 'optimizes', 'regularization', 'penalize']]
# Coherence c_v: 0.1462274503128631
# Current topic: [['imaging', 'phases', 'microscopy', 'optics', 'photonics', 'nanobeamnn', 'optimizers', 'phase', 'microscope', 'reflectance']]
# Coherence c_v: 0.22956213085342
# Current topic: [['learns', 'memorization', 'attentional', 'classifiers', 'perceptrons', 'attention', 'attentions', 'recognition', 'softmax', 'neural']]
# Coherence c_v: 0.28350375596069355
# Current topic: [['adversarial', 'adversarially', 'dversarial', 'attackgnn', 'deepnet', 'attacks', 'imagenet', 'classifier', 'classifiers', 'badnet']]
# Coherence c_v: 0.33027303611365977
# Current topic: [['fisheries', 'fishing', 'sportfishing', 'fish', 'overfishing', 'lure', 'wildlife', 'anglers', 'ecology', 'trawling']]
# Coherence c_v: 0.6096775179357088
# Current topic: [['ais', 'automation', 'ai', 'hazards', 'cybersecurity', 'accidents', 'developments', 'automate', 'autonomous', 'safeguards']]
# Coherence c_v: 0.300364955786877
# Current topic: [['ai', 'intelligences', 'tasking', 'intelligence', 'intelligibility', 'automation', 'sensemaking', 'automated', 'cognition', 'automate']]
# Coherence c_v: 0.3644087370534192
# Current topic: [['software', 'dataflows', 'intel', 'implementations', 'applications', 'programmable', 'runtime', 'workflows', 'dataflow', 'features']]
# Coherence c_v: 0.3165818684501508
# Current topic: [['supervised', 'classifiers', 'classifier', 'learns', 'classify', 'classifying', 'classification', 'datasets', 'ai', 'annotators']]
# Coherence c_v: 0.5020210063714032
# Current topic: [['satisfiability', 'formalizations', 'logics', 'formalization', 'formalisation', 'formalized', 'formalizing', 'unsatisfiability', 'propositional', 'formalize']]
# Coherence c_v: 0.1403837921272811
# Current topic: [['deepvision', 'videodrafter', 'videographer', 'sceneflow', 'videopoet', 'videos', 'videoscore', 'renderings', 'rendering', 'imagenetvid']]
# Coherence c_v: 0.18904854838361648
# Current topic: [['musicological', 'musicology', 'genres', 'musicinstruct', 'musicxml', 'musicality', 'musics', 'musically', 'musictheorybench', 'musicgen']]
# Coherence c_v: 0.19833552478289776
# Current topic: [['datasets', 'gan', 'dataset', 'gans', 'adversarial', 'data', 'rnns', 'rnn', 'autoencoders', 'ehrs']]
# Coherence c_v: 0.4373331274094105
# Current topic: [['enrolled', 'curriculum', 'students', 'curriculums', 'tutoring', 'student', 'study', 'tutors', 'tutorly', 'assessments']]
# Coherence c_v: 0.43077906744367633
# Current topic: [['astroinformatics', 'astrophysical', 'cosmology', 'cosmological', 'cosmologies', 'galaxies', 'supernova', 'astrophysicists', 'subgalactic', 'cosmologically']]
# Coherence c_v: 0.3072948226946976
# Current topic: [['audiogram', 'recordings', 'audios', 'audio', 'microphone', 'soundspaces', 'acoustical', 'audiological', 'recording', 'voice']]
# Coherence c_v: 0.26168582656580996
# Current topic: [['radar', 'radars', 'radarocc', 'autopilot', 'platooning', 'transmit', 'platoons', 'maneuvers', 'signalized', 'planning']]
# Coherence c_v: 0.27200634945373503
# Current topic: [['classifiers', 'classifier', 'classifying', 'keywords', 'classification', 'sentiment', 'classify', 'predictive', 'linguistic', 'categorization']]
# Coherence c_v: 0.48109315751456627
# Current topic: [['epidemic', 'epidemics', 'outbreak', 'outbreaks', 'spreading', 'worm', 'pathogen', 'pathogens', 'virus', 'viral']]
# Coherence c_v: 0.49012051216418745
# Current topic: [['interventions', 'efficacy', 'effectiveness', 'analyses', 'interventional', 'interventionally', 'outcomes', 'intervention', 'procedures', 'modelling']]
# Coherence c_v: 0.44020905480092926
# Current topic: [['synchronization', 'lyapunov', 'synchronize', 'dynamics', 'chaotic', 'rhythms', 'chaos', 'oscillatory', 'bifurcation', 'deterministic']]
# Coherence c_v: 0.3280361538916383
# Current topic: [['bioinformatics', 'genomics', 'multiomics', 'genomic', 'proteinengine', 'proteinlmdataset', 'transcriptomics', 'proteinworkshop', 'pathogens', 'transcriptomic']]
# Coherence c_v: 0.2545143755649529
# Current topic: [['linguistics', 'phonetic', 'linguists', 'protolanguage', 'linguistic', 'corpus', 'vocabularies', 'phonology', 'languages', 'lexicostatistics']]
# Coherence c_v: 0.4371718087572275
# Current topic: [['computational', 'qmls', 'implementations', 'algorithms', 'quantumleak', 'computing', 'classification', 'qml', 'algorithmic', 'computationally']]
# Coherence c_v: 0.3159119740228222
# Current topic: [['imagenet', 'cnns', 'cnn', 'recognizing', 'supervised', 'recognition', 'inception', 'features', 'autoencoders', 'classifiers']]
# Coherence c_v: 0.4301840087947353
# Current topic: [['posture', 'kinematic', 'pose', 'skeleton', 'poses', 'routines', 'kinematics', 'motions', 'joints', 'posing']]
# Coherence c_v: 0.38894549895325914
# Current topic: [['conversational', 'chatbots', 'conversations', 'dialogues', 'conversation', 'dialog', 'communicating', 'dialogue', 'discusses', 'chatbot']]
# Coherence c_v: 0.6287732430125502
# Current topic: [['adversarial', 'adversarially', 'classifiers', 'classifier', 'supervised', 'malware', 'classification', 'gans', 'evading', 'datasets']]
# Coherence c_v: 0.5320094120745542
# Current topic: [['clusterings', 'clusters', 'cluster', 'clustering', 'clusterability', 'clustered', 'pagerank', 'nodes', 'hierarchicalclustering', 'dbscan']]
# Coherence c_v: 0.3953392315921359
# Current topic: [['supervised', 'benchmarks', 'benchmark', 'classification', 'classifying', 'bandwidths', 'datasets', 'features', 'regularization', 'kernel']]
# Coherence c_v: 0.35333999888207523
# Current topic: [['banditq', 'bandit', 'reinforcement', 'strategies', 'bandits', 'strategic', 'strategy', 'optimizes', 'heuristics', 'strategically']]
# Coherence c_v: 0.43633064323685405
# Current topic: [['classifier', 'classifiers', 'inspection', 'classification', 'classifying', 'classify', 'inspections', 'recognition', 'svm', 'features']]
# Coherence c_v: 0.47801179114256903
# Current topic: [['cluster', 'clustering', 'clusterqat', 'clusters', 'classification', 'supervised', 'optimizer', 'classifier', 'imagenet', 'optimize']]
# Coherence c_v: 0.3347263777346422
# Current topic: [['backpropagation', 'gradients', 'tensorflow', 'classifiers', 'benchmarks', 'subgradients', 'trainability', 'optimisers', 'optimizers', 'classifier']]
# Coherence c_v: 0.3501612134624632
# Current topic: [['inceptionresnet', 'prostate', 'imagenet', 'segmentation', 'segmentations', 'cnn', 'deepmedic', 'cnns', 'segmental', 'imagen']]
# Coherence c_v: 0.28141287765512285
# Current topic: [['transistors', 'transistor', 'circuits', 'circuitnet', 'circuitgnn', 'circuitsynth', 'circuitry', 'circuitvae', 'electronics', 'semiconductor']]
# Coherence c_v: 0.2887029972781273
# Current topic: [['inversion', 'inverting', 'inverses', 'operators', 'inverse', 'implementations', 'invertibility', 'operator', 'inverted', 'normalization']]
# Coherence c_v: 0.32315574120827495
# Current topic: [['qam', 'apsk', 'iot', 'qos', 'lte', 'sdn', 'qoe', 'wlan', 'bandwidth', 'qmix']]
# Coherence c_v: 0.2820219638498801
# Current topic: [['ontologies', 'ontological', 'ontology', 'terminologies', 'ontologically', 'semantic', 'ontologizing', 'taxonomy', 'schemas', 'schema']]
# Coherence c_v: 0.3284192302743782
# Current topic: [['forecaster', 'forecast', 'forecasts', 'forecasting', 'forecasters', 'weatherformer', 'meteorological', 'climateq', 'subseasonalclimateusa', 'predicting']]
# Coherence c_v: 0.38057216206027356
# Current topic: [['classifiers', 'classifier', 'classify', 'implementations', 'classifying', 'classification', 'rnns', 'learns', 'classifications', 'autoencoders']]
# Coherence c_v: 0.3372475386381001
# Current topic: [['deepeyenet', 'vision', 'retinaface', 'retina', 'eyeformer', 'macular', 'retinal', 'cnns', 'datasets', 'inception']]
# Coherence c_v: 0.2539496147427446
# Current topic: [['classifiers', 'classifier', 'supervised', 'classifying', 'classification', 'discriminated', 'classify', 'categorise', 'categorizes', 'discriminating']]
# Coherence c_v: 0.3757245980727836
# Current topic: [['turbulent', 'turbulence', 'aerodynamics', 'aerodynamic', 'flows', 'simulations', 'reynolds', 'simulators', 'flow', 'tensorflow']]
# Coherence c_v: 0.41119669442956486
# Current topic: [['gans', 'gan', 'projectedgan', 'generative', 'cyclegan', 'autoencoders', 'codegan', 'dcgan', 'asymmetricgan', 'imagenet']]
# Coherence c_v: 0.40801563504601146
# Current topic: [['modeling', 'modelling', 'curvatures', 'learns', 'dynamics', 'models', 'surfaces', 'curvature', 'nonlinear', 'shapes']]
# Coherence c_v: 0.36339524990181876
# Current topic: [['graphon', 'graphsage', 'graphssm', 'graphaware', 'graphs', 'graphbased', 'graphons', 'graphtrans', 'graphacl', 'graphrevoker']]
# Coherence c_v: 0.13268311709418112
# Current topic: [['imputations', 'missingness', 'imputation', 'datasets', 'fuzzy', 'criteria', 'attributes', 'classifiers', 'incompleteness', 'classifier']]
# Coherence c_v: 0.26992354158079424
# Current topic: [['activitynet', 'monitoring', 'sensor', 'iot', 'activity', 'automate', 'datasets', 'dataset', 'sensing', 'accelerometers']]
# Coherence c_v: 0.34869145190391215
# Current topic: [['features', 'affectnet', 'emotions', 'emotion', 'classifiers', 'svm', 'classifier', 'recognizing', 'classifying', 'affective']]
# Coherence c_v: 0.4650339177525226
# Current topic: [['automl', 'automate', 'automating', 'automated', 'workflows', 'automation', 'workflow', 'classification', 'functionality', 'requirements']]
# Coherence c_v: 0.6373055740844035
# Current topic: [['humordb', 'chatbots', 'utterances', 'humour', 'humor', 'dialogues', 'corpus', 'text', 'wordnet', 'ai']]
# Coherence c_v: 0.2585011766782795
# Current topic: [['imaging', 'denoising', 'photography', 'photographs', 'bioimaging', 'upsampling', 'denoisers', 'bioimage', 'denoiser', 'reconstructing']]
# Coherence c_v: 0.2002318122162765
# Current topic: [['kalmannet', 'modelling', 'systems', 'predictability', 'models', 'adaptive', 'modeling', 'optimisers', 'uncertainties', 'adaptively']]
# Coherence c_v: 0.26930996735186835
# Current topic: [['cooperation', 'influence', 'strategies', 'communication', 'influencer', 'coordination', 'social', 'reciprocity', 'behaviors', 'dissemination']]
# Coherence c_v: 0.4390060374608752
# Current topic: [['annotating', 'annotators', 'coreference', 'annotations', 'annotation', 'corpus', 'annotator', 'annotates', 'supervised', 'semantic']]
# Coherence c_v: 0.5105383774171087
# Current topic: [['adversarial', 'voice', 'speech', 'attacks', 'spoofing', 'attacker', 'utterances', 'attack', 'adversary', 'spoof']]
# Coherence c_v: 0.5101353496776474
# Current topic: [['retrievals', 'hashing', 'retrieval', 'keywords', 'cataloging', 'indexing', 'searches', 'pagerank', 'searcher', 'cataloguing']]
# Coherence c_v: 0.32556140275140477
# Current topic: [['tweets', 'hoaxpedia', 'newsguard', 'snopes', 'newsclaims', 'credibility', 'newsclippings', 'journalism', 'news', 'journalistic']]
# Coherence c_v: 0.21619996200430416
# Current topic: [['recipes', 'renewable', 'recipemc', 'recipedb', 'chef', 'recipe', 'sustainability', 'sustainable', 'cooking', 'ai']]
# Coherence c_v: 0.3000179616644808
# Current topic: [['toolflow', 'toolkits', 'annotators', 'slots', 'annotations', 'annotating', 'languageprocessing', 'toolsets', 'codeptms', 'implementations']]
# Coherence c_v: 0.40006399186013236
# Current topic: [['learns', 'retraining', 'learnt', 'retrain', 'memorizer', 'relearning', 'memorization', 'learning', 'memorize', 'memorizing']]
# Coherence c_v: 0.27285594255501155
# Current topic: [['classifiers', 'boosting', 'classifier', 'boost', 'treeshap', 'forest', 'forests', 'classification', 'ensembles', 'classifications']]
# Coherence c_v: 0.44314199974610896
# Current topic: [['classifier', 'activelab', 'classifiers', 'classification', 'datasets', 'supervised', 'boosting', 'classify', 'detects', 'dataset']]
# Coherence c_v: 0.4433510792239913
# Current topic: [['predicting', 'datamodels', 'forecasting', 'datasets', 'classifiers', 'prediction', 'regressions', 'classifier', 'forecasters', 'classification']]
# Coherence c_v: 0.3001680441892889
# Current topic: [['compression', 'benchmarking', 'classifiers', 'benchmarks', 'datasets', 'optimisers', 'benchmark', 'compressed', 'classifier', 'classification']]
# Coherence c_v: 0.3943259166523795
# Current topic: [['classifiers', 'classifier', 'classification', 'classifying', 'classifications', 'classify', 'datasets', 'misclassifications', 'svm', 'misclassification']]
# Coherence c_v: 0.5955719608142434
# Current topic: [['implementations', 'oracles', 'protocols', 'procedures', 'datasets', 'implementation', 'algorithms', 'oracle', 'reproducibility', 'distributed']]
# Coherence c_v: 0.32721846957651674
# Current topic: [['bioinformatics', 'patterns', 'spm', 'preprocessors', 'lifecycle', 'workflows', 'datasets', 'workflow', 'databases', 'dataset']]
# Coherence c_v: 0.2923463336631507
# Current topic: [['manifolds', 'manifold', 'supervised', 'metrics', 'clustering', 'geodesics', 'riemannian', 'metric', 'classification', 'clustertree']]
# Coherence c_v: 0.5086992005913125
# Current topic: [['tensorflow', 'pinn', 'backpropagation', 'optimizers', 'pinns', 'nonlinear', 'rnns', 'dpinn', 'pinnsformer', 'simulation']]
# Coherence c_v: 0.2691978756349693
# Current topic: [['fetal', 'supervised', 'mapping', 'inception', 'benchmarking', 'automate', 'cnn', 'fetus', 'pretraining', 'mapped']]
# Coherence c_v: 0.25434315367947125
# Current topic: [['tweets', 'abuseanalyzer', 'mitigation', 'keywords', 'classifier', 'mitigating', 'corpus', 'nlp', 'threats', 'svm']]
# Coherence c_v: 0.4312995837340418
# Current topic: [['learns', 'pretraining', 'curriculum', 'training', 'learners', 'distillation', 'learner', 'trained', 'learnt', 'datasets']]
# Coherence c_v: 0.3556063798523736
# Current topic: [['robotics', 'cooperative', 'robot', 'cooperatively', 'robots', 'robotic', 'protocols', 'implementations', 'coordination', 'cooperation']]
# Coherence c_v: 0.45902819665824557
# Current topic: [['electromyographic', 'exoskeletons', 'electromyography', 'neurorobotics', 'postures', 'gestures', 'posture', 'amputees', 'gesturing', 'gestureprint']]
# Coherence c_v: 0.3662381447234958
# Current topic: [['utterances', 'captioners', 'captioner', 'captioning', 'attention', 'attentional', 'speech', 'dialogues', 'verbalize', 'vocabularies']]
# Coherence c_v: 0.24576446736689106
# Current topic: [['supervised', 'dataset', 'matching', 'datasets', 'pedestrian', 'cnn', 'retrieval', 'recognize', 'pedestrians', 'features']]
# Coherence c_v: 0.29691685202061857
# Current topic: [['cardiovascular', 'cardiac', 'macrovascular', 'arterial', 'artery', 'arteries', 'coronary', 'bloodstream', 'vascular', 'diagnostics']]
# Coherence c_v: 0.4144428414355229
# Current topic: [['corpus', 'lingual', 'multilinguals', 'linguistics', 'macrolanguage', 'lingua', 'linguistic', 'multilingual', 'bilingual', 'multilinguality']]
# Coherence c_v: 0.30934338517937665
# Current topic: [['auctioning', 'bidding', 'auction', 'bids', 'auctionsdecrease', 'auctions', 'auctioneer', 'auctionimpacts', 'bidders', 'advertisements']]
# Coherence c_v: 0.5603626532936868
# Current topic: [['optimisation', 'metaheuristics', 'automate', 'automating', 'programming', 'scheduling', 'optimizations', 'heuristics', 'workflows', 'automation']]
# Coherence c_v: 0.38410502475417463
# Current topic: [['intercity', 'dispatching', 'transportation', 'shuttles', 'optimisers', 'autonomous', 'taxis', 'mobility', 'vehicles', 'automation']]
# Coherence c_v: 0.390316108714989
# Current topic: [['bayesian', 'procedures', 'tutorials', 'probabilistic', 'implementations', 'routines', 'modelling', 'methodology', 'documentation', 'analyses']]
# Coherence c_v: 0.23887301717827336
# Current topic: [['photovoltaics', 'photovoltaic', 'renewables', 'forecasting', 'renewable', 'forecaster', 'pv', 'forecast', 'forecasters', 'forecasts']]
# Coherence c_v: 0.5024327679739782
# Current topic: [['clustering', 'cluster', 'algorithms', 'modelling', 'clusterability', 'algorithmic', 'modelled', 'clusters', 'classification', 'probabilistic']]
# Coherence c_v: 0.33364869603785635
# Current topic: [['sampling', 'simulations', 'samples', 'algorithms', 'modeling', 'simulation', 'stochastic', 'samplers', 'mcmc', 'lmcs']]
# Coherence c_v: 0.4188822972132808
# Current topic: [['functionality', 'features', 'autoencoders', 'datasets', 'softmax', 'autoencoder', 'svm', 'supervised', 'personalization', 'recommender']]
# Coherence c_v: 0.2775753488750409
# Current topic: [['microgrids', 'microgrid', 'optimizers', 'optimsation', 'optimisation', 'automate', 'optimizes', 'utility', 'optimizing', 'automation']]
# Coherence c_v: 0.261201950089215
# Current topic: [['supervised', 'landforms', 'datasets', 'cropnet', 'watershed', 'classification', 'vegetation', 'dataset', 'lowlands', 'forests']]
# Coherence c_v: 0.28862872918027294
# Current topic: [['automate', 'robot', 'robotized', 'ai', 'robotic', 'robotics', 'robotscript', 'automation', 'conceptnet', 'planning']]
# Coherence c_v: 0.3905632842705071
# Current topic: [['classifying', 'classification', 'supervised', 'classify', 'classifier', 'classifiers', 'classifications', 'datasets', 'labeled', 'dataset']]
# Coherence c_v: 0.6378893744539151
# Current topic: [['healthgat', 'biomarker', 'biobank', 'datasets', 'classifier', 'classification', 'classifiers', 'dataset', 'diabetes', 'autoprognosis']]
# Coherence c_v: 0.3262607952955759
# Current topic: [['epileptic', 'epilepsy', 'electroencephalogram', 'seizures', 'electroencephalograms', 'seizure', 'eegencoder', 'electroencephalografic', 'electroencephalographic', 'electroencephalography']]
# Coherence c_v: 0.34436538797162614
# Current topic: [['datasets', 'classification', 'classifiers', 'detections', 'nasa', 'features', 'supervised', 'dataset', 'classifier', 'spacecraft']]
# Coherence c_v: 0.36343074177571627
# Current topic: [['speechcodes', 'utterances', 'speechlms', 'languagenet', 'speechlm', 'speechdat', 'speechx', 'corpus', 'audioset', 'utterance']]
# Coherence c_v: 0.20406395994305798
# Current topic: [['algorithms', 'regularization', 'matrix', 'vectorized', 'matrices', 'submatrix', 'regularized', 'optimizers', 'normalization', 'optimizations']]
# Coherence c_v: 0.3021877206440254
# Current topic: [['migratory', 'migration', 'urbanization', 'mobility', 'mobilitygpt', 'migrants', 'transportation', 'travel', 'moving', 'transport']]
# Coherence c_v: 0.23866914592868774
# Current topic: [['decoding', 'decoders', 'decoder', 'multiplexing', 'channels', 'encoder', 'encode', 'channel', 'wavenet', 'telecommunication']]
# Coherence c_v: 0.3925554844883178
#                               Third_Level_Topic_Label  \
# 0   AI and Data-Driven Approaches for Urban and Di...
# 1   Advanced Statistical and Machine Learning Methods
# 2   Advanced Technologies for Simulation, Sensing,...
# 3          Advances in Sequence Modeling and Learning
# 4   Adversarial Attacks and Vulnerabilities in AI ...
# ..                                                ...
# 95             Solar Activity Prediction and Analysis
# 96                        Speech and Audio Processing
# 97  Tensor and Matrix Methods for Data Representat...
# 98  Transportation Systems and Environmental Analy...
# 99          Wireless Technologies and Sensing Systems
#
#                                              Keywords  Coherence c_v
# 0   [crisistransformers, webnews, crises, disaster...       0.293066
# 1   [lasso, lassoglm, optimizations, optimizer, op...       0.146227
# 2   [imaging, phases, microscopy, optics, photonic...       0.229562
# 3   [learns, memorization, attentional, classifier...       0.283504
# 4   [adversarial, adversarially, dversarial, attac...       0.330273
# ..                                                ...            ...
# 95  [datasets, classification, classifiers, detect...       0.363431
# 96  [speechcodes, utterances, speechlms, languagen...       0.204064
# 97  [algorithms, regularization, matrix, vectorize...       0.302188
# 98  [migratory, migration, urbanization, mobility,...       0.238669
# 99  [decoding, decoders, decoder, multiplexing, ch...       0.392555
#
# [100 rows x 3 columns]

# %%
file_path = 'Third_Level_Topic_coherence.csv'  # Replace with your file path
data = pd.read_csv(file_path)
mean_score = data['Coherence c_v'].mean()
data['Coherence c_v'].mean()
mean_score
# Out:
# 0.35840321747998716
