# %%
# Topic Diversity
# Describe the details.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from keybert import KeyBERT
import nltk

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Load your dataset
file_path = 'Concatenated_First_Second_Step_BERTopic_Result.csv'  # Replace with your file path
data = pd.read_csv(file_path)

# Example: Assuming you have a separate list of documents
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return ' '.join(tokens)  # Join tokens back to a single string for KeyBERT

processed_docs = [preprocess(doc) for doc in documents]

# Initialize KeyBERT model
kw_model = KeyBERT()

# Group documents by 'Second_Level_Topic_Label'
grouped_docs = data.groupby('Highest_Topic_Label')['text'].apply(lambda texts: ' '.join(texts))

# Extract keywords per topic
def extract_keywords(text, model, num_keywords=10):
    keywords = model.extract_keywords(text, stop_words='english', top_n=num_keywords)
    return [keyword[0] for keyword in keywords]

topic_keywords = {}
for topic_label, docs in grouped_docs.items():
    processed_text = preprocess(docs)
    keywords = extract_keywords(processed_text, kw_model)
    topic_keywords[topic_label] = keywords

# Convert topic_keywords dictionary to DataFrame
keywords_df = pd.DataFrame(list(topic_keywords.items()), columns=['Highest_Topic_Label', 'KeyBERT_Keywords'])

# Merge the KeyBERT keywords back into the original dataset
data_with_keywords = pd.merge(data, keywords_df, on='Highest_Topic_Label', how='left')

# Display the resulting dataset with the KeyBERT keywords added
data_with_keywords
# Out:
# /home/yc656703/.local/lib/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# [nltk_data] Downloading package punkt to /home/yc656703/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yc656703/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /w0/tmp/slurm_yc656703.49958868/ipykernel_145262/1697083403.py:13: DtypeWarning: Columns (24,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)
#        Unnamed: 0                   id isRetweet isDeleted  \
# 0             3.0  1304875170860015617         f         f
# 1            11.0  1319496349092511744         t         f
# 2            12.0  1236502342121541632         t         f
# 3            13.0  1225835449379258368         t         f
# 4            14.0  1215247978966986752         f         f
# ...           ...                  ...       ...       ...
# 56323         NaN  1212165225748803585         t         f
# 56324         NaN  1212165147902578688         t         f
# 56325         NaN  1212165019053494272         t         f
# 56326         NaN  1319484210101379072         t         f
# 56327         NaN  1319384118849949702         f         f
#
#                    device  favorites  retweets                 date isFlagged  \
# 0      Twitter for iPhone      80527     23502  2020-09-12 20:10:58         f
# 1      Twitter for iPhone          0      8921  2020-10-23 04:30:19         f
# 2      Twitter for iPhone          0      8681  2020-03-08 04:01:46         f
# 3      Twitter for iPhone          0      7679  2020-02-07 17:35:20         f
# 4      Twitter for iPhone      48510     11608  2020-01-09 12:24:31         f
# ...                   ...        ...       ...                  ...       ...
# 56323  Twitter for iPhone          0      7133  2020-01-01 00:14:45         f
# 56324  Twitter for iPhone          0      8034  2020-01-01 00:14:26         f
# 56325  Twitter for iPhone          0      5336  2020-01-01 00:13:56         f
# 56326  Twitter for iPhone          0      9869  2020-10-23 03:42:05         f
# 56327  Twitter for iPhone     176289     36001  2020-10-22 21:04:21         f
#
#                                                     text  ...  \
# 0      The Unsolicited Mail In Ballot Scam is a major...  ...
# 1                                            Eric Trump:  ...
# 2      GOPChairwoman: The economic boom continues! 27...  ...
# 3      Tom Fitton: Vindman's behavior is a scandal. H...  ...
# 4                                       Thank you Elise!  ...
# ...                                                  ...  ...
# 56323  heatherjones333: Congratulations Sleepy Joe! Y...  ...
# 56324  heatherjones333: DEAR STUPID PEOPLE- PEACE IS ...  ...
# 56325  heatherjones333: 'We Have Taken Appropriate Fo...  ...
# 56326  Elise Stefanik: President real Donald Trump ex...  ...
# 56327  Just signed an order to support the workers of...  ...
#
#                                            Matched_Topic  \
# 0                  Mail-In Voting and Election Integrity
# 1                                             Eric Trump
# 2           RNC/GOP Chairwoman's Tweets and Endorsements
# 3      Tom Fitton on Mueller Probe and Russiagate Sca...
# 4                                      Wishes and Thanks
# ...                                                  ...
# 56323                                                NaN
# 56324                                                NaN
# 56325                                                NaN
# 56326                                                NaN
# 56327                                                NaN
#
#                                  Highest_Topic_Label Unnamed: 0.1  \
# 0           US Election Integrity and Voting Process          NaN
# 1                            Donald Trump and Family          NaN
# 2                   US Politics and Republican Party          NaN
# 3           US Politics and Government Controversies          NaN
# 4      Expressions of Emotion and Social Interaction          NaN
# ...                                              ...          ...
# 56323                         Criticism of Joe Biden      21168.0
# 56324                                            NaN      21169.0
# 56325                                  Law and Order      21170.0
# 56326       US Politics and Government Controversies      21171.0
# 56327             US Economic Policy and Performance      21172.0
#
#       Unnamed: 0_x                         Second_Step_Topic_Name  \
# 0              NaN                                            NaN
# 1              NaN                                            NaN
# 2              NaN                                            NaN
# 3              NaN                                            NaN
# 4              NaN                                            NaN
# ...            ...                                            ...
# 56323      56563.0                 122_sleepy_joe_obama_exhausted
# 56324      56564.0             365_sweden_norway_denmark_lockdown
# 56325      56565.0              263_safety_security_danger_safely
# 56326      56567.0                 35_biden_joe_bernie_corruption
# 56327      56569.0  176_congress_economy_infrastructure_americans
#
#                               Second_Step_Topic_Keywords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 56323  sleepy, joe, obama, exhausted, bernie, shamble...
# 56324  sweden, norway, denmark, lockdown, immigrants,...
# 56325  safety, security, danger, safely, concerns, vi...
# 56326  biden, joe, bernie, corruption, corrupt, sande...
# 56327  congress, economy, infrastructure, americans, ...
#
#                         Second_Step_Topic_Representation  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 56323  sleepy (0.49), joe (0.45), obama (0.37), exhau...
# 56324  sweden (0.44), norway (0.38), denmark (0.35), ...
# 56325  safety (0.50), security (0.40), danger (0.39),...
# 56326  biden (0.53), joe (0.41), bernie (0.34), corru...
# 56327  congress (0.42), economy (0.35), infrastructur...
#
#                          Second_Step_Representative_Docs Unnamed: 0_y  \
# 0                                                    NaN          NaN
# 1                                                    NaN          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 56323  Sleepy Joe Hiden’ was acknowledged by his own ...        122.0
# 56324  Michael Goodwin, New York Post: “Trump’s peace...        365.0
# 56325  We are doing very precise Medical Screenings a...        263.0
# 56326  Joe Biden is a corrupt politician and he’s COM...         35.0
# 56327  We want our companies to hire &amp, grow in AM...        176.0
#
#                                         KeyBERT_Keywords
# 0      [ballots, voteridplease, voter, elections, bal...
# 1      [scavino, trumpfor, presidential, realdonaldtr...
# 2      [congresswomen, rand, candidates, congresswoma...
# 3      [flynn, indictments, mueller, congressmen, spy...
# 4      [elderly, honor, responders, aid, charity, car...
# ...                                                  ...
# 56323  [biden, realdonaldtrump, presidential, preside...
# 56324                                                NaN
# 56325  [nypd, deputies, mayor, protestors, officers, ...
# 56326  [flynn, indictments, mueller, congressmen, spy...
# 56327  [reaganomics, reagan, trumpenomics, booming, r...
#
# [56328 rows x 34 columns]

# %%
# Example: Assuming you have a separate list of documents
data = data_with_keywords.copy()
documents = data['text']

# Preprocess documents
stop_words = set(stopwords.words('english'))

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [token for token in tokens if token.isalpha() and token not in stop_words]
    return tokens

processed_docs = [preprocess(doc) for doc in documents]

# Extract topics after filtering
# No need to split the 'KeyBERT_Keywords' column as it's already a list
topic_representations = data.groupby('Highest_Topic_Label')['KeyBERT_Keywords'].apply(lambda x: x.iloc[0])
topics = topic_representations.tolist()

# Calculate Topic Diversity
def calculate_topic_diversity(topics):
    unique_words = set()
    total_words = 0

    for topic in topics:
        unique_words.update(topic)  # Add words to the unique set
        total_words += len(topic)   # Count total words in all topics

    # Topic diversity is the proportion of unique words to total words
    topic_diversity = len(unique_words) / total_words if total_words > 0 else 0
    return topic_diversity

# Calculate topic diversity
topic_diversity = calculate_topic_diversity(topics)

# Display the topic diversity score
print(f"\nTopic Diversity: {topic_diversity}")
# Out:
# Topic Diversity: 0.7582322357019065

# %% [markdown]
# Topic Coherence

# %%
import os
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary
import pandas as pd

# Disable Hugging Face tokenizers parallelism to avoid the warning
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Assuming 'processed_docs' is a list of tokenized documents from the previous code
# Create a Gensim dictionary from the processed documents
dictionary = Dictionary(processed_docs)

# Initialize a list to store the per-topic coherence c_v scores
per_topic_coherence_cv = []

# Calculate coherence for each topic in 'topics'
for topic in topics:
    # Create a list containing just the current topic
    current_topic = [topic]
    
    # Initialize the CoherenceModel for the current topic using 'c_v'
    coherence_model_cv = CoherenceModel(topics=current_topic, texts=processed_docs, dictionary=dictionary, coherence='c_v')
    
    # Compute the c_v coherence score
    coherence_cv = coherence_model_cv.get_coherence()
    print(f"Current topic: {current_topic}")
    print(f"Coherence c_v: {coherence_cv}")
    
    # Append the c_v score to the list
    per_topic_coherence_cv.append(coherence_cv)
    
# Create a DataFrame to display the results
results = pd.DataFrame({
    "Highest_Topic_Label": topic_representations.index,  # Use topic labels from topic_representations
    "Keywords": topic_representations.values,  # Keywords from earlier processing
    "Coherence c_v": per_topic_coherence_cv,  # Coherence scores
})

# Display the results
print(results)

# Save the results to a CSV file
results.to_csv('Third_Level_Topic_coherence.csv', index=False)
# Out:
# Current topic: [['presidential', 'administrations', 'pharmacy', 'presidency', 'bipartisan', 'pharmaceutical', 'president', 'pharm', 'prescription', 'pharma']]
# Coherence c_v: 0.33027072416076575
# Current topic: [['entrepreneurs', 'entrepreneur', 'entrepreneurship', 'succeed', 'success', 'confidence', 'roy', 'entrepreneurial', 'flourishing', 'humble']]
# Coherence c_v: 0.33605158822068637
# Current topic: [['airlines', 'airports', 'airport', 'aviation', 'pilot', 'flights', 'airplane', 'pilots', 'flight', 'airplanes']]
# Coherence c_v: 0.27922930418501146
# Current topic: [['postal', 'washingtonpost', 'stamps', 'bezos', 'parcel', 'taxpayer', 'taxes', 'taxation', 'office', 'tax']]
# Coherence c_v: 0.21936922808729795
# Current topic: [['anthem', 'patriotism', 'allegiance', 'salutes', 'salute', 'honoring', 'protesting', 'protest', 'solidarity', 'proudly']]
# Coherence c_v: 0.37058835059001105
# Current topic: [['hampshire', 'nh', 'nc', 'greensboro', 'nhpolitics', 'carolina', 'dems', 'primaries', 'maine', 'nhmake']]
# Coherence c_v: 0.30317533100270466
# Current topic: [['autismsupport', 'autism', 'autismspeaks', 'vaccine', 'vaccines', 'vaccinations', 'nbsaphier', 'aspergers', 'autistic', 'fda']]
# Coherence c_v: 0.2660212397020817
# Current topic: [['pitchers', 'yankee', 'yankees', 'sox', 'nationals', 'phillies', 'mets', 'clemens', 'pitcher', 'astros']]
# Coherence c_v: 0.30705357620762175
# Current topic: [['vaccine', 'vaccines', 'vaccinations', 'vaccinated', 'pandemics', 'pandemic', 'epidemics', 'epidemic', 'covid', 'flu']]
# Coherence c_v: 0.3172635516872998
# Current topic: [['twitter', 'tweets', 'followers', 'follow', 'daily', 'aol', 'news', 'newspaper', 'lowlifes', 'stalker']]
# Coherence c_v: 0.28651123710220655
# Current topic: [['apprenticenbc', 'apprentice', 'apprentices', 'omar', 'contestant', 'letterman', 'omarosa', 'seth', 'emmy', 'cooper']]
# Coherence c_v: 0.42492806327011
# Current topic: [['sean', 'limbaugh', 'letterman', 'lettermans', 'donald', 'celeb', 'apprentice', 'seanspicer', 'connery', 'seandburke']]
# Coherence c_v: 0.30899421299381846
# Current topic: [['riots', 'protests', 'protest', 'protesters', 'protestors', 'unrest', 'protesting', 'uprising', 'rioters', 'protester']]
# Coherence c_v: 0.34163022748945526
# Current topic: [['climatechange', 'warming', 'climate', 'winters', 'tectonic', 'globalwarming', 'arctic', 'snowstorm', 'snowfall', 'snow']]
# Coherence c_v: 0.1983975300662462
# Current topic: [['marklevinshow', 'mark', 'markrucci', 'markknoller', 'dershowitz', 'joe', 'bretmichaels', 'abuse', 'shepard', 'pat']]
# Coherence c_v: 0.40776764425146517
# Current topic: [['mayor', 'foxnewspolitics', 'governors', 'governor', 'scandals', 'staten', 'donald', 'msnbc', 'politicians', 'trumps']]
# Coherence c_v: 0.4471918777106946
# Current topic: [['brennan', 'scandal', 'dnc', 'dems', 'politi', 'pols', 'cia', 'corrupt', 'corruption', 'spygate']]
# Coherence c_v: 0.3185773187482562
# Current topic: [['barack', 'obama', 'obamafraudulent', 'obamatrade', 'obamagate', 'obamas', 'barackobama', 'presidents', 'presidential', 'president']]
# Coherence c_v: 0.35651922381967316
# Current topic: [['biden', 'realdonaldtrump', 'presidential', 'presidents', 'joebiden', 'candidates', 'bernie', 'president', 'politicians', 'pollster']]
# Coherence c_v: 0.28775909555402285
# Current topic: [['polls', 'polling', 'pollsters', 'pollster', 'polled', 'ballots', 'elections', 'cnnpolitics', 'msnbc', 'election']]
# Coherence c_v: 0.3690630695172415
# Current topic: [['congresswomen', 'senators', 'senator', 'libby', 'senate', 'kamala', 'politicians', 'sanders', 'bernie', 'dems']]
# Coherence c_v: 0.2774330793638545
# Current topic: [['ahmadinejad', 'iranian', 'iranians', 'iran', 'tehran', 'fisa', 'ayatollah', 'fisacourt', 'detainees', 'benghazis']]
# Coherence c_v: 0.30798735777334246
# Current topic: [['bankrupt', 'bankruptcy', 'wig', 'bankrupted', 'hairstyle', 'tweets', 'like', 'bankrutcy', 'vanity', 'wonder']]
# Coherence c_v: 0.26387257181688195
# Current topic: [['race', 'blacks', 'negro', 'minorities', 'naacp', 'racial', 'cnnpolitics', 'hispanic', 'hispanics', 'whites']]
# Coherence c_v: 0.32998993791399905
# Current topic: [['scavino', 'trumpfor', 'presidential', 'realdonaldtrump', 'trumpnationalphiladelphia', 'presidenttrump', 'donald', 'trump', 'wrasmussen', 'president']]
# Coherence c_v: 0.33556132866385213
# Current topic: [['trumpu', 'realdonaldtrump', 'trumpforpresidemt', 'trumpophobes', 'trumpforpresident', 'donald', 'trumpster', 'donaldforpresident', 'trumpvlog', 'trumper']]
# Coherence c_v: 0.41557638882946923
# Current topic: [['rally', 'rallies', 'ohio', 'rallying', 'iowa', 'iowans', 'iowan', 'idaho', 'indiana', 'dayton']]
# Coherence c_v: 0.33127405493646156
# Current topic: [['conservatism', 'wsjpolitics', 'overturning', 'revolution', 'conservatives', 'liberalism', 'presidential', 'bannon', 'sanders', 'spygate']]
# Coherence c_v: 0.429367317668254
# Current topic: [['jacknicklaus', 'golfer', 'nicklaus', 'golfers', 'golfweek', 'pga', 'pgachampionship', 'golf', 'golfs', 'pgaalltheway']]
# Coherence c_v: 0.28083650312641
# Current topic: [['reagan', 'presidential', 'presidents', 'realdonaldtrump', 'president', 'republican', 'republicans', 'government', 'bush', 'trump']]
# Coherence c_v: 0.2761922788890843
# Current topic: [['debates', 'trumpforpresident', 'trumpforprez', 'realdonaldtrump', 'trumplican', 'donald', 'trumpvlog', 'trump', 'potus', 'jr']]
# Coherence c_v: 0.3747027067795326
# Current topic: [['rand', 'taxes', 'fiscal', 'taxpay', 'paychecks', 'irs', 'tariffs', 'biden', 'dems', 'paycheck']]
# Coherence c_v: 0.3633771550499848
# Current topic: [['dow', 'nasdaq', 'stocks', 'polls', 'markets', 'presidential', 'presidents', 'columnist', 'news', 'donald']]
# Coherence c_v: 0.2705530843408866
# Current topic: [['renewables', 'renewable', 'obama', 'coal', 'pipelines', 'tariffs', 'pipeline', 'epa', 'barack', 'democrats']]
# Coherence c_v: 0.35829978749524083
# Current topic: [['california', 'nra', 'wildfires', 'forests', 'suvs', 'gov', 'fires', 'forest', 'sheriffs', 'states']]
# Coherence c_v: 0.3201697378119359
# Current topic: [['wisconsin', 'wi', 'milwaukee', 'upstate', 'minnesota', 'congressional', 'mississippi', 'states', 'state', 'democrat']]
# Coherence c_v: 0.3178858371334134
# Current topic: [['elderly', 'honor', 'responders', 'aid', 'charity', 'care', 'grateful', 'healthcare', 'representative', 'providing']]
# Coherence c_v: 0.3771470467070036
# Current topic: [['foxandfriends', 'foxnews', 'foxand', 'fox', 'foxnation', 'mondays', 'snl', 'foxsports', 'cpacnews', 'daily']]
# Coherence c_v: 0.41160176285305383
# Current topic: [['spygate', 'obamagate', 'spying', 'snowden', 'spies', 'surveillance', 'nsa', 'spy', 'flynn', 'cia']]
# Coherence c_v: 0.2798320084823142
# Current topic: [['tomi', 'governor', 'katrina', 'hurricane', 'flooded', 'louisiana', 'fla', 'farmers', 'mayor', 'farms']]
# Coherence c_v: 0.372009038839297
# Current topic: [['pennsylvania', 'floridians', 'louisiana', 'florida', 'states', 'delaware', 'fl', 'statewide', 'state', 'indianapolis']]
# Coherence c_v: 0.3008086868533895
# Current topic: [['amendment', 'guns', 'virginia', 'constitution', 'liberty', 'nra', 'firearms', 'dems', 'va', 'firearm']]
# Coherence c_v: 0.33522652144320897
# Current topic: [['hillarycare', 'medicar', 'medicaid', 'medicare', 'obamacare', 'meadows', 'feds', 'healthcare', 'sanders', 'dems']]
# Coherence c_v: 0.30614025123989846
# Current topic: [['cadets', 'veterans', 'thanksgiving', 'honoring', 'graduation', 'holidays', 'ranchers', 'holiday', 'gratitude', 'salute']]
# Coherence c_v: 0.4606131880497025
# Current topic: [['hurricane', 'hurricanes', 'carolina', 'katrina', 'florida', 'governor', 'storms', 'fl', 'louisiana', 'storm']]
# Coherence c_v: 0.35244338961330024
# Current topic: [['transcripts', 'transcript', 'read', 'sunday', 'reference', 'michael', 'york', 'usa', 'wrong', 'goodwin']]
# Coherence c_v: 0.24541716326571295
# Current topic: [['abraham', 'edison', 'lincoln', 'benjamin', 'roosevelt', 'franklin', 'penny', 'neil', 'essentials', 'ralph']]
# Coherence c_v: 0.3007749639170288
# Current topic: [['iq', 'smarter', 'smartest', 'smarts', 'intellectual', 'smartwomen', 'intelligent', 'smart', 'donald', 'trump']]
# Coherence c_v: 0.27058074737698057
# Current topic: [['mattis', 'fired', 'resignation', 'kosovo', 'obama', 'administration', 'ambassador', 'serbia', 'trump', 'balkans']]
# Coherence c_v: 0.1715342520106104
# Current topic: [['kimfreethinker', 'pyongyang', 'nasa', 'astronauts', 'warmonger', 'administrations', 'kim', 'presidents', 'bergdahl', 'donald']]
# Coherence c_v: 0.36439407919397865
# Current topic: [['nypd', 'deputies', 'mayor', 'protestors', 'officers', 'congressmen', 'officer', 'policemen', 'congresswomen', 'sheriffs']]
# Coherence c_v: 0.2974961755458835
# Current topic: [['inmate', 'clemency', 'prison', 'sentenced', 'convicted', 'jr', 'jail', 'pardon', 'arrests', 'prisoners']]
# Coherence c_v: 0.21496108465902353
# Current topic: [['palm', 'beach', 'bocelli', 'fl', 'florida', 'nightclub', 'mansions', 'trump', 'donald', 'lavish']]
# Coherence c_v: 0.36059553282373136
# Current topic: [['macys', 'macy', 'shopgirlusa', 'shop', 'fragrances', 'shopping', 'cologne', 'apparel', 'retailers', 'fragrance']]
# Coherence c_v: 0.294655189152769
# Current topic: [['miss', 'missusa', 'missuniverse', 'pageants', 'pageant', 'contestant', 'contestants', 'maria', 'vegas', 'pageantwill']]
# Coherence c_v: 0.39547276986347335
# Current topic: [['breitbart', 'foxnews', 'msnbc', 'newsmax', 'tvnews', 'newsbusters', 'hannity', 'huffington', 'seanhannity', 'nbcnews']]
# Coherence c_v: 0.4122727097298883
# Current topic: [['donald', 'sugar', 'cola', 'coke', 'soda', 'coca', 'marx', 'trump', 'tweet', 'maker']]
# Coherence c_v: 0.20020604261223282
# Current topic: [['hostage', 'hostages', 'negotiate', 'negotiating', 'diplomat', 'captives', 'pompeo', 'diplomatic', 'vp', 'negotiations']]
# Coherence c_v: 0.41568962299543727
# Current topic: [['armenian', 'mirziyoyev', 'boris', 'aliyev', 'minister', 'petraeus', 'turnbull', 'general', 'azerbaijani', 'putin']]
# Coherence c_v: 0.3035925374063567
# Current topic: [['churchill', 'einstein', 'roosevelt', 'smarter', 'intelligence', 'intellectuals', 'common', 'stupidity', 'truman', 'theodore']]
# Coherence c_v: 0.40079747811125055
# Current topic: [['pledge', 'pledgeto', 'proud', 'patriotic', 'pledged', 'nyc', 'allegiance', 'anthem', 'pride', 'patriotism']]
# Coherence c_v: 0.3000232489017231
# Current topic: [['rnc', 'republican', 'christie', 'gop', 'convention', 'party', 'tampa', 'sarasota', 'fnc', 'fl']]
# Coherence c_v: 0.37715398641423814
# Current topic: [['congress', 'veto', 'senate', 'bipartisan', 'senators', 'section', 'reform', 'repeal', 'rnc', 'nra']]
# Coherence c_v: 0.3853767464273669
# Current topic: [['charities', 'charity', 'fundraising', 'donations', 'donors', 'donate', 'donated', 'politicians', 'campaigns', 'funding']]
# Coherence c_v: 0.30666653702530305
# Current topic: [['mueller', 'persecution', 'maga', 'dershowitz', 'judge', 'gregg', 'impeachment', 'witch', 'crack', 'discredited']]
# Coherence c_v: 0.36110991183180846
# Current topic: [['hank', 'condolences', 'eddie', 'daniels', 'andy', 'ripcharlie', 'dave', 'died', 'frank', 'yankees']]
# Coherence c_v: 0.3558299974192728
# Current topic: [['dealmaker', 'johnboehner', 'entrepreneurs', 'opportunities', 'cash', 'jobs', 'rich', 'finance', 'unselfishness', 'investments']]
# Coherence c_v: 0.42028972522221403
# Current topic: [['boring', 'bills', 'nfl', 'nba', 'tired', 'flags', 'viewers', 'debt', 'viewership', 'football']]
# Coherence c_v: 0.2783156036613013
# Current topic: [['daytona', 'jimmie', 'nascaronfox', 'nascarnac', 'nascar', 'racing', 'indy', 'ric', 'sharyl', 'races']]
# Coherence c_v: 0.2988748216399099
# Current topic: [['schneiderman', 'prosecutor', 'prosecutorial', 'crook', 'corrupt', 'testified', 'accused', 'corruption', 'misconduct', 'prosecute']]
# Coherence c_v: 0.27731028267645097
# Current topic: [['piersmorgan', 'piersmorganlive', 'piers', 'pierson', 'letterman', 'msnbc', 'snl', 'primetime', 'fallon', 'emmy']]
# Coherence c_v: 0.4324365454822881
# Current topic: [['katrina', 'governor', 'governors', 'mayors', 'governorship', 'caucus', 'mayor', 'hicks', 'trumponly', 'hillarysusans']]
# Coherence c_v: 0.4594758990342548
# Current topic: [['dbongino', 'mike', 'michael', 'mikeliberation', 'trumpvlog', 'tyson', 'karentalk', 'jackson', 'mikeandmike', 'krobbio']]
# Coherence c_v: 0.36162714552762554
# Current topic: [['maria', 'flotus', 'ivanka', 'bartiromo', 'florid', 'santa', 'tiffany', 'holiday', 'martha', 'gloria']]
# Coherence c_v: 0.3802825176176581
# Current topic: [['tomi', 'tom', 'donaldtrump', 'trumplasvegas', 'realdonaldtrump', 'trump', 'kerry', 'donald', 'bushpiggy', 'tomxconn']]
# Coherence c_v: 0.3483670930659635
# Current topic: [['jasoninthehouse', 'jason', 'robert', 'book', 'bestseller', 'books', 'strassel', 'bnbooks', 'kim', 'paperback']]
# Coherence c_v: 0.3652423076609024
# Current topic: [['trumpadvice', 'realdonaldtrump', 'trumpera', 'trumpfor', 'trumpforpresident', 'donaldtrumpforprez', 'donald', 'presidents', 'donaldforpresident', 'presidential']]
# Coherence c_v: 0.4092670533714342
# Current topic: [['chucktodd', 'chuck', 'sleepyeyes', 'todd', 'barr', 'cbsnews', 'chuckwoolery', 'sleepy', 'davidwebbshow', 'corrupt']]
# Coherence c_v: 0.3661980214462351
# Current topic: [['geraldo', 'mueller', 'trumpvlog', 'rivera', 'president', 'impeachment', 'geraldorivera', 'weiner', 'dems', 'donald']]
# Coherence c_v: 0.3191148400139347
# Current topic: [['mortgages', 'foreclosures', 'housing', 'luxury', 'mortgage', 'estates', 'condo', 'villas', 'wealth', 'estate']]
# Coherence c_v: 0.3335920982742676
# Current topic: [['medal', 'roosevelt', 'keane', 'flags', 'honored', 'memorial', 'awards', 'flag', 'honor', 'presidential']]
# Coherence c_v: 0.3938658642100812
# Current topic: [['serta', 'mattresses', 'mattress', 'sheep', 'bed', 'sheets', 'covers', 'apprentice', 'king', 'hotel']]
# Coherence c_v: 0.35398033693112374
# Current topic: [['phones', 'iphone', 'donald', 'apple', 'phone', 'trump', 'samsung', 'screen', 'screens', 'texting']]
# Coherence c_v: 0.38001529718214133
# Current topic: [['lsufootball', 'lsu', 'ncaa', 'finals', 'championship', 'nba', 'sports', 'espn', 'baylor', 'nfl']]
# Coherence c_v: 0.3024198521907713
# Current topic: [['thinking', 'progress', 'thinks', 'dreams', 'success', 'think', 'inspire', 'realdonaldtrump', 'visionary', 'leader']]
# Coherence c_v: 0.37777047195568497
# Current topic: [['trumpfor', 'donald', 'hillarysusans', 'trumpbux', 'realdonaldtrump', 'trumpforprez', 'trumpforpresident', 'trumptforpresident', 'donaldforpresident', 'donaldjtrump']]
# Coherence c_v: 0.37590368226573256
# Current topic: [['veterans', 'servicemen', 'veteran', 'soldier', 'honoring', 'remembrance', 'memorial', 'soldiers', 'usmc', 'patriotic']]
# Coherence c_v: 0.40402447016056015
# Current topic: [['wow', 'unbelievable', 'big', 'stuff']]
# Coherence c_v: 0.4247525282040487
# Current topic: [['letterman', 'colbert', 'snl', 'greggutfeld', 'nbcsnl', 'gutfeld', 'fallon', 'jimmy', 'jd', 'nbcnightly']]
# Coherence c_v: 0.2829989934644201
# Current topic: [['terroristist', 'soleimani', 'benghazi', 'terrorists', 'qaeda', 'terrorist', 'patriot', 'terror', 'realdonaldtrump', 'detainees']]
# Coherence c_v: 0.3144482917702205
# Current topic: [['ebola', 'epidemic', 'quarantines', 'pandemic', 'flu', 'austin', 'outbreak', 'quarantine', 'paso', 'airports']]
# Coherence c_v: 0.3672824794533926
# Current topic: [['pelositantrum', 'impeachments', 'pelosi', 'realdonaldtrump', 'pelos', 'foxnewspolitics', 'impeachmentcircus', 'impeachmen', 'impeachmenthearing', 'impeachment']]
# Coherence c_v: 0.3154840351433675
# Current topic: [['reaganomics', 'reagan', 'trumpenomics', 'booming', 'recession', 'forbes', 'unemployment', 'jobsreport', 'federal', 'fdr']]
# Coherence c_v: 0.47158304888764857
# Current topic: [['presidential', 'presidents', 'president', 'trump', 'bush', 'presidency', 'administrations', 'reagan', 'jfk', 'fed']]
# Coherence c_v: 0.30482712497561715
# Current topic: [['ballots', 'voteridplease', 'voter', 'elections', 'balloting', 'voters', 'election', 'voting', 'electoral', 'pollsters']]
# Coherence c_v: 0.3503632245942187
# Current topic: [['hagel', 'obama', 'senator', 'appointee', 'senate', 'nomination', 'secretary', 'nominating', 'senators', 'tenures']]
# Coherence c_v: 0.3634118268524256
# Current topic: [['usmc', 'birthday', 'marines', 'honorable', 'marine', 'bday', 'usaf', 'nominates', 'veteran', 'usatoday']]
# Coherence c_v: 0.33849326850180217
# Current topic: [['borders', 'immigration', 'wall', 'amnesty', 'illegals', 'fences', 'fence', 'mexicans', 'bipartisan', 'mexican']]
# Coherence c_v: 0.3230837687578376
# Current topic: [['socialist', 'socialism', 'socialists', 'chavez', 'venezuelans', 'venezuelan', 'bolivia', 'venezuela', 'communist', 'dictatorship']]
# Coherence c_v: 0.2846040604332295
# Current topic: [['justices', 'nominates', 'nominee', 'nominate', 'nominating', 'presidential', 'scalia', 'nominees', 'fdr', 'senatemajldr']]
# Coherence c_v: 0.388203507342805
# Current topic: [['veto', 'bipartisan', 'senate', 'congress', 'vetoed', 'feinstein', 'senator', 'congressman', 'representatives', 'committees']]
# Coherence c_v: 0.29802753500903734
# Current topic: [['justices', 'judge', 'txelectionlaw', 'testified', 'congressman', 'legislators', 'congressional', 'tx', 'courts', 'paso']]
# Coherence c_v: 0.3741813743475891
# Current topic: [['georgia', 'ga', 'georgians', 'georgian', 'romneyromney', 'romney', 'atlanta', 'caucus', 'savannah', 'macon']]
# Coherence c_v: 0.3742272811244044
# Current topic: [['bipartisan', 'scalise', 'conservativ', 'dems', 'pelosi', 'lindsey', 'breitbart', 'hillary', 'kasich', 'benghazis']]
# Coherence c_v: 0.29996980339666723
# Current topic: [['presidential', 'trumpsign', 'trumpforpresident', 'donald', 'trump', 'president', 'trumptower', 'congressman', 'trumplife', 'realdonaldtrump']]
# Coherence c_v: 0.32699782980859493
# Current topic: [['flynn', 'indictments', 'mueller', 'congressmen', 'spygate', 'scandals', 'indicted', 'rosenstein', 'mccains', 'testified']]
# Coherence c_v: 0.30569945950005384
# Current topic: [['maga', 'magamarch', 'anarchists', 'antifa', 'rally', 'thugs', 'alpolitics', 'protesters', 'strongl', 'legitimize']]
# Coherence c_v: 0.28734918447164837
# Current topic: [['congresswomen', 'rand', 'candidates', 'congresswoman', 'republican', 'gop', 'politicalelle', 'candidate', 'gopchairwoman', 'politician']]
# Coherence c_v: 0.3184638981226972
# Current topic: [['russiagate', 'collusion', 'breitbart', 'scandal', 'corrupt', 'corruption', 'dnc', 'indictment', 'indicted', 'manafort']]
# Coherence c_v: 0.3425438832254758
# Current topic: [['hamas', 'palestinian', 'palestine', 'baghdadi', 'palestinians', 'israel', 'taliban', 'israeli', 'syrian', 'gaza']]
# Coherence c_v: 0.31392791149335963
# Current topic: [['washington', 'politician', 'president', 'politicians', 'congressman', 'obama', 'anarchists', 'political', 'congress', 'barack']]
# Coherence c_v: 0.35292083290874104
# Current topic: [['presidential', 'donald', 'trump', 'presidents', 'president', 'podium', 'briefings', 'briefing', 'rnc', 'conference']]
# Coherence c_v: 0.34141347383252696
# Current topic: [['presidential', 'presidents', 'presidency', 'president', 'pence', 'vice', 'reagan', 'vp', 'potus', 'impeach']]
# Coherence c_v: 0.2894486706060782
# Current topic: [['senators', 'senatemajldr', 'senate', 'senator', 'bipartisan', 'dems', 'democrats', 'republicans', 'repub', 'republican']]
# Coherence c_v: 0.6194529504400664
# Current topic: [['agree', 'agreed', 'interestingly', 'totally', 'disagree', 'haters', 'wholeheartedly', 'right', 'true', 'noall']]
# Coherence c_v: 0.34224832174898295
# Current topic: [['shinatasangh', 'best', 'strength', 'رنجند', 'choosing', 'باشیم', 'سلاح', 'تحریم', 'سال', 'age']]
# Coherence c_v: 0.32561901516945513
#                                    Highest_Topic_Label  \
# 0       "Trump Administration Statements and Policies"
# 1                Achieving Success and Personal Growth
# 2                                Aircraft and Aviation
# 3    Amazon's Impact on US Postal Service and Taxation
# 4            American Patriotism and National Identity
# ..                                                 ...
# 111                     US Presidential Communications
# 112                US Presidential Politics and Policy
# 113                  US Senate and Republican Politics
# 114                           Validation and Agreement
# 115                     سیاست خارجی و روابط بین المللی
#
#                                               Keywords  Coherence c_v
# 0    [presidential, administrations, pharmacy, pres...       0.330271
# 1    [entrepreneurs, entrepreneur, entrepreneurship...       0.336052
# 2    [airlines, airports, airport, aviation, pilot,...       0.279229
# 3    [postal, washingtonpost, stamps, bezos, parcel...       0.219369
# 4    [anthem, patriotism, allegiance, salutes, salu...       0.370588
# ..                                                 ...            ...
# 111  [presidential, donald, trump, presidents, pres...       0.341413
# 112  [presidential, presidents, presidency, preside...       0.289449
# 113  [senators, senatemajldr, senate, senator, bipa...       0.619453
# 114  [agree, agreed, interestingly, totally, disagr...       0.342248
# 115  [shinatasangh, best, strength, رنجند, choosing...       0.325619
#
# [116 rows x 3 columns]

# %%
file_path = 'Third_Level_Topic_coherence.csv'  # Replace with your file path
data = pd.read_csv(file_path)
mean_score = data['Coherence c_v'].mean()
data['Coherence c_v'].mean()
mean_score
# Out:
# 0.33914022160259877
