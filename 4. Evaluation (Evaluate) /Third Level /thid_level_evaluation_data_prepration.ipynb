# %%
import pandas as pd

# Load the datasets
first_step_result_df = pd.read_csv('First_Step_BERTopic_result.csv')
second_level_knowledge_df = pd.read_csv('First_Step_BERTopic_topic_info_labelled_with_Highest_Topic_Label_final.csv')


# Remove rows where 'Topic' equals -1
first_step_result_df = first_step_result_df[first_step_result_df['Topic Label'] != -1]


# Specify the column names in both datasets for the merge
first_dataset_column = 'Topic Label'
second_dataset_column = 'Topic'

# Merge the datasets based on the 'Topic' and 'Topic Label' columns
merged_df = pd.merge(first_step_result_df, second_level_knowledge_df, 
                     left_on=first_dataset_column, right_on=second_dataset_column, how='left')

# Save the merged dataset
merged_df.to_csv('Merged_First_Step_BERTopic_Result.csv', index=False)

print("Datasets merged successfully.")
# Out:
# /w0/tmp/slurm_yc656703.50590673/ipykernel_121198/425245262.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_step_result_df = pd.read_csv('First_Step_BERTopic_result.csv')
# Datasets merged successfully.

# %%
concatenated_df = pd.concat([merged_df, merged_second_step_df], ignore_index=False)
concatenated_df
# Out:
#                  id              submitter  \
# 0          806.1636     Ian Pratt-Hartmann
# 1          808.0521     Ian Pratt-Hartmann
# 2          905.3108     Ian Pratt-Hartmann
# 3         1104.2444      Claus-Peter Wirth
# 4          1301.387  Pierfrancesco La Mura
# ...             ...                    ...
# 26779    2408.08302                 Bin Hu
# 26780    2408.08307   Ahmed Imtiaz Humayun
# 26781    2408.08310             Ruihang Li
# 26787    cs/0701194       Andrij Rovenchak
# 26788  nlin/0408039            Yuzuru Sato
#
#                                                  authors  \
# 0                                     Ian Pratt-Hartmann
# 1                Ian Pratt-Hartmann and Lawrence S. Moss
# 2                 Yevgeny Kazakov and Ian Pratt-Hartmann
# 3                                      Claus-Peter Wirth
# 4                                  Pierfrancesco La Mura
# ...                                                  ...
# 26779  Usman Syed, Ethan Light, Xingang Guo, Huan Zha...
# 26780  Ahmed Imtiaz Humayun, Ibtihel Amara, Candice S...
# 26781  Ruihang Li, Yixuan Wei, Miaosen Zhang, Nenghai...
# 26787                  Solomija Buk and Andrij Rovenchak
# 26788    Yuzuru Sato, Eizo Akiyama, James P. Crutchfield
#
#                                                    title  \
# 0      Data-Complexity of the Two-Variable Fragment w...
# 1                  Logics for the Relational Syllogistic
# 2      A Note on the Complexity of the Satisfiability...
# 3      A Simplified and Improved Free-Variable Framew...
# 4                                          Game Networks
# ...                                                  ...
# 26779  Benchmarking the Capabilities of Large Languag...
# 26780  Understanding the Local Geometry of Generative...
# 26781  ScalingFilter: Assessing Data Quality through ...
# 26787  Menzerath-Altmann Law for Syntactic Structures...
# 26788   Stability and Diversity in Collective Adaptation
#
#                                                 comments  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Full proofs for paper presented at the IEEE Co...
# 3                                         ii + 114 pages
# 4      Appears in Proceedings of the Sixteenth Confer...
# ...                                                  ...
# 26779                                                NaN
# 26780  Pre-print. 11 pages main, 8 pages app., 28 fig...
# 26781                                                NaN
# 26787  8 pages; submitted to the Proceedings of the I...
# 26788  22 pages, 23 figures; updated references, corr...
#
#                                              journal-ref  \
# 0      Information and Computation, 207(8), 2009, pp....
# 1      Review of Symbolic Logic, 2(4), 2009, pp. 647-...
# 2      Proceedings, 24th Annual IEEE Symposium on Log...
# 3      IfCoLog Journal of Logics and their Applicatio...
# 4                                                    NaN
# ...                                                  ...
# 26779                                                NaN
# 26780                                                NaN
# 26781                                                NaN
# 26787       Glottotheory. Vol. 1, No. 1, pp 10-17 (2008)
# 26788                                                NaN
#
#                                doi  \
# 0         10.1016/j.ic.2009.02.004
# 1        10.1017/S1755020309990086
# 2             10.1109/LICS.2009.17
# 3                              NaN
# 4                              NaN
# ...                            ...
# 26779                          NaN
# 26780                          NaN
# 26781                          NaN
# 26787       10.1515/glot-2008-0002
# 26788  10.1016/j.physd.2005.06.031
#
#                                         report-no  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                          SEKI Report SR-2011-01
# 4                           UAI-P-2000-PG-335-342
# ...                                           ...
# 26779                                         NaN
# 26780                                         NaN
# 26781                                         NaN
# 26787                                         NaN
# 26788  Santa Fe Institute Working Paper 04-08-025
#
#                                   categories  \
# 0                          cs.LO cs.AI cs.CC
# 1                          cs.LO cs.CC cs.CL
# 2                          cs.LO cs.AI cs.CC
# 3                              cs.AI math.LO
# 4                                cs.GT cs.AI
# ...                                      ...
# 26779                      cs.AI cs.CL cs.LG
# 26780                            cs.LG cs.CV
# 26781                                  cs.CL
# 26787                                  cs.CL
# 26788  nlin.AO cs.LG math.DS nlin.CD stat.ML
#
#                                                  license  ...  \
# 0      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 1      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 2      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 3      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 4      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# ...                                                  ...  ...
# 26779  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 26780  http://creativecommons.org/licenses/by-nc-sa/4.0/  ...
# 26781  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 26787                                                NaN  ...
# 26788                                                NaN  ...
#
#                                    Human_Readable_Topic  \
# 0          Formal Reasoning and Satisfiability in Logic
# 1          Formal Reasoning and Satisfiability in Logic
# 2          Formal Reasoning and Satisfiability in Logic
# 3          Formal Reasoning and Satisfiability in Logic
# 4             Game Theory and Strategic Decision Making
# ...                                                 ...
# 26779      Transportation Systems and Mobility Analysis
# 26780               Manifold Learning with Autoencoders
# 26781      Large Language Models and Dataset Generation
# 26787  Multilingual Language Processing and Linguistics
# 26788      Optimal Decision-Making in Multi-Agent Games
#
#                                       Higher_Topic_Label  \
# 0      Reasoning and Problem-Solving with Logic, Lang...
# 1      Reasoning and Problem-Solving with Logic, Lang...
# 2      Reasoning and Problem-Solving with Logic, Lang...
# 3      Reasoning and Problem-Solving with Logic, Lang...
# 4              Game Theory and Strategic Decision Making
# ...                                                  ...
# 26779               Transportation and Mobility Analysis
# 26780               Geometric Deep Learning on Manifolds
# 26781                  Advances in Large Language Models
# 26787           Multilingual Natural Language Processing
# 26788  Multi-Agent Decision Making and Reinforcement ...
#
#                                      Highest_Topic_Label Unnamed: 0_x  \
# 0          Artificial Intelligence and Reasoning Systems          NaN
# 1          Artificial Intelligence and Reasoning Systems          NaN
# 2          Artificial Intelligence and Reasoning Systems          NaN
# 3          Artificial Intelligence and Reasoning Systems          NaN
# 4      Decision Making and Optimization under Uncerta...          NaN
# ...                                                  ...          ...
# 26779  Transportation Systems and Environmental Analy...      20548.0
# 26780            Geometric and Equivariant Deep Learning      20549.0
# 26781                              Large Language Models      20550.0
# 26787                        Natural Language Processing      20551.0
# 26788    Multi-Agent Systems and Artificial Intelligence      20552.0
#
#                                 Second_Step_Topic_Name  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 26779     36_transportation_traffic_routes_ridesharing
# 26780  291_autoencoders_autoencoder_embeddings_encoder
# 26781             146_tokenizers_language_datasets_nlp
# 26787     170_lingual_multilingual_corpus_translations
# 26788          199_reinforcement_optimal_games_bandits
#
#                               Second_Step_Topic_Keywords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26779  transportation, traffic, routes, ridesharing, ...
# 26780  autoencoders, autoencoder, embeddings, encoder...
# 26781  tokenizers, language, datasets, nlp, models, f...
# 26787  lingual, multilingual, corpus, translations, l...
# 26788  reinforcement, optimal, games, bandits, strate...
#
#                         Second_Step_Topic_Representation  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26779  transportation (0.48), traffic (0.47), routes ...
# 26780  autoencoders (0.58), autoencoder (0.52), embed...
# 26781  tokenizers (0.42), language (0.35), datasets (...
# 26787  lingual (0.52), multilingual (0.52), corpus (0...
# 26788  reinforcement (0.44), optimal (0.41), games (0...
#
#                          Second_Step_Representative_Docs Unnamed: 0_y  \
# 0                                                    NaN          NaN
# 1                                                    NaN          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 26779    Mobility service route design requires deman...         36.0
# 26780    Representing a manifold of very high-dimensi...        291.0
# 26781    The rapid advancement of large language mode...        146.0
# 26787    As Uzbek language is agglutinative, has many...        170.0
# 26788    Addressing the question of how to achieve op...        199.0
#
#                                              Final_Label
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 26779  Transportation Systems and Environmental Analy...
# 26780            Geometric and Equivariant Deep Learning
# 26781                              Large Language Models
# 26787                        Natural Language Processing
# 26788    Multi-Agent Systems and Artificial Intelligence
#
# [60328 rows x 35 columns]

# %%
import pandas as pd

# Load the datasets
second_step_result_df = pd.read_csv('Second_Step_BERTopic_results.csv')
second_level_knowledge_df = pd.read_csv('Second_Step_BERTopic_topic_info_labelled_with_Final_Label_Merged.csv')

# Specify the column names in both datasets for the merge
first_dataset_column = 'Topic Label'
second_dataset_column = 'Topic'


# Merge the datasets based on the 'Topic Label' and 'Topic' columns
merged_second_step_df = pd.merge(second_step_result_df, second_level_knowledge_df, 
                                 left_on=first_dataset_column, right_on=second_dataset_column, how='left')

merged_second_step_df = merged_second_step_df.drop_duplicates()


# Save the merged dataset
merged_second_step_df.to_csv('Merged_Second_Step_BERTopic_Result.csv', index=False)

print("Second step datasets merged successfully.")
# Out:
# Second step datasets merged successfully.

# %%
merged_second_step_df
# Out:
#        Unnamed: 0_x            id             submitter  \
# 0                 0      1203.055   Afshin Rostamizadeh
# 1                 1     1402.5593         Rustam Tagiew
# 2                 2     1404.0736           Remi Denton
# 3                 3    1501.01678       Changwang Zhang
# 5                 4     1507.0275         Pratik Gajane
# ...             ...           ...                   ...
# 26779         20548    2408.08302                Bin Hu
# 26780         20549    2408.08307  Ahmed Imtiaz Humayun
# 26781         20550    2408.08310            Ruihang Li
# 26787         20551    cs/0701194      Andrij Rovenchak
# 26788         20552  nlin/0408039           Yuzuru Sato
#
#                                                  authors  \
# 0      Corinna Cortes, Mehryar Mohri, Afshin Rostamiz...
# 1                    Rustam Tagiew and Dmitry I. Ignatov
# 2      Remi Denton, Wojciech Zaremba, Joan Bruna, Yan...
# 3       Changwang Zhang, Shi Zhou, and Benjamin M. Chain
# 5                         Pratik Gajane and Tanguy Urvoy
# ...                                                  ...
# 26779  Usman Syed, Ethan Light, Xingang Guo, Huan Zha...
# 26780  Ahmed Imtiaz Humayun, Ibtihel Amara, Candice S...
# 26781  Ruihang Li, Yixuan Wei, Miaosen Zhang, Nenghai...
# 26787                  Solomija Buk and Andrij Rovenchak
# 26788    Yuzuru Sato, Eizo Akiyama, James P. Crutchfield
#
#                                                    title  \
# 0      Algorithms for Learning Kernels Based on Cente...
# 1                     Reciprocity in Gift-Exchange-Games
# 2      Exploiting Linear Structure Within Convolution...
# 3      LeoTask: a fast, flexible and reliable framewo...
# 5      Utility-based Dueling Bandits as a Partial Mon...
# ...                                                  ...
# 26779  Benchmarking the Capabilities of Large Languag...
# 26780  Understanding the Local Geometry of Generative...
# 26781  ScalingFilter: Assessing Data Quality through ...
# 26787  Menzerath-Altmann Law for Syntactic Structures...
# 26788   Stability and Diversity in Collective Adaptation
#
#                                                 comments  \
# 0                                                    NaN
# 1                           6 pages, 2 figures, 5 tables
# 2                                                    NaN
# 3                                                    NaN
# 5      Accepted at the 12th European Workshop on Rein...
# ...                                                  ...
# 26779                                                NaN
# 26780  Pre-print. 11 pages main, 8 pages app., 28 fig...
# 26781                                                NaN
# 26787  8 pages; submitted to the Proceedings of the I...
# 26788  22 pages, 23 figures; updated references, corr...
#
#                                              journal-ref  \
# 0      Journal of Machine Learning Research 13 (2012)...
# 1      Experimental Economics and Machine Learning 20...
# 2                                                    NaN
# 3                                                    NaN
# 5      12th European Workshop on Reinforcement Learni...
# ...                                                  ...
# 26779                                                NaN
# 26780                                                NaN
# 26781                                                NaN
# 26787       Glottotheory. Vol. 1, No. 1, pp 10-17 (2008)
# 26788                                                NaN
#
#                                doi  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 5                              NaN
# ...                            ...
# 26779                          NaN
# 26780                          NaN
# 26781                          NaN
# 26787       10.1515/glot-2008-0002
# 26788  10.1016/j.physd.2005.06.031
#
#                                         report-no  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 5                                             NaN
# ...                                           ...
# 26779                                         NaN
# 26780                                         NaN
# 26781                                         NaN
# 26787                                         NaN
# 26788  Santa Fe Institute Working Paper 04-08-025
#
#                                   categories  ... Topic Count  \
# 0                                cs.LG cs.AI  ...   139    65
# 1                                      cs.AI  ...    56    95
# 2                                cs.CV cs.LG  ...    23   117
# 3                    cs.SE cs.AI cs.DC cs.PL  ...    95    78
# 5                                      cs.LG  ...    64    92
# ...                                      ...  ...   ...   ...
# 26779                      cs.AI cs.CL cs.LG  ...    36   107
# 26780                            cs.LG cs.CV  ...   291    21
# 26781                                  cs.CL  ...   146    63
# 26787                                  cs.CL  ...   170    56
# 26788  nlin.AO cs.LG math.DS nlin.CD stat.ML  ...   199    50
#
#                                                   Name  \
# 0      139_regularization_kernels_lasso_classification
# 1          56_optimal_allocation_equilibrium_incentive
# 2                   23_parallelization_fpgas_cnns_fpga
# 3            95_workflows_workflow_automate_automation
# 5                     64_bandits_bandit_optimal_regret
# ...                                                ...
# 26779     36_transportation_traffic_routes_ridesharing
# 26780  291_autoencoders_autoencoder_embeddings_encoder
# 26781             146_tokenizers_language_datasets_nlp
# 26787     170_lingual_multilingual_corpus_translations
# 26788          199_reinforcement_optimal_games_bandits
#
#                                           Representation  \
# 0      ['regularization', 'kernels', 'lasso', 'classi...
# 1      ['optimal', 'allocation', 'equilibrium', 'ince...
# 2      ['parallelization', 'fpgas', 'cnns', 'fpga', '...
# 3      ['workflows', 'workflow', 'automate', 'automat...
# 5      ['bandits', 'bandit', 'optimal', 'regret', 'op...
# ...                                                  ...
# 26779  ['transportation', 'traffic', 'routes', 'rides...
# 26780  ['autoencoders', 'autoencoder', 'embeddings', ...
# 26781  ['tokenizers', 'language', 'datasets', 'nlp', ...
# 26787  ['lingual', 'multilingual', 'corpus', 'transla...
# 26788  ['reinforcement', 'optimal', 'games', 'bandits...
#
#                                                  Aspect1  \
# 0      ['kernel', 'regularization', 'linear', 'sparse...
# 1      ['regret', 'facility', 'agents', 'bandit', 'op...
# 2      ['hardware', 'parallelism', 'memory', 'acceler...
# 3      ['workflow', 'workflows', 'tools', 'agents', '...
# 5      ['regret', 'bandit', 'games', 'bandits', 'onli...
# ...                                                  ...
# 26779  ['mobility', 'transportation', 'travel', 'traf...
# 26780  ['latent', 'manifold', 'dimensional', 'spaces'...
# 26781  ['glitch', 'tokens', 'language', 'synthetic', ...
# 26787  ['languages', 'translation', 'lingual', 'hallu...
# 26788  ['games', 'game', 'equilibrium', 'agents', 'co...
#
#                                      Representative_Docs  \
# 0      ['  In inverse problems, it is widely recogniz...
# 1      ["  Two-sided matching markets have been widel...
# 2      ['  The relentless advancement of artificial i...
# 3      ['  Automating enterprise workflows could unlo...
# 5      ['  In this work, we study potential games and...
# ...                                                  ...
# 26779  ['  Mobility service route design requires dem...
# 26780  ['  Representing a manifold of very high-dimen...
# 26781  ["  The rapid advancement of large language mo...
# 26787  ['  As Uzbek language is agglutinative, has ma...
# 26788  ['  Addressing the question of how to achieve ...
#
#                                     Human_Readable_Topic  \
# 0      Machine Learning for Inverse Problems and Kern...
# 1       Mechanism Design for Strategic Markets and Games
# 2          AI/ML Hardware Accelerators and Optimizations
# 3                    Automating Workflows with AI and ML
# 5       Bandit Learning and Regret Optimization in Games
# ...                                                  ...
# 26779       Transportation Systems and Mobility Analysis
# 26780                Manifold Learning with Autoencoders
# 26781       Large Language Models and Dataset Generation
# 26787   Multilingual Language Processing and Linguistics
# 26788       Optimal Decision-Making in Multi-Agent Games
#
#                                       Higher_Topic_Label  \
# 0                  Machine Learning for Inverse Problems
# 1              Game Theory and Strategic Decision Making
# 2      Hardware Design and Acceleration for AI and ML...
# 3      Artificial Intelligence in Technology and Engi...
# 5      Optimization and Learning in Bandit and Game-T...
# ...                                                  ...
# 26779               Transportation and Mobility Analysis
# 26780               Geometric Deep Learning on Manifolds
# 26781                  Advances in Large Language Models
# 26787           Multilingual Natural Language Processing
# 26788  Multi-Agent Decision Making and Reinforcement ...
#
#                                      Highest_Topic_Label  \
# 0                      Machine Learning and Optimization
# 1      Decision Making and Optimization under Uncerta...
# 2      Artificial Intelligence and Machine Learning H...
# 3          Artificial Intelligence and Cognitive Systems
# 5      Decision Making and Optimization under Uncerta...
# ...                                                  ...
# 26779  Transportation Systems and Environmental Analy...
# 26780            Geometric and Equivariant Deep Learning
# 26781                              Large Language Models
# 26787                        Natural Language Processing
# 26788    Multi-Agent Systems and Artificial Intelligence
#
#                                              Final_Label
# 0           Machine Learning and Artificial Intelligence
# 1      Decision Making and Optimization under Uncerta...
# 2      Artificial Intelligence and Machine Learning H...
# 3          Artificial Intelligence and Reasoning Systems
# 5      Decision Making and Optimization under Uncerta...
# ...                                                  ...
# 26779  Transportation Systems and Environmental Analy...
# 26780            Geometric and Equivariant Deep Learning
# 26781                              Large Language Models
# 26787                        Natural Language Processing
# 26788    Multi-Agent Systems and Artificial Intelligence
#
# [20553 rows x 35 columns]

# %%
import pandas as pd

# Load the datasets
first_step_result_df = pd.read_csv('Merged_First_Step_BERTopic_Result.csv')
second_step_result_df = pd.read_csv('Merged_Second_Step_BERTopic_Result.csv')


# Step 2: Concatenate the filtered first step dataset with the second step dataset
concatenated_df = pd.concat([filtered_first_step_df, second_step_result_df], ignore_index=True)

# Save the concatenated dataset
concatenated_df.to_csv('Concatenated_First_Second_Step_BERTopic_Result.csv', index=False)

print("Datasets filtered and concatenated successfully.")
# Out:
# /w0/tmp/slurm_yc656703.50590673/ipykernel_121198/2208170543.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   first_step_result_df = pd.read_csv('Merged_First_Step_BERTopic_Result.csv')
# /w0/tmp/slurm_yc656703.50590673/ipykernel_121198/2208170543.py:5: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_step_result_df = pd.read_csv('Merged_Second_Step_BERTopic_Result.csv')
# /home/yc656703/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:7834: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# Datasets filtered and concatenated successfully.

# %%
concatenated_df
# Out:
#                  id              submitter  \
# 0          806.1636     Ian Pratt-Hartmann
# 1          808.0521     Ian Pratt-Hartmann
# 2          905.3108     Ian Pratt-Hartmann
# 3         1104.2444      Claus-Peter Wirth
# 4          1301.387  Pierfrancesco La Mura
# ...             ...                    ...
# 60323    2408.08302                 Bin Hu
# 60324    2408.08307   Ahmed Imtiaz Humayun
# 60325    2408.08310             Ruihang Li
# 60326    cs/0701194       Andrij Rovenchak
# 60327  nlin/0408039            Yuzuru Sato
#
#                                                  authors  \
# 0                                     Ian Pratt-Hartmann
# 1                Ian Pratt-Hartmann and Lawrence S. Moss
# 2                 Yevgeny Kazakov and Ian Pratt-Hartmann
# 3                                      Claus-Peter Wirth
# 4                                  Pierfrancesco La Mura
# ...                                                  ...
# 60323  Usman Syed, Ethan Light, Xingang Guo, Huan Zha...
# 60324  Ahmed Imtiaz Humayun, Ibtihel Amara, Candice S...
# 60325  Ruihang Li, Yixuan Wei, Miaosen Zhang, Nenghai...
# 60326                  Solomija Buk and Andrij Rovenchak
# 60327    Yuzuru Sato, Eizo Akiyama, James P. Crutchfield
#
#                                                    title  \
# 0      Data-Complexity of the Two-Variable Fragment w...
# 1                  Logics for the Relational Syllogistic
# 2      A Note on the Complexity of the Satisfiability...
# 3      A Simplified and Improved Free-Variable Framew...
# 4                                          Game Networks
# ...                                                  ...
# 60323  Benchmarking the Capabilities of Large Languag...
# 60324  Understanding the Local Geometry of Generative...
# 60325  ScalingFilter: Assessing Data Quality through ...
# 60326  Menzerath-Altmann Law for Syntactic Structures...
# 60327   Stability and Diversity in Collective Adaptation
#
#                                                 comments  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Full proofs for paper presented at the IEEE Co...
# 3                                         ii + 114 pages
# 4      Appears in Proceedings of the Sixteenth Confer...
# ...                                                  ...
# 60323                                                NaN
# 60324  Pre-print. 11 pages main, 8 pages app., 28 fig...
# 60325                                                NaN
# 60326  8 pages; submitted to the Proceedings of the I...
# 60327  22 pages, 23 figures; updated references, corr...
#
#                                              journal-ref  \
# 0      Information and Computation, 207(8), 2009, pp....
# 1      Review of Symbolic Logic, 2(4), 2009, pp. 647-...
# 2      Proceedings, 24th Annual IEEE Symposium on Log...
# 3      IfCoLog Journal of Logics and their Applicatio...
# 4                                                    NaN
# ...                                                  ...
# 60323                                                NaN
# 60324                                                NaN
# 60325                                                NaN
# 60326       Glottotheory. Vol. 1, No. 1, pp 10-17 (2008)
# 60327                                                NaN
#
#                                doi  \
# 0         10.1016/j.ic.2009.02.004
# 1        10.1017/S1755020309990086
# 2             10.1109/LICS.2009.17
# 3                              NaN
# 4                              NaN
# ...                            ...
# 60323                          NaN
# 60324                          NaN
# 60325                          NaN
# 60326       10.1515/glot-2008-0002
# 60327  10.1016/j.physd.2005.06.031
#
#                                         report-no  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                          SEKI Report SR-2011-01
# 4                           UAI-P-2000-PG-335-342
# ...                                           ...
# 60323                                         NaN
# 60324                                         NaN
# 60325                                         NaN
# 60326                                         NaN
# 60327  Santa Fe Institute Working Paper 04-08-025
#
#                                   categories  \
# 0                          cs.LO cs.AI cs.CC
# 1                          cs.LO cs.CC cs.CL
# 2                          cs.LO cs.AI cs.CC
# 3                              cs.AI math.LO
# 4                                cs.GT cs.AI
# ...                                      ...
# 60323                      cs.AI cs.CL cs.LG
# 60324                            cs.LG cs.CV
# 60325                                  cs.CL
# 60326                                  cs.CL
# 60327  nlin.AO cs.LG math.DS nlin.CD stat.ML
#
#                                                  license  ...  \
# 0      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 1      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 2      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 3      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 4      http://arxiv.org/licenses/nonexclusive-distrib...  ...
# ...                                                  ...  ...
# 60323  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 60324  http://creativecommons.org/licenses/by-nc-sa/4.0/  ...
# 60325  http://arxiv.org/licenses/nonexclusive-distrib...  ...
# 60326                                                NaN  ...
# 60327                                                NaN  ...
#
#                                    Human_Readable_Topic  \
# 0          Formal Reasoning and Satisfiability in Logic
# 1          Formal Reasoning and Satisfiability in Logic
# 2          Formal Reasoning and Satisfiability in Logic
# 3          Formal Reasoning and Satisfiability in Logic
# 4             Game Theory and Strategic Decision Making
# ...                                                 ...
# 60323      Transportation Systems and Mobility Analysis
# 60324               Manifold Learning with Autoencoders
# 60325      Large Language Models and Dataset Generation
# 60326  Multilingual Language Processing and Linguistics
# 60327      Optimal Decision-Making in Multi-Agent Games
#
#                                       Higher_Topic_Label  \
# 0      Reasoning and Problem-Solving with Logic, Lang...
# 1      Reasoning and Problem-Solving with Logic, Lang...
# 2      Reasoning and Problem-Solving with Logic, Lang...
# 3      Reasoning and Problem-Solving with Logic, Lang...
# 4              Game Theory and Strategic Decision Making
# ...                                                  ...
# 60323               Transportation and Mobility Analysis
# 60324               Geometric Deep Learning on Manifolds
# 60325                  Advances in Large Language Models
# 60326           Multilingual Natural Language Processing
# 60327  Multi-Agent Decision Making and Reinforcement ...
#
#                                      Highest_Topic_Label Unnamed: 0_x  \
# 0          Artificial Intelligence and Reasoning Systems          NaN
# 1          Artificial Intelligence and Reasoning Systems          NaN
# 2          Artificial Intelligence and Reasoning Systems          NaN
# 3          Artificial Intelligence and Reasoning Systems          NaN
# 4      Decision Making and Optimization under Uncerta...          NaN
# ...                                                  ...          ...
# 60323  Transportation Systems and Environmental Analy...      20548.0
# 60324            Geometric and Equivariant Deep Learning      20549.0
# 60325                              Large Language Models      20550.0
# 60326                        Natural Language Processing      20551.0
# 60327    Multi-Agent Systems and Artificial Intelligence      20552.0
#
#                                 Second_Step_Topic_Name  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 60323     36_transportation_traffic_routes_ridesharing
# 60324  291_autoencoders_autoencoder_embeddings_encoder
# 60325             146_tokenizers_language_datasets_nlp
# 60326     170_lingual_multilingual_corpus_translations
# 60327          199_reinforcement_optimal_games_bandits
#
#                               Second_Step_Topic_Keywords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  transportation, traffic, routes, ridesharing, ...
# 60324  autoencoders, autoencoder, embeddings, encoder...
# 60325  tokenizers, language, datasets, nlp, models, f...
# 60326  lingual, multilingual, corpus, translations, l...
# 60327  reinforcement, optimal, games, bandits, strate...
#
#                         Second_Step_Topic_Representation  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  transportation (0.48), traffic (0.47), routes ...
# 60324  autoencoders (0.58), autoencoder (0.52), embed...
# 60325  tokenizers (0.42), language (0.35), datasets (...
# 60326  lingual (0.52), multilingual (0.52), corpus (0...
# 60327  reinforcement (0.44), optimal (0.41), games (0...
#
#                          Second_Step_Representative_Docs Unnamed: 0_y  \
# 0                                                    NaN          NaN
# 1                                                    NaN          NaN
# 2                                                    NaN          NaN
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 60323    Mobility service route design requires deman...         36.0
# 60324    Representing a manifold of very high-dimensi...        291.0
# 60325    The rapid advancement of large language mode...        146.0
# 60326    As Uzbek language is agglutinative, has many...        170.0
# 60327    Addressing the question of how to achieve op...        199.0
#
#                                              Final_Label
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 60323  Transportation Systems and Environmental Analy...
# 60324            Geometric and Equivariant Deep Learning
# 60325                              Large Language Models
# 60326                        Natural Language Processing
# 60327    Multi-Agent Systems and Artificial Intelligence
#
# [60328 rows x 35 columns]
